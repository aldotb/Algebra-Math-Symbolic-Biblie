# %%
from  Libaldomath  import *
# this cell will be initializing your variables,get help run helplib

# %% [markdown]
#  <img src="https://github.com/aldotb/Solve-Academic-Algebra-Math-Problems-whit-Python-and-Sympy/blob/main/images/linep.png?raw=1" alt="ml" style="width : 100%;"/>

# %% [markdown]
# ![image.png](attachment:639f001d-e725-4d76-8f10-4b06de5d0211.png)

# %%
(cos(pi))**3
# Out:
# -1

# %%
Q1=MQ(x**3-x**2,-1)
# Out:
# $\displaystyle x^{3} - x^{2} = -1$

# %%
Q1.Add(x*x)
# Out:
# $\displaystyle x^{3} = x^{2} - 1$

# %%
Q1.Add(1)
# Out:
# $\displaystyle x^{3} + 1 = x^{2}$

# %%
P=MyEq(x**7+x**6+x**5+x**3+2*x*x+2*x ,'P')
# Out:
# $\displaystyle P =x^{7} + x^{6} + x^{5} + x^{3} + 2 x^{2} + 2 x$

# %%
P.subs(x**6,x**4-2*x*x+1)
# Out:
# $\displaystyle P =x^{7} + x^{5} + x^{4} + x^{3} + 2 x + 1$

# %%
P.efactor(x**7+x**4,x**4)
# Out:
# $\displaystyle P =x^{5} + x^{4} \left(x^{3} + 1\right) + x^{3} + 2 x + 1$

# %%
P.subs(x**3+1,x**2)
# Out:
# $\displaystyle P =x^{6} + x^{5} + x^{2} + 2 x$

# %%
P.efactor(x**5+x**2,x**2)
# Out:
# $\displaystyle P =x^{6} + x^{2} \left(x^{3} + 1\right) + 2 x$

# %%
P.subs(x**3+1,x**2)
# Out:
# $\displaystyle P =x^{6} + x^{4} + 2 x$

# %%
P.subs(x**6,x**4-2*x*x+1)
# Out:
# $\displaystyle P =2 x^{4} - 2 x^{2} + 2 x + 1$

# %%
P.efactor(2*x**4+2*x,2*x)
# Out:
# $\displaystyle P =- 2 x^{2} + 2 x \left(x^{3} + 1\right) + 1$

# %%
P.subs(x**3+1,x**2)
# Out:
# $\displaystyle P =2 x^{3} - 2 x^{2} + 1$

# %%
P.efactor(2*x**3-2*x**2,2)
# Out:
# $\displaystyle P =2 \left(x^{3} - x^{2}\right) + 1$

# %%
P.subs(x**3-x**2,-1)
# Out:
# $\displaystyle P =-1$

# %% [markdown]
#  <img src="https://github.com/aldotb/Solve-Academic-Algebra-Math-Problems-whit-Python-and-Sympy/blob/main/images/linep.png?raw=1" alt="ml" style="width : 100%;"/>

# %%
from  Libaldomath  import *
# this cell will be initializing your variables,get help run helplib

# %% [markdown]
#  <img src="https://github.com/aldotb/Solve-Academic-Algebra-Math-Problems-whit-Python-and-Sympy/blob/main/images/p38.png?raw=1" alt="ml" style="width : 100%;"/>

# %% [markdown]
#  <img src="https://github.com/aldotb/Solve-Academic-Algebra-Math-Problems-whit-Python-and-Sympy/blob/main/images/lines.png?raw=1" alt="ml" style="width : 100%;"/>

# %%
xx=symbols('f(x)')

# %%
x1=symbols('f(x+1)')

# %%
x2=symbols('f(x+2)')

# %%
P=MQ(x2,x+xx+x1)
# Out:
# $\displaystyle f(x+2) = f(x) + f(x+1) + x$

# %%
P.setL(2*x1)
# Out:
# $\displaystyle 2 f(x+1) = f(x) + f(x+1) + x$

# %%
P.Substrac(x1)
# Out:
# $\displaystyle f(x+1) = f(x) + x$

# %%
P.setL(2*xx)
# Out:
# $\displaystyle 2 f(x) = f(x) + x$

# %%
P.Substrac(xx)
# Out:
# $\displaystyle f(x) = x$

# %%
f=MyEq(x,'f')
# Out:
# $\displaystyle f =x$

# %%
f(-3)+f(4)
# Out:
# 1

# %% [markdown]
#  <img src="https://github.com/aldotb/Solve-Academic-Algebra-Math-Problems-whit-Python-and-Sympy/blob/main/images/linep.png?raw=1" alt="ml" style="width : 100%;"/>

# %%
from  Libaldomath  import *
# this cell will be initializing your variables,get help run helplib

# %% [markdown]
#  <img src="https://github.com/aldotb/Solve-Academic-Algebra-Math-Problems-whit-Python-and-Sympy/blob/main/images/p39.png?raw=1" alt="ml" style="width : 100%;"/>

# %% [markdown]
#  <img src="https://github.com/aldotb/Solve-Academic-Algebra-Math-Problems-whit-Python-and-Sympy/blob/main/images/lines.png?raw=1" alt="ml" style="width : 100%;"/>

# %%
f=MyEq(exp(x)+pi**x,'f')
# Out:
# $\displaystyle f =\pi^{x} + e^{x}$

# %%
f(1)
# Out:
# ℯ + π

# %%
f(3)  # and equal 1
# Out:
#  3    3
# ℯ  + π

# %%
F1=MyEq(f(4)-f(7),'F1')
# Out:
# $\displaystyle F1 =- \pi^{7} - e^{7} + e^{4} + \pi^{4}$

# %%
F1.efactor(pi**4-pi**7,pi**4)
# Out:
# $\displaystyle F1 =\pi^{4} \cdot \left(1 - \pi^{3}\right) - e^{7} + e^{4}$

# %%
F1.efactor(exp(4)-exp(7),exp(4))
# Out:
# $\displaystyle F1 =\pi^{4} \cdot \left(1 - \pi^{3}\right) + \left(1 - e^{3}\right) e^{4}$

# %%
F1.subs(1-pi**3,exp(3))
# Out:
# $\displaystyle F1 =\left(1 - e^{3}\right) e^{4} + \pi^{4} e^{3}$

# %%
F1.subs(1-exp(3),pi**3)
# Out:
# $\displaystyle F1 =\pi^{3} e^{4} + \pi^{4} e^{3}$

# %%
F1.factor()
# Out:
# $\displaystyle F1 =\pi^{3} \left(e + \pi\right) e^{3}$

# %%
F1.subs(exp(1)+pi,1)
# Out:
# $\displaystyle F1 =\pi^{3} e^{3}$

# %%
F2=MyEq(1/F1,'F2')
# Out:
# $\displaystyle F2 =\frac{1}{\pi^{3} e^{3}}$

# %%
F2.Rpow(3)
# Out:
# $\displaystyle F2 =\frac{1}{e \pi}$

# %% [markdown]
#  <img src="https://github.com/aldotb/Solve-Academic-Algebra-Math-Problems-whit-Python-and-Sympy/blob/main/images/linep.png?raw=1" alt="ml" style="width : 100%;"/>

# %%
from  Libaldomath  import *
# this cell will be initializing your variables,get help run helplib

# %% [markdown]
#  <img src="https://github.com/aldotb/Solve-Academic-Algebra-Math-Problems-whit-Python-and-Sympy/blob/main/images/p45.png?raw=1" alt="ml" style="width : 100%;"/>

# %% [markdown]
#  <img src="https://github.com/aldotb/Solve-Academic-Algebra-Math-Problems-whit-Python-and-Sympy/blob/main/images/lines.png?raw=1" alt="ml" style="width : 100%;"/>

# %%
def fx(x):
    return((x+1)/(x-1))

# %%
sE(['From','data','f(1/2)=',fx(frs(1,2)),'.f(',fx(frs(1,2)),')+3'])
# Out:
# $\displaystyle From\;data\;f(1/2)=\;-3\;.f(\;-3\;)+3\;$

# %%
sE(['Also..','f(-3)=',fx(-3),'.f(',fx(-3),')+3'])
# Out:
# $\displaystyle Also..\;f(-3)=\;0.5\;.f(\;0.5\;)+3\;$

# %%
# f(-3)  = y
# f(1/2) = x then
x,y = symbols('x y')
csolve(y-x/2-3,y)
# Out:
# x
# ─ + 3
# 2

# %%
csolve(x -(-3*(x/2+3)+3),x)
# Out:
# -12/5

# %% [markdown]
#  <img src="https://github.com/aldotb/Solve-Academic-Algebra-Math-Problems-whit-Python-and-Sympy/blob/main/images/linep.png?raw=1" alt="ml" style="width : 100%;"/>

# %%
from  Libaldomath  import *
# this cell will be initializing your variables,get help run helplib

# %% [markdown]
#  <img src="https://github.com/aldotb/Solve-Academic-Algebra-Math-Problems-whit-Python-and-Sympy/blob/main/images/p47.png?raw=1" alt="ml" style="width : 100%;"/>

# %% [markdown]
#  <img src="https://github.com/aldotb/Solve-Academic-Algebra-Math-Problems-whit-Python-and-Sympy/blob/main/images/lines.png?raw=1" alt="ml" style="width : 100%;"/>

# %%
a,b,c,x=symbols('a b c x')

# %%
def P(x):
    return(opemat(x*x+a,'esfs'))

# %%
a1=P(P(P(x)));a1 # n=3
# Out:
#  4      3  2      3      2  4      2  2    2        6        4        8
# a  + 4⋅a ⋅x  + 2⋅a  + 6⋅a ⋅x  + 4⋅a ⋅x  + a  + 4⋅a⋅x  + 2⋅a⋅x  + a + x

# %% [markdown]
#  <img src="https://github.com/aldotb/Solve-Academic-Algebra-Math-Problems-whit-Python-and-Sympy/blob/main/images/p47a.png?raw=1" alt="ml" style="width : 80%;"/>

# %%
fpoly(a1,'unfilt',x) # return al monom if dont have x...
# Out:
#  4      3    2
# a  + 2⋅a  + a  + a

# %%
show_exp(['if',fpoly(a1,'unfilt',x),'=',5,'then',a,'=',1])
# Out:
# $\displaystyle if\;a^{4} + 2 a^{3} + a^{2} + a\;=\;5\;then\;a\;=\;1\;$

# %%
def P(x):
    return(opemat(x*x+1,'esfs'))

# %%
P(P(P(x)))
# Out:
#  8      6      4      2
# x  + 4⋅x  + 8⋅x  + 8⋅x  + 5

# %%
P(35)
# Out:
# 1226

# %% [markdown]
#  <img src="https://github.com/aldotb/Solve-Academic-Algebra-Math-Problems-whit-Python-and-Sympy/blob/main/images/linep.png?raw=1" alt="ml" style="width : 100%;"/>

# %%
from  Libaldomath  import *
# this cell will be initializing your variables,get help run helplib

# %% [markdown]
#  <img src="https://github.com/aldotb/Solve-Academic-Algebra-Math-Problems-whit-Python-and-Sympy/blob/main/images/p48.png?raw=1" alt="ml" style="width : 100%;"/>

# %% [markdown]
#  <img src="https://github.com/aldotb/Solve-Academic-Algebra-Math-Problems-whit-Python-and-Sympy/blob/main/images/lines.png?raw=1" alt="ml" style="width : 100%;"/>

# %% [markdown]
#  <img src="https://github.com/aldotb/Solve-Academic-Algebra-Math-Problems-whit-Python-and-Sympy/blob/main/images/p48a.png?raw=1" alt="ml" style="width : 50%;"/>

# %%
a=rpow(3*x);b=rpow(x+2)

# %%
e1=expand(kpow(a+b,2));e1 #pow a+b to 2
# Out:
#           _______
# 2⋅√3⋅√x⋅╲╱ x + 2  + 4⋅x + 2

# %%
e2=e1/2;e2 #divide by 2
# Out:
#         _______
# √3⋅√x⋅╲╱ x + 2  + 2⋅x + 1

# %%
e3=e2-1;e3 #Add -1 and get tha same eq from question
# Out:
#         _______
# √3⋅√x⋅╲╱ x + 2  + 2⋅x

# %%
# creatinf func whit the same step
def f(y):
    return(kpow(y,2)/2-1)

# %%
f(x) # whi x
# Out:
#  2
# x
# ── - 1
# 2

# %%
a+b # a+b ?
# Out:
#           _______
# √3⋅√x + ╲╱ x + 2

# %%
simplify(expand(f(a+b))) # test the func ok
# Out:
#         _______
# √3⋅√x⋅╲╱ x + 2  + 2⋅x

# %% [markdown]
#  <img src="https://github.com/aldotb/Solve-Academic-Algebra-Math-Problems-whit-Python-and-Sympy/blob/main/images/p48b.png?raw=1" alt="ml" style="width : 50%;"/>

# %%
eq3=factor(expand(f(x)-f(x-1)+f(x+1)));eq3
# Out:
#  2
# x  + 4⋅x - 2
# ────────────
#      2

# %%
g,G=symbols('g G')

# %% [markdown]
#  <img src="https://github.com/aldotb/Solve-Academic-Algebra-Math-Problems-whit-Python-and-Sympy/blob/main/images/p48b.png?raw=1" alt="ml" style="width : 50%;"/>

# %%
P=polyclass(eq3/kpow(x+2,2),(G-6)/(2*G));P.Q
# Out:
# (x**2 + 4*x - 2)/(2*(x + 2)**2)=(G - 6)/(2*G)

# %%
eq4=expand(numer(P.q1)*denom(P.q2));eq4
# Out:
#      2
# 2⋅G⋅x  + 8⋅G⋅x - 4⋅G

# %%
eq5=expand(numer(P.q2)*denom(P.q1));eq5
# Out:
#      2                     2
# 2⋅G⋅x  + 8⋅G⋅x + 8⋅G - 12⋅x  - 48⋅x - 48

# %%
factor(csolve((eq4-eq5)/12,G))
# Out:
#        2
# (x + 2)

# %%
def g(x):
    return(kpow(x+2,2))

# %% [markdown]
#  <img src="https://github.com/aldotb/Solve-Academic-Algebra-Math-Problems-whit-Python-and-Sympy/blob/main/images/p48c.png?raw=1" alt="ml" style="width : 50%;"/>

# %%
def M(x):
    return( 2*( simple_m(rpow(x)  ,'O') )-1)

# %%
M(g(x))
# Out:
# 2⋅x + 3

# %%
sE(['M(x)=',M(x)])
# Out:
# $\displaystyle M(x)=\;2 \sqrt{x} - 1\;$

# %% [markdown]
#  <img src="https://github.com/aldotb/Solve-Academic-Algebra-Math-Problems-whit-Python-and-Sympy/blob/main/images/linep.png?raw=1" alt="ml" style="width : 100%;"/>

# %%
from  Libaldomath  import *
# this cell will be initializing your variables,get help run helplib

# %% [markdown]
#  <img src="https://github.com/aldotb/Solve-Academic-Algebra-Math-Problems-whit-Python-and-Sympy/blob/main/images/p49.png?raw=1" alt="ml" style="width : 100%;"/>

# %% [markdown]
#  <img src="https://github.com/aldotb/Solve-Academic-Algebra-Math-Problems-whit-Python-and-Sympy/blob/main/images/lines.png?raw=1" alt="ml" style="width : 100%;"/>

# %%
x,B,a,b,n=symbols('x B a b n')

# %%
def P(x):
    return(simplify(factor(a*x+b)))

# %% [markdown]
#  <img src="https://github.com/aldotb/Solve-Academic-Algebra-Math-Problems-whit-Python-and-Sympy/blob/main/images/p49.png?raw=1" alt="ml" style="width : 100%;"/>

# %%
B1= (-b*(kpow(a,n)-1))/(kpow(a,n)*(a-1));B1
# Out:
#   -n   ⎛ n    ⎞
# -a  ⋅b⋅⎝a  - 1⎠
# ────────────────
#      a - 1

# %% [markdown]
#  <img src="https://github.com/aldotb/Solve-Academic-Algebra-Math-Problems-whit-Python-and-Sympy/blob/main/images/p49.png?raw=1" alt="ml" style="width : 100%;"/>

# %%
P(B1)
# Out:
#  -n   ⎛     n⎞
# a  ⋅b⋅⎝a - a ⎠
# ──────────────
#     a - 1

# %%
P(P(B1))
# Out:
#  -n   ⎛ 2    n⎞
# a  ⋅b⋅⎝a  - a ⎠
# ───────────────
#      a - 1

# %%
P(P(P(B1)))
# Out:
#  -n   ⎛ 3    n⎞
# a  ⋅b⋅⎝a  - a ⎠
# ───────────────
#      a - 1

# %%
def Pn(x):
    return(a**-n*b*(a**x-a**n)/(a-1))

# %%
Pn(x)
# Out:
#  -n   ⎛   n    x⎞
# a  ⋅b⋅⎝- a  + a ⎠
# ─────────────────
#       a - 1

# %%
show_res(Pn(n),'P(P(P....P(B)...))')
# Out:
# $\displaystyle P(P(P....P(B)...)) =0$
