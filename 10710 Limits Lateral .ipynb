# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %%
from  libaldomath  import *

# %% [markdown]
# ![image.png](attachment:0bbc56b6-6236-45f3-bc5e-6f39062113e4.png)

# %% [markdown]
# ![image.png](attachment:8bd895b7-0cd2-4f0a-9639-485a2209d1b8.png)

# %%
P1=MyEq(x*x+3,'P1',var=x)
P2=MyEq(x+1,'P2',var=x)
# Out:
# $\displaystyle P1 =x^{2} + 3$
# $\displaystyle P2 =x + 1$

# %%
P1.limit(1,'-')
# Out:
# 4

# %%
P2.limit(1,'+')
# Out:
# 2

# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %%
from  libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:ae4d3db6-49a5-43b0-88c0-dccaa881f671.png)

# %% [markdown]
# ![image.png](attachment:8bd895b7-0cd2-4f0a-9639-485a2209d1b8.png)

# %%
P1=MyEq(x*x,'P1',var=x)
P2=MyEq(8-2*x,'P2',var=x)
# Out:
# $\displaystyle P1 =x^{2}$
# $\displaystyle P2 =8 - 2 x$

# %%
P1.limit(2,'-')
# Out:
# 4

# %%
P2.limit(2,'+')
# Out:
# 4

# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %%
from  libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:fd5f69ba-12e6-455f-9ed9-a93a649c13c1.png)

# %% [markdown]
# ![image.png](attachment:8bd895b7-0cd2-4f0a-9639-485a2209d1b8.png)

# %%
P=MyEq(x*rpow(1/(4*x*x)-16),'P',var=x)
# Out:
# $\displaystyle P =x \sqrt{-16 + \frac{1}{4 x^{2}}}$

# %%
P1.limit(0,'-')
# Out:
# 0

# %%
P1.limit(0,'+')
# Out:
# 0

# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %%
from  libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:09b96037-aefa-4b5d-b98c-a6ecd69a2779.png)

# %% [markdown]
# ![image.png](attachment:8bd895b7-0cd2-4f0a-9639-485a2209d1b8.png)

# %%
# create figurative max integer function 
m1=maxint("x-1")
m2=maxint("x")

# %%
P1=MyEq((maxint("x-1")-x)/rpow(x*x-maxint("x")),'P1',var=x)
# Out:
# $\displaystyle P1 =\frac{- x + ǁx-1ǁ}{\sqrt{x^{2} - ǁxǁ}}$

# %% [markdown]
# ![image.png](attachment:11d3a9c0-821e-4eb2-872b-b530fd4810df.png)

# %%
P1.subsubs(m1,m2-1)
# Out:
# $\displaystyle P1 =\frac{- x + ǁxǁ - 1}{\sqrt{x^{2} - ǁxǁ}}$

# %% [markdown]
# ![image.png](attachment:8592c109-05f8-4fc9-80ba-5902bf9006f0.png)

# %%
P1.subsubs(m2,-4)
# Out:
# $\displaystyle P1 =\frac{- x - 5}{\sqrt{x^{2} + 4}}$

# %%
P1.limit(-3,'+')
# Out:
# -2⋅√13
# ───────
#    13

# %%
P2=MyEq((m1-x)/rpow(x*x-m2),'P2',var=x)
# Out:
# $\displaystyle P2 =\frac{- x + ǁx-1ǁ}{\sqrt{x^{2} - ǁxǁ}}$

# %%
P2.subsubs(m1,m2-1)
# Out:
# $\displaystyle P2 =\frac{- x + ǁxǁ - 1}{\sqrt{x^{2} - ǁxǁ}}$

# %% [markdown]
# ![image.png](attachment:3ffabae5-45f4-4374-b293-5963d2d1d96b.png)

# %%
P2.subsubs(m2,-3)
# Out:
# $\displaystyle P2 =\frac{- x - 4}{\sqrt{x^{2} + 3}}$

# %%
P2.limit(-3,'-')
# Out:
# -√3
# ────
#  6

# %% [markdown]
# ![image.png](attachment:39694a9e-7607-4b61-87ab-8360a8c493b5.png)

# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %%
from  libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:bfed1256-ccd0-430e-b223-1a1f84851db4.png)

# %% [markdown]
# ![image.png](attachment:8bd895b7-0cd2-4f0a-9639-485a2209d1b8.png)

# %%
# create figurative max integer function 
mm=maxint("(2x+1)/(x-1)")
m1=maxint("3/(x-1)")

# %%
P=MyEq((x*x*mm-10*x)/(x**3-11*x*x+38*x-40),'P',var=x)
# Out:
# $\displaystyle P =\frac{x^{2} ǁ(2x+1)/(x-1)ǁ - 10 x}{x^{3} - 11 x^{2} + 38 x - 40}$

# %% [markdown]
# ![image.png](attachment:9d1419a0-f90f-460e-b13a-b808eae19216.png)

# %%
mm=2+m1

# %%
P=MyEq((x*x*mm-10*x)/(x**3-11*x*x+38*x-40),'P',var=x)
# Out:
# $\displaystyle P =\frac{x^{2} \left(ǁ3/(x-1)ǁ + 2\right) - 10 x}{x^{3} - 11 x^{2} + 38 x - 40}$

# %% [markdown]
# ![image.png](attachment:fc31f4d6-c2e5-4573-8475-342ca13f0e0d.png)

# %%
P.subsubs(m1,3)
# Out:
# $\displaystyle P =\frac{5 x^{2} - 10 x}{x^{3} - 11 x^{2} + 38 x - 40}$

# %%
P.limit(2)
# Out:
# 5/3

# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %%
from  libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:ca0bd66b-f17c-4ed2-a62b-2da2009bdbe1.png)

# %% [markdown]
# ![image.png](attachment:8bd895b7-0cd2-4f0a-9639-485a2209d1b8.png)

# %%
m3=maxint("3x")

# %%
P=MyEq(rpow(abs(x)+m3),'P',var=x)
# Out:
# $\displaystyle P =\sqrt{ǁ3xǁ + \left|{x}\right|}$

# %% [markdown]
# ![image.png](attachment:f43c5071-9614-42a1-ba40-4b4a3ab98842.png)

# %%
P.subsubs(m3,6)
# Out:
# $\displaystyle P =\sqrt{\left|{x}\right| + 6}$

# %%
P.limit(cfrac(7,3),'+')
# Out:
#     _________
#    ╱ │7│
#   ╱  │─│ + 6
# ╲╱   │3│

# %% [markdown]
# ![image.png](attachment:18e8043b-f51d-41f1-9fc8-4fdd9d5b271e.png)

# %%
P=MyEq(rpow(abs(x)+m3),'P',var=x)
# Out:
# $\displaystyle P =\sqrt{ǁ3xǁ + \left|{x}\right|}$

# %%
P.subsubs(m3,7)
# Out:
# $\displaystyle P =\sqrt{\left|{x}\right| + 7}$

# %%
P.limit(cfrac(7,3),'-')
# Out:
#     _________
#    ╱ │7│
#   ╱  │─│ + 7
# ╲╱   │3│

# %% [markdown]
# ![image.png](attachment:ea6f0fd0-14cd-4777-8c44-552aeaec49ee.png)

# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)
