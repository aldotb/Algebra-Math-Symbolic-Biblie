# %% [markdown]
# * here we will use...:
#     * MyEq(),MyEqEq or MQ()
#     * ppow() rpow()
#     * crossMul(), Add(), Substrac(),  Mul(), Pow() a Rpow()}
#     * to manage exponencial funtions  we well use:
#         * mulexpo()
#         * primegfactors()
#         * joinbase()
#         * pow2powpow()
#     and of course the nessesary...:
#     * solve()
#     * solveSys()

# %% [markdown]
# ![image.png](attachment:7b428bb1-4d3b-438c-af57-447beed34dad.png)

# %%
from Libaldomath import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:20e0cd2a-95b2-4f69-8c93-5299e944d921.png)

# %% [markdown]
# ![image.png](attachment:a4ca75cc-2730-4dbd-b101-a429064d1b26.png)

# %%
Q=MyEq(2*x**4+a*x**3+b*x*x+27*x-10,'Q')
q=MyEq(x*x-6*x+5,'q')
# Out:
# $\displaystyle Q =a x^{3} + b x^{2} + 2 x^{4} + 27 x - 10$
# $\displaystyle q =x^{2} - 6 x + 5$

# %%
rem=Q.rem(q,'rem')
# Out:
# $\displaystyle rem =31 a x - 30 a + 6 b x - 5 b + 339 x - 320$

# %%
vec=rem.coef_list(x)
vec
# Out:
# [31⋅a + 6⋅b + 339, -30⋅a - 5⋅b - 320]

# %%
a,b=simplesolve(vec)
# Out:
# $\displaystyle a =-9$
# $\displaystyle b =-10$

# %% [markdown]
# ![image.png](attachment:7b428bb1-4d3b-438c-af57-447beed34dad.png)

# %%
from Libaldomath import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:20e0cd2a-95b2-4f69-8c93-5299e944d921.png)

# %% [markdown]
# ![image.png](attachment:232daf59-9ec8-48ea-9ba2-bb2b9569d8a4.png)

# %%
q1=MyEq(a*x+b,'q1')
# Out:
# $\displaystyle q1 =a x + b$

# %%
P=MyEq(q1*(2*x**4-3),'P')
# Out:
# $\displaystyle P =\left(2 x^{4} - 3\right) \left(a x + b\right)$

# %%
Q1=MQ(P.rem(x+1),7)
Q2=MQ(P.rem(x-2),232)
# Out:
# $\displaystyle a - b = 7$
# $\displaystyle 58 a + 29 b = 232$

# %%
a,b = simplesolve(Q1,Q2)
# Out:
# $\displaystyle a =5$
# $\displaystyle b =-2$

# %%
P.set(a,b)
# Out:
# $\displaystyle P =\left(2 x^{4} - 3\right) \left(a x + b\right)$

# %% [markdown]
# ![image.png](attachment:7b428bb1-4d3b-438c-af57-447beed34dad.png)

# %%
from Libaldomath import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:20e0cd2a-95b2-4f69-8c93-5299e944d921.png)

# %% [markdown]
# ![image.png](attachment:c7afcf2a-2ed2-40a4-829e-6a7fa48e0722.png)

# %%
P=MyEq(2*x**5+x**4+a*x**2+b*x+c,'P',var=x)
# Out:
# $\displaystyle P =a x^{2} + b x + c + 2 x^{5} + x^{4}$

# %%
R=P.rem(x**4-1,'R')
# Out:
# $\displaystyle R =a x^{2} + b x + c + 2 x + 1$

# %%
R.coef_list()
# Out:
# [a, b + 2, c + 1]

# %%
a=0
b=-2
c=-1

# %%
(a+b)/(a-b)
# Out:
# -1.0

# %% [markdown]
# ![image.png](attachment:7b428bb1-4d3b-438c-af57-447beed34dad.png)

# %%
from Libaldomath import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:20e0cd2a-95b2-4f69-8c93-5299e944d921.png)

# %% [markdown]
# ![image.png](attachment:53ebaed8-4b43-48da-ae2a-3d285580b714.png)

# %%
P=MyEq(2*x**4+x**3+m*x*x+6*x+n,'P',var=x)
# Out:
# $\displaystyle P =m x^{2} + n + 2 x^{4} + x^{3} + 6 x$

# %%
R=P.rem(2*x*x-x+3,'R')
# Out:
# $\displaystyle R =\frac{m x}{2} - \frac{3 m}{2} + n + 2 x + 3$

# %%
mm=R.coef_list(x)
mm
# Out:
# ⎡m        3⋅m        ⎤
# ⎢─ + 2, - ─── + n + 3⎥
# ⎣2         2         ⎦

# %%
m,n=simplesolve(R.coef_list(x))
# Out:
# $\displaystyle m =-4$
# $\displaystyle n =-9$

# %% [markdown]
# ![image.png](attachment:7b428bb1-4d3b-438c-af57-447beed34dad.png)

# %%
from Libaldomath import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:20e0cd2a-95b2-4f69-8c93-5299e944d921.png)

# %% [markdown]
# ![image.png](attachment:0f178212-31ff-4fc2-8118-6ead92510a68.png)

# %%
Q=MyEq(x**4+(a-3)*x*x+b+3,'Q',var=x)
# Out:
# $\displaystyle Q =b + x^{4} + x^{2} \left(a - 3\right) + 3$

# %%
q=MyEq(x*x+x+1,'q',var=x)
# Out:
# $\displaystyle q =x^{2} + x + 1$

# %%
R=Q.rem(q,'R')
# Out:
# $\displaystyle R =- a x - a + b + 4 x + 6$

# %%
a,b=simplesolve(R.coef_list(x))
# Out:
# $\displaystyle a =4$
# $\displaystyle b =-2$

# %%
a+b
# Out:
# 2

# %% [markdown]
# ![image.png](attachment:7b428bb1-4d3b-438c-af57-447beed34dad.png)

# %%
from Libaldomath import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:20e0cd2a-95b2-4f69-8c93-5299e944d921.png)

# %% [markdown]
# ![image.png](attachment:ef8d4a51-76ce-441c-bfb7-36ff882543a0.png)

# %%
P=MyEq(x**4+x**3-11*x*x+m*x+n,'P',var=x)
q1=MyEq(x-3,'q1',var=x)
q2=MyEq(x+3,'q2',var=x)
# Out:
# $\displaystyle P =m x + n + x^{4} + x^{3} - 11 x^{2}$
# $\displaystyle q1 =x - 3$
# $\displaystyle q2 =x + 3$

# %%
R=P.rem(x*x-9,'R')
# Out:
# $\displaystyle R =m x + n + 9 x - 18$

# %%
m,n=simplesolve(R.coef_list(x))
# Out:
# $\displaystyle m =-9$
# $\displaystyle n =18$

# %%
m+n
# Out:
# 9
