# %% [markdown]
# ## Finding Ration , Varation and Differential value

# %%
from  libaldomath  import *
from lib_MyIntegral import *

# %% [markdown]
# ![image.png](attachment:f779fa77-c353-43ee-ba21-aa51f9b9562f.png)

# %%
dx=MyDiff(-k*t,'dx',var=t)
# Out:
# $\displaystyle dx =- k t d_t$

# %%
x=dx.integral()
# Out:
# $\displaystyle x=\int \left(- k t\right)\, dt$

# %%
x.doit()
# Out:
# $\displaystyle x=C_{1} - \frac{k t^{2}}{2}$

# %%
C1,k=simplesolve(x(0)-1,x(10)-0.5)
# Out:
# $\displaystyle C1 =1.0$
# $\displaystyle k =0.01$

# %%
x.set(C1=1)
# Out:
# $\displaystyle x=- \frac{k t^{2}}{2} + 1$

# %%
x.set(k=0.01)
# Out:
# $\displaystyle x=1 - 0.005 t^{2}$

# %%
x.Substrac(0.1)
# Out:
# $\displaystyle x=0.9 - 0.005 t^{2}$

# %%
t=x.solve(t,'signo')
# Out:
# $\displaystyle t =13.4164078649987$

# %%
from lib_MyIntegral import *

# %% [markdown]
# ![image.png](attachment:45d440e2-0613-4394-b4f3-7a5e6bc1875d.png)

# %%
dx=MyDiff(-k*t,'dx')
# Out:
# $\displaystyle dx =- k t d_t$

# %%
x=dx.integral()
# Out:
# $\displaystyle x=\int \left(- k t\right)\, dt$

# %%
x.doit()
# Out:
# $\displaystyle x=C_{1} - \frac{k t^{2}}{2}$

# %%
C1,k=simplesolve(x(0)-100,x(200)-55,'MyEq')
# Out:
# $\displaystyle C1 =100$
# $\displaystyle k =\frac{9}{4000}$

# %%
x.set(C1=C1,k=k)
# Out:
# $\displaystyle x=100 - \frac{9 t^{2}}{8000}$

# %%
x.Substrac(50)
# Out:
# $\displaystyle x=50 - \frac{9 t^{2}}{8000}$

# %%
t=x.solve(t,'signo','float')
# Out:
# $\displaystyle t =210.818510677892$

# %%
from  libaldomath  import *
from lib_MyIntegral import *

# %% [markdown]
# ![image.png](attachment:75ee4819-af6b-495e-9a19-0750a3bb8a40.png)

# %% [markdown]
# ![image.png](attachment:ad704b8a-326f-478f-a0a1-e15ee372e40a.png)

# %%
r=3*h/7

# %%
Q=MQ(V,pi*r*r*h/3)
# Out:
# $\displaystyle V = \frac{3 \pi h^{3}}{49}$

# %%
Q.diff(V,h)
# Out:
# $\displaystyle dV = \frac{9 \pi dh h^{2}}{49}$

# %%
Q.set(dV=3,h=2)
# Out:
# $\displaystyle 3 = \frac{36 \pi dh}{49}$

# %%
dh=Q.solve(dh)
# Out:
# $\displaystyle dh =\frac{49}{12 \pi}$

# %%
dh.float
# Out:
# 1.299765368583812

# %% [markdown]
# ![image.png](attachment:de2badc9-b7d7-44b1-b9b2-1f59856a5ba9.png)

# %%
from  libaldomath  import *
from lib_MyIntegral import *

# %% [markdown]
# ![image.png](attachment:b9ebe0c7-2988-4fed-8831-af30ac4ad001.png)

# %% [markdown]
# ![image.png](attachment:88ead5a0-b0da-48ec-80ce-bd074253dd42.png)

# %%
Q=MQ(tan(alpha),18/x,var=t)
# Out:
# $\displaystyle \tan{\left(\alpha \right)} = \frac{18}{x}$

# %%
Q.diff(alpha,x)
# Out:
# $\displaystyle dα \left(\tan^{2}{\left(\alpha \right)} + 1\right) = - \frac{18 dx}{x^{2}}$

# %%
str(alpha)
# Out:
# 'alpha'

# %%
alpha.str
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 alpha.str
#
# AttributeError: 'Symbol' object has no attribute 'str'

# %%
Q.subsubs('dx',1.8)
# Out:
# $\displaystyle dα \left(\tan^{2}{\left(\alpha \right)} + 1\right) = - \frac{32.4}{x^{2}}$

# %%
Q.set(x=24)
# Out:
# $\displaystyle dα \left(\tan^{2}{\left(\alpha \right)} + 1\right) = -0.05625$

# %%
Q.set(alpha=acos(24/30))
# Out:
# $\displaystyle 1.5625 dα = -0.05625$

# %%
da='d'+alphaname(alpha)

# %%
da=Q.solve(da)
# Out:
# $\displaystyle dα =-0.036$

# %% [markdown]
# ![image.png](attachment:9fda1fe8-9a6a-4a44-8e85-61f928426c44.png)

# %%
from  libaldomath  import *
from lib_MyIntegral import *

# %% [markdown]
# ![image.png](attachment:44783643-9e2f-4640-9522-28c12e86af99.png)

# %% [markdown]
# ![image.png](attachment:ceb5b7fa-45a8-4c9f-ba1d-a4160923218d.png)

# %%
Q=MQ(A,b*h/2,var=t)
# Out:
# $\displaystyle A = \frac{b h}{2}$

# %%
Q.diff(A,h,b)
# Out:
# $\displaystyle dA = \frac{b dh}{2} + \frac{db h}{2}$

# %% [markdown]
# ![image.png](attachment:bb19f70f-1379-4e58-877d-e259528e458f.png)

# %%
Q.set(dh=-2,dA=-3,b=15,h=20)
# Out:
# $\displaystyle -3 = 10 db - 15$

# %%
db=Q.solve('db')
# Out:
# $\displaystyle db =\frac{6}{5}$

# %% [markdown]
#  <img src="imgdata/rcd3c.png" alt="ml" style="width : 68%;"/>

# %%
from  libaldomath  import *
from lib_MyIntegral import *

# %% [markdown]
# ![image.png](attachment:0184cd6d-e344-4151-97be-3237070e1896.png)

# %% [markdown]
# ![image.png](attachment:df917eb6-0b26-489b-b3e9-63e1a3e7067d.png)

# %%
Q=MQ(z**2,x*x+y*y,var=t)
# Out:
# $\displaystyle z^{2} = x^{2} + y^{2}$

# %%
Q.diff(z,x,y)
# Out:
# $\displaystyle 2 dz z = 2 dx x + 2 dy y$

# %%
Q.set(x=150,y=200,z=750,dx=-450)
# Out:
# $\displaystyle 1500 dz = 300 dx + 400 dy$

# %%
Q.subsubs('dx',-450)
# Out:
# $\displaystyle 1500 dz = 400 dy - 135000$

# %%
Q.subsubs('dy',-600)
# Out:
# $\displaystyle 1500 dz = -375000$

# %%
dz=Q.solve('dz')
# Out:
# $\displaystyle dz =-250$
