# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %%
from  libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:29c96334-be39-4de9-b52b-c66010e07a1e.png)

# %%
P1=MyEq(2*x*x+3*x+5,'P1',var=x)
P2=MyEq(3*x*x-23*x+1,'P2',var=x)
P=MyEq(P1/P2,'P',var=x)
# Out:
# $\displaystyle P1 =2 x^{2} + 3 x + 5$
# $\displaystyle P2 =3 x^{2} - 23 x + 1$
# $\displaystyle P =\frac{2 x^{2} + 3 x + 5}{3 x^{2} - 23 x + 1}$

# %%
#test
P(oo)
# Out:
# nan

# %%
P1.Div(x*x)
P1.expand()
# Out:
# $\displaystyle P1 =\frac{2 x^{2} + 3 x + 5}{x^{2}}$
# $\displaystyle P1 =2 + \frac{3}{x} + \frac{5}{x^{2}}$

# %%
P2.Div(x*x)
P2.expand()
# Out:
# $\displaystyle P2 =\frac{3 x^{2} - 23 x + 1}{x^{2}}$
# $\displaystyle P2 =3 - \frac{23}{x} + \frac{1}{x^{2}}$

# %%
P=MyEq(P1/P2,'P',var=x)
# Out:
# $\displaystyle P =\frac{2 + \frac{3}{x} + \frac{5}{x^{2}}}{3 - \frac{23}{x} + \frac{1}{x^{2}}}$

# %%
P=MyEq(P1/P2,'P',var=x)
# Out:
# $\displaystyle P =\frac{2 + \frac{3}{x} + \frac{5}{x^{2}}}{3 - \frac{23}{x} + \frac{1}{x^{2}}}$

# %%
#text
P(oo)
# Out:
# 2/3

# %%
P.limit(oo)
# Out:
# 2/3

# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %%
from  libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:84efa44b-c412-49b0-93b5-8678105bd579.png)

# %%
P1=MyEq(2*x*x-3*x+4,'P1',var=x)
P2=MyEq(rpow(x**4+1),'P2',var=x)
P=MyEq(P1/P2,'P',var=x)
# Out:
# $\displaystyle P1 =2 x^{2} - 3 x + 4$
# $\displaystyle P2 =\sqrt{x^{4} + 1}$
# $\displaystyle P =\frac{2 x^{2} - 3 x + 4}{\sqrt{x^{4} + 1}}$

# %%
#text
P(oo)
# Out:
# nan

# %%
P1.Div(x*x)
P1.expand()
# Out:
# $\displaystyle P1 =\frac{2 x^{2} - 3 x + 4}{x^{2}}$
# $\displaystyle P1 =2 - \frac{3}{x} + \frac{4}{x^{2}}$

# %%
P2.Div(x*x)
# Out:
# $\displaystyle P2 =\frac{\sqrt{x^{4} + 1}}{x^{2}}$

# %%
P2.Pow(2)
# Out:
# $\displaystyle P2 =\frac{x^{4} + 1}{x^{4}}$

# %%
P2.expand()
# Out:
# $\displaystyle P2 =1 + \frac{1}{x^{4}}$

# %%
P2.Rpow(2)
# Out:
# $\displaystyle P2 =\sqrt{1 + \frac{1}{x^{4}}}$

# %%
P=MyEq(P1/P2,'P',var=x)
# Out:
# $\displaystyle P =\frac{2 - \frac{3}{x} + \frac{4}{x^{2}}}{\sqrt{1 + \frac{1}{x^{4}}}}$

# %%
P(oo)
# Out:
# 2

# %%
P=MyEq(P1/P2,'P',var=x)
P.limit(oo)
# Out:
# $\displaystyle P =\frac{2 - \frac{3}{x} + \frac{4}{x^{2}}}{\sqrt{1 + \frac{1}{x^{4}}}}$
# 2

# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %%
from  libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:10160cd6-4e37-4d00-a11a-50beb7748b7e.png)

# %%
P1=MyEq(rpow(x*x+4),'P1',var=x)
P2=MyEq(x+7,'P2',var=x)
P=MyEq(P1/P2,'P',var=x)
# Out:
# $\displaystyle P1 =\sqrt{x^{2} + 4}$
# $\displaystyle P2 =x + 7$
# $\displaystyle P =\frac{\sqrt{x^{2} + 4}}{x + 7}$

# %%
P1.Div(-sqrt(x*x))
P2.Div(x)
# Out:
# $\displaystyle P1 =- \frac{\sqrt{x^{2} + 4}}{\sqrt{x^{2}}}$
# $\displaystyle P2 =\frac{x + 7}{x}$

# %%
P1.Pow(2)
# Out:
# $\displaystyle P1 =\frac{x^{2} + 4}{x^{2}}$

# %%
P1.Rpow(2)
# Out:
# $\displaystyle P1 =\sqrt{\frac{x^{2} + 4}{x^{2}}}$

# %%
P1.Mul(-1)
# Out:
# $\displaystyle P1 =- \sqrt{\frac{x^{2} + 4}{x^{2}}}$

# %%
P1.expand()
# Out:
# $\displaystyle P1 =- \sqrt{1 + \frac{4}{x^{2}}}$

# %%
P2.expand()
# Out:
# $\displaystyle P2 =1 + \frac{7}{x}$

# %%
P.limit(oo)
# Out:
# 1

# %%
P=MyEq(P1/P2,'P',var=x)
P.limit(oo)
# Out:
# $\displaystyle P =- \frac{\sqrt{1 + \frac{4}{x^{2}}}}{1 + \frac{7}{x}}$
# -1

# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %%
from  libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:ddb686a0-1f9e-4bd7-94a7-7cfdc7c8c65f.png)

# %%
P1=MyEq(rpow(x*x-5*x+6)+x,'P1',var=x)
P=MyEq(rpow(x*x-5*x+6)-x,'P',var=x)
# Out:
# $\displaystyle P1 =x + \sqrt{x^{2} - 5 x + 6}$
# $\displaystyle P =- x + \sqrt{x^{2} - 5 x + 6}$

# %%
P.Mul(P1)
# Out:
# $\displaystyle P =\left(- x + \sqrt{x^{2} - 5 x + 6}\right) \left(x + \sqrt{x^{2} - 5 x + 6}\right)$

# %%
P.expand()
# Out:
# $\displaystyle P =6 - 5 x$

# %%
P.Div(P1)
# Out:
# $\displaystyle P =\frac{6 - 5 x}{x + \sqrt{x^{2} - 5 x + 6}}$

# %%
p1,p2=fraction(P())

# %%
p1=p1/x
p1=expand(p1)
p1
# Out:
#      6
# -5 + ─
#      x

# %%
p2=p2/x;p2
# Out:
#        ______________
#       ╱  2
# x + ╲╱  x  - 5⋅x + 6
# ─────────────────────
#           x

# %%
p2=expand(p2);p2
# Out:
#        ______________
#       ╱  2
#     ╲╱  x  - 5⋅x + 6
# 1 + ─────────────────
#             x

# %%
# take note of this math supossed 
print(p2)
# Out:
# 1 + sqrt(x**2 - 5*x + 6)/x

# %%
p2=1+sqrt(1+5/x+6/(x*x))

# %%
p2
# Out:
#      ____________
#     ╱     5   6
#    ╱  1 + ─ + ──  + 1
#   ╱       x    2
# ╲╱            x

# %%
P=MyEq(p1/p2,'P',var=x)
# Out:
# $\displaystyle P =\frac{-5 + \frac{6}{x}}{\sqrt{1 + \frac{5}{x} + \frac{6}{x^{2}}} + 1}$

# %%
P.limit(oo)
# Out:
# -5/2

# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %%
from  libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:0a5ce400-9d4f-485c-b948-ea8734b04ccc.png))

# %%
p1=rpow(x+rpow(x+rpow(x+2)))
p2=rpow(x+2)

P=MyEq(p1/p2,'P',var=x)
# Out:
# $\displaystyle P =\frac{\sqrt{x + \sqrt{x + \sqrt{x + 2}}}}{\sqrt{x + 2}}$

# %%
P.limit(oo)
# Out:
# 1
