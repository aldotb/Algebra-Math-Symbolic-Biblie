# %% [markdown]
# ![image.png](attachment:fe4d89c2-2fe0-4968-89ec-eacf08018c0b.png)

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)

# %% [markdown]
# ![image.png](attachment:14a3cf97-5117-4ba9-b9ce-bdb34bee0ebe.png)

# %% [markdown]
# ![image.png](attachment:9472e8f6-51b3-4232-a728-ca2228f19b34.png)

# %% [markdown]
# ![image.png](attachment:14a3cf97-5117-4ba9-b9ce-bdb34bee0ebe.png)

# %% [markdown]
# ![image.png](attachment:5a90b90a-efc1-4756-8a52-9fe376791887.png)

# %%
from  Libaldomath  import *
# this cell will be initializing your variables,get help run helplib

# %% [markdown]
# ![image.png](attachment:a9796cb6-a0a3-42db-81ba-fa0ff6fa2e40.png)

# %%
Q=MyEqEq(4*x+1,'>',x+5)
# Out:
# $\displaystyle 4 x + 1 > x + 5$

# %%
Q.Add(-x-1)
# Out:
# $\displaystyle 3 x > 4$

# %%
Qr=Q.isolve('Qr')
# Out:
# $\displaystyle Qr =\left(\frac{4}{3}, \infty\right)$

# %% [markdown]
# ![image.png](attachment:14a3cf97-5117-4ba9-b9ce-bdb34bee0ebe.png)

# %% [markdown]
# ![image.png](attachment:66e08457-b9e9-4014-83c7-626f2c04a9b4.png)

# %% [markdown]
# ![image.png](attachment:ade683d4-533e-4b3f-888e-fda8990326e0.png)

# %%
from  Libaldomath  import *
# this cell will be initializing your variables,get help run helplib

# %%
# nerd methode

# %%
Q=MQ(x/b+b/a,'>',x/a+a/b)
# Out:
# $\displaystyle \frac{x}{b} + \frac{b}{a} > \frac{a}{b} + \frac{x}{a}$

# %%
Q.Substrac(a/b+x/b)
# Out:
# $\displaystyle - \frac{a}{b} + \frac{b}{a} > - \frac{x}{b} + \frac{x}{a}$

# %%
Q.factor()
# Out:
# $\displaystyle - \frac{\left(a - b\right) \left(a + b\right)}{a b} > - \frac{x \left(a - b\right)}{a b}$

# %%
Q.simplify()
# Out:
# $\displaystyle a + b > x$

# %% [markdown]
# ![image.png](attachment:14a3cf97-5117-4ba9-b9ce-bdb34bee0ebe.png)

# %% [markdown]
# ![image.png](attachment:09e94295-4016-4104-8d3c-bb328172cf13.png)

# %%
from  Libaldomath  import *
# this cell will be initializing your variables,get help run helplib

# %%
Q=MQ(3*a*(a+2)*x*x+3*(x+1),'>',x*(9*x+8*a))
# Out:
# $\displaystyle 3 a x^{2} \left(a + 2\right) + 3 x + 3 > x \left(8 a + 9 x\right)$

# %%
# nerd methode

# %%
Q.expand()
# Out:
# $\displaystyle 3 a^{2} x^{2} + 6 a x^{2} + 3 x + 3 > 8 a x + 9 x^{2}$

# %%
Q.all2L()
# Out:
# $\displaystyle 3 a^{2} x^{2} + 6 a x^{2} - 8 a x - 9 x^{2} + 3 x + 3 > 0$

# %%
Q.sortdegree(x)
# Out:
# $\displaystyle x^{2} \cdot \left(3 a^{2} + 6 a - 9\right) + x \left(3 - 8 a\right) + 3 > 0$

# %% [markdown]
# ![image.png](attachment:21712684-f812-4188-a0ec-3813ffd7009b.png)

# %%
Q2=MQ(3*a*a+6*a-9,'>',0,var=a)
# Out:
# $\displaystyle 3 a^{2} + 6 a - 9 > 0$

# %%
Q2.Div(3)
# Out:
# $\displaystyle a^{2} + 2 a - 3 > 0.0$

# %%
Q2.factor()
# Out:
# $\displaystyle \left(a - 1\right) \left(a + 3\right) > 0$

# %%
S1=Q2.isolve()
# Out:
# $\displaystyle \left(-\infty, -3\right) \cup \left(1, \infty\right)$

# %%
m1=solve_univariate_inequality(5*x>=3,x,relational=False)
m1
# Out:
# [3/5, ∞)

# %%
m2=solve_univariate_inequality(10>=5*x,x,relational=False)
m2
# Out:
# (-∞, 2]

# %%
m1 & m2
# Out:
# [3/5, 2]

# %%
str(mm)
# Out:
# 'Interval(3/5, oo)'

# %% [markdown]
# ![image.png](attachment:e2eca442-54fa-4846-97d8-6669ace8959f.png)

# %%
Q.s()
# Out:
# $\displaystyle x^{2} \cdot \left(3 a^{2} + 6 a - 9\right) + x \left(3 - 8 a\right) + 3 > 0$

# %%
A=3*a*a+6*a-9
B=3-8*a
C=3

# %%
Q3=MQ(B*B-4*A*C,'<',0,var=a)
# Out:
# $\displaystyle - 36 a^{2} - 72 a + \left(3 - 8 a\right)^{2} + 108 < 0$

# %%
Q3.expand()
# Out:
# $\displaystyle 28 a^{2} - 120 a + 117 < 0$

# %%
S2=Q3.isolve()
# Out:
# $\displaystyle \frac{3}{2} < a \wedge a < \frac{39}{14}$

# %% [markdown]
# ![image.png](attachment:7fd068e2-3d7a-4f0a-ab31-de38dd8e6b55.png)

# %%
S1 and S2
# Out:
#               39
# 3/2 < a ∧ a < ──
#               14

# %% [markdown]
# ![image.png](attachment:14a3cf97-5117-4ba9-b9ce-bdb34bee0ebe.png)

# %% [markdown]
# ![image.png](attachment:a6c5eb3d-40e7-422a-aae8-2e76c2c23070.png)

# %%
from  Libaldomath  import *
# this cell will be initializing your variables,get help run helplib

# %%
Q=MQ(((2*x+1)*(x*x+1))/((x+1)*(4*x*x+4*x+1)),'<=',(-2*x*(2*x+1)/((1+4*x+4*x*x)*(1+x))))
# Out:
# $\displaystyle \frac{\left(2 x + 1\right) \left(x^{2} + 1\right)}{\left(x + 1\right) \left(4 x^{2} + 4 x + 1\right)} ≤ - \frac{2 x \left(2 x + 1\right)}{\left(x + 1\right) \left(4 x^{2} + 4 x + 1\right)}$

# %%
Q.factor()
# Out:
# $\displaystyle \frac{x^{2} + 1}{\left(x + 1\right) \left(2 x + 1\right)} ≤ - \frac{2 x}{\left(x + 1\right) \left(2 x + 1\right)}$

# %%
Q.all2L()
# Out:
# $\displaystyle \frac{x + 1}{2 x + 1} ≤ 0$

# %%
Q.isolve()
# Out:
# $\displaystyle -1 \leq x \wedge x < - \frac{1}{2}$
# -1 ≤ x ∧ x < -1/2

# %% [markdown]
# ![image.png](attachment:699fb9e9-c335-443e-b343-7bebfff4836a.png)
