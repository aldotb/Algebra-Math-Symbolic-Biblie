# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %%
from  Libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %% [markdown]
# ![image.png](attachment:ca1ea927-cacd-4a22-bdb0-e4bfb24f09b3.png)

# %%
def Sf(n):
    kres= I**(4*n)+I**(-2*n)
    return kres

# %%
Sf(1)
# Out:
# 0

# %%
Sf(2)
# Out:
# 2

# %%
kres=0
for i in range(1,2003):
    kres=kres+Sf(i)
kres
# Out:
# 2002

# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %%
from  Libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %% [markdown]
# ![image.png](attachment:3446474b-7577-4274-814d-2f4c93305c4a.png)

# %%
z=MyEq(a+b*I,'z')
w=MyEq(c+d*I,'w')
# Out:
# $\displaystyle z =a + i b$
# $\displaystyle w =c + i d$

# %% [markdown]
# ![image.png](attachment:d7f14abd-91db-4c20-9069-c59a5013d013.png)

# %%
P1=MyEq(z+w,'P1')
# Out:
# $\displaystyle P1 =a + i b + c + i d$

# %%
P1.Div(z)
# Out:
# $\displaystyle P1 =\frac{a + i b + c + i d}{a + i b}$

# %%
P1.Pow(-1)
# Out:
# $\displaystyle P1 =\frac{a + i b}{a + i b + c + i d}$

# %%
P1.simplify_img()
# Out:
# $\displaystyle P1 =\frac{a + i b}{a + c + i \left(b + d\right)}$

# %%
F=a+c-(b+d)*I
P1.Div(a+c-(b+d)*I)
# Out:
# $\displaystyle P1 =\frac{a + i b}{\left(a + c - i \left(b + d\right)\right) \left(a + c + i \left(b + d\right)\right)}$

# %%
P1.expand()
# Out:
# $\displaystyle P1 =\frac{a}{a^{2} + 2 a c + b^{2} + 2 b d + c^{2} + d^{2}} + \frac{i b}{a^{2} + 2 a c + b^{2} + 2 b d + c^{2} + d^{2}}$

# %%
P1.factor()
# Out:
# $\displaystyle P1 =\frac{a + i b}{a^{2} + 2 a c + b^{2} + 2 b d + c^{2} + d^{2}}$

# %%
P1.Mul(F)
# Out:
# $\displaystyle P1 =\frac{\left(a + i b\right) \left(a + c - i \left(b + d\right)\right)}{a^{2} + 2 a c + b^{2} + 2 b d + c^{2} + d^{2}}$

# %%
P1.expand()
# Out:
# $\displaystyle P1 =\frac{a^{2}}{a^{2} + 2 a c + b^{2} + 2 b d + c^{2} + d^{2}} + \frac{a c}{a^{2} + 2 a c + b^{2} + 2 b d + c^{2} + d^{2}} - \frac{i a d}{a^{2} + 2 a c + b^{2} + 2 b d + c^{2} + d^{2}} + \frac{b^{2}}{a^{2} + 2 a c + b^{2} + 2 b d + c^{2} + d^{2}} + \frac{i b c}{a^{2} + 2 a c + b^{2} + 2 b d + c^{2} + d^{2}} + \frac{b d}{a^{2} + 2 a c + b^{2} + 2 b d + c^{2} + d^{2}}$

# %%
P1.factor()
# Out:
# $\displaystyle P1 =\frac{\left(a + i b\right) \left(a - i b + c - i d\right)}{a^{2} + 2 a c + b^{2} + 2 b d + c^{2} + d^{2}}$

# %%
P1d=P1.denom

# %%
P1n=P1.numer

# %%
P1n=expand(P1n);P1n
# Out:
#  2                  2
# a  + a⋅c - ⅈ⋅a⋅d + b  + ⅈ⋅b⋅c + b⋅d

# %%
P1n=simplify_img(P1n);P1n
# Out:
#  2          2
# a  + a⋅c + b  + b⋅d + ⅈ⋅(-a⋅d + b⋅c)

# %%
repart(P1n)
# Out:
#  2          2
# a  + a⋅c + b  + b⋅d

# %%
R1=repart(P1n)/P1d;R1
# Out:
#         2          2
#        a  + a⋅c + b  + b⋅d
# ─────────────────────────────────
#  2            2            2    2
# a  + 2⋅a⋅c + b  + 2⋅b⋅d + c  + d

# %% [markdown]
# ![image.png](attachment:1258594a-45b5-4580-9327-2e415fb54565.png)

# %%
P2=MyEq(z+w,'P2')
# Out:
# $\displaystyle P2 =a + i b + c + i d$

# %%
P2.Div(w)
# Out:
# $\displaystyle P2 =\frac{a + i b + c + i d}{c + i d}$

# %%
P2.Pow(-1)
# Out:
# $\displaystyle P2 =\frac{c + i d}{a + i b + c + i d}$

# %%
P2.simplify_img()
# Out:
# $\displaystyle P2 =\frac{c + i d}{a + c + i \left(b + d\right)}$

# %%
F=a+c-(b+d)*I
P2.Div(a+c-(b+d)*I)
# Out:
# $\displaystyle P2 =\frac{c + i d}{\left(a + c - i \left(b + d\right)\right) \left(a + c + i \left(b + d\right)\right)}$

# %%
P2.expand()
# Out:
# $\displaystyle P2 =\frac{c}{a^{2} + 2 a c + b^{2} + 2 b d + c^{2} + d^{2}} + \frac{i d}{a^{2} + 2 a c + b^{2} + 2 b d + c^{2} + d^{2}}$

# %%
P2.factor()
# Out:
# $\displaystyle P2 =\frac{c + i d}{a^{2} + 2 a c + b^{2} + 2 b d + c^{2} + d^{2}}$

# %%
P2.Mul(F)
# Out:
# $\displaystyle P2 =\frac{\left(c + i d\right) \left(a + c - i \left(b + d\right)\right)}{a^{2} + 2 a c + b^{2} + 2 b d + c^{2} + d^{2}}$

# %%
P2.expand()
# Out:
# $\displaystyle P2 =\frac{a c}{a^{2} + 2 a c + b^{2} + 2 b d + c^{2} + d^{2}} + \frac{i a d}{a^{2} + 2 a c + b^{2} + 2 b d + c^{2} + d^{2}} - \frac{i b c}{a^{2} + 2 a c + b^{2} + 2 b d + c^{2} + d^{2}} + \frac{b d}{a^{2} + 2 a c + b^{2} + 2 b d + c^{2} + d^{2}} + \frac{c^{2}}{a^{2} + 2 a c + b^{2} + 2 b d + c^{2} + d^{2}} + \frac{d^{2}}{a^{2} + 2 a c + b^{2} + 2 b d + c^{2} + d^{2}}$

# %%
P2.factor()
# Out:
# $\displaystyle P2 =\frac{\left(c + i d\right) \left(a - i b + c - i d\right)}{a^{2} + 2 a c + b^{2} + 2 b d + c^{2} + d^{2}}$

# %%
P2d=P2.denom 
P2n=P2.numer

# %%
P2n
# Out:
# (c + ⅈ⋅d)⋅(a - ⅈ⋅b + c - ⅈ⋅d)

# %%
P2n=expand(P2n);P2n
# Out:
#                              2    2
# a⋅c + ⅈ⋅a⋅d - ⅈ⋅b⋅c + b⋅d + c  + d

# %%
P2n=simplify_img(P2n);P2n
# Out:
#              2    2
# a⋅c + b⋅d + c  + d  + ⅈ⋅(a⋅d - b⋅c)

# %%
repart(P2n)
# Out:
#              2    2
# a⋅c + b⋅d + c  + d

# %%
R2=repart(P2n)/P2d;R2
# Out:
#                     2    2
#        a⋅c + b⋅d + c  + d
# ─────────────────────────────────
#  2            2            2    2
# a  + 2⋅a⋅c + b  + 2⋅b⋅d + c  + d

# %% [markdown]
# ![image.png](attachment:0df856e2-cf06-4eba-9aa7-150570bd14f2.png)

# %% [markdown]
# ![image.png](attachment:13fa5bcc-8415-43d7-909a-0232d4240d43.png)

# %%
R=MyEq(R1+R2,'R')
# Out:
# $\displaystyle R =\frac{a^{2} + a c + b^{2} + b d}{a^{2} + 2 a c + b^{2} + 2 b d + c^{2} + d^{2}} + \frac{a c + b d + c^{2} + d^{2}}{a^{2} + 2 a c + b^{2} + 2 b d + c^{2} + d^{2}}$

# %% [markdown]
# ![image.png](attachment:22a647ce-e86d-4c8d-a5f6-6ad975c85a47.png)

# %%
R.simplify()
# Out:
# $\displaystyle R =1$

# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)
