# %% [markdown]
# ![image.png](attachment:20e0cd2a-95b2-4f69-8c93-5299e944d921.png)

# %% [markdown]
# ![image.png](attachment:fe4d89c2-2fe0-4968-89ec-eacf08018c0b.png)

# %%
from  libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:73517cb3-98da-4c40-8d77-21db4972fcb9.png)

# %% [markdown]
# ![image.png](attachment:5a18c037-4336-4662-ad36-271ce3ba79d4.png)

# %%
P=MyEq((x+3)*(x*x+(a-2)*x-2*a),'P')
Q=MyEq((x-2)*( x*x+(b+3)*x+3*b),'Q')
# Out:
# $\displaystyle P =\left(x + 3\right) \left(- 2 a + x^{2} + x \left(a - 2\right)\right)$
# $\displaystyle Q =\left(x - 2\right) \left(3 b + x^{2} + x \left(b + 3\right)\right)$

# %%
P.factor()
Q.factor()
# Out:
# $\displaystyle P =\left(a + x\right) \left(x - 2\right) \left(x + 3\right)$
# $\displaystyle Q =\left(b + x\right) \left(x - 2\right) \left(x + 3\right)$

# %%
mcm=P.LCM(Q,'mcm')
# Out:
# $\displaystyle mcm =\left(a + x\right) \left(b + x\right) \left(x - 2\right) \left(x + 3\right)$

# %%
MCD=P.GCD(Q,'MCD')
# Out:
# $\displaystyle MCD =\left(x - 2\right) \left(x + 3\right)$

# %%
P.Div(MCD)
# Out:
# $\displaystyle P =a + x$

# %%
P.Mul(Q)
# Out:
# $\displaystyle P =\left(a + x\right) \left(b + x\right) \left(x - 2\right) \left(x + 3\right)$

# %%
P.expand()
# Out:
# $\displaystyle P =a b x^{2} + a b x - 6 a b + a x^{3} + a x^{2} - 6 a x + b x^{3} + b x^{2} - 6 b x + x^{4} + x^{3} - 6 x^{2}$

# %%
P.sortdegree(x)
# Out:
# $\displaystyle P =- 6 a b + x^{4} + x^{3} \left(a + b + 1\right) + x^{2} \left(a b + a + b - 6\right) + x \left(a b - 6 a - 6 b\right)$

# %%
mcm.expand()
# Out:
# $\displaystyle mcm =a b x^{2} + a b x - 6 a b + a x^{3} + a x^{2} - 6 a x + b x^{3} + b x^{2} - 6 b x + x^{4} + x^{3} - 6 x^{2}$

# %%
mcm.sortdegree(x)
# Out:
# $\displaystyle mcm =- 6 a b + x^{4} + x^{3} \left(a + b + 1\right) + x^{2} \left(a b + a + b - 6\right) + x \left(a b - 6 a - 6 b\right)$

# %%
Q1=MQ(-6*a*b,120)
# Out:
# $\displaystyle - 6 a b = 120$

# %%
P.s()
# Out:
# $\displaystyle P =- 6 a b + x^{4} + x^{3} \left(a + b + 1\right) + x^{2} \left(a b + a + b - 6\right) + x \left(a b - 6 a - 6 b\right)$

# %%
Q2=MQ(a+b+1,2)
# Out:
# $\displaystyle a + b + 1 = 2$

# %%
a,b=simplesolve(Q1,Q2)
# Out:
# $\displaystyle b =5$
# $\displaystyle a =-4$

# %%
1/a+1/b
# Out:
# -1/20

# %% [markdown]
# ![image.png](attachment:9ae86b6b-f45c-46fc-be16-7c5fdc1f36a8.png)

# %%
from  libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:73517cb3-98da-4c40-8d77-21db4972fcb9.png)

# %% [markdown]
# ![image.png](attachment:38e78f27-8041-4dbd-b15d-d700e4d254c1.png)

# %%
F=MyEq(x**6+2*x**5+x**4+x+1,'F')
P=MyEq(2*x**4+7*x**3+9*x*x+7*x+2,'P')
# Out:
# $\displaystyle F =x^{6} + 2 x^{5} + x^{4} + x + 1$
# $\displaystyle P =2 x^{4} + 7 x^{3} + 9 x^{2} + 7 x + 2$

# %%
F.factor()
# Out:
# $\displaystyle F =\left(x + 1\right) \left(x^{2} + x + 1\right) \left(x^{3} - x + 1\right)$

# %%
P.factor()
# Out:
# $\displaystyle P =\left(x + 2\right) \left(2 x + 1\right) \left(x^{2} + x + 1\right)$

# %%
MCD=P.GCD(F,'MCD')
# Out:
# $\displaystyle MCD =x^{2} + x + 1$

# %%
MCD.set(x=sqrt(2)+1)
# Out:
# $\displaystyle MCD =\sqrt{2} + 2 + \left(1 + \sqrt{2}\right)^{2}$

# %%
MCD.expand()
# Out:
# $\displaystyle MCD =3 \sqrt{2} + 5$

# %% [markdown]
# ![image.png](attachment:9ae86b6b-f45c-46fc-be16-7c5fdc1f36a8.png)

# %%
from  libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:73517cb3-98da-4c40-8d77-21db4972fcb9.png)

# %% [markdown]
# ![image.png](attachment:2e7554e8-ce76-4d1c-aeae-b460d003011d.png)

# %%
P=MyEq((x*x-2*x+1)**4*(x*x+3*x+2)**8,'P')
Q=MyEq((x**3-3*x*x+3*x-1)**4*(x+2)**8,'Q')
# Out:
# $\displaystyle P =\left(x^{2} - 2 x + 1\right)^{4} \left(x^{2} + 3 x + 2\right)^{8}$
# $\displaystyle Q =\left(x + 2\right)^{8} \left(x^{3} - 3 x^{2} + 3 x - 1\right)^{4}$

# %%
P.factor()
Q.factor()
# Out:
# $\displaystyle P =\left(x - 1\right)^{8} \left(x + 1\right)^{8} \left(x + 2\right)^{8}$
# $\displaystyle Q =\left(x - 1\right)^{12} \left(x + 2\right)^{8}$

# %%
F=P.MCD(Q,'F')
# Out:
# $\displaystyle F =\left(x - 1\right)^{8} \left(x + 2\right)^{8}$

# %%
n=8
F.Rpow(8)
# Out:
# $\displaystyle F =\left(\left(x - 1\right)^{8} \left(x + 2\right)^{8}\right)^{\frac{1}{8}}$

# %%
F.mulexpo()
# Out:
# $\displaystyle F =\left(x - 1\right)^{8 \cdot \frac{1}{8}} \left(x + 2\right)^{8 \cdot \frac{1}{8}}$

# %%
F.simplify()
# Out:
# $\displaystyle F =\left(x - 1\right) \left(x + 2\right)$

# %%
F.expand()
# Out:
# $\displaystyle F =x^{2} + x - 2$

# %% [markdown]
# ![image.png](attachment:2687061f-64c5-49bb-8920-75a1862fd540.png)

# %%
a=1
b=1
c=-2

# %%
a*b*c+n
# Out:
# 6

# %% [markdown]
# ![image.png](attachment:9ae86b6b-f45c-46fc-be16-7c5fdc1f36a8.png)

# %%
from  libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:73517cb3-98da-4c40-8d77-21db4972fcb9.png)

# %% [markdown]
# ![image.png](attachment:964b68e1-d9bb-4522-929d-09e531126dd0.png)

# %%
P=MyEq( x*x-2*x+1,'P',var=x)
# Out:
# $\displaystyle P =x^{2} - 2 x + 1$

# %%
q=MyEq(2*x**5+x**3+2*x*x+a*x+b,'q')
# Out:
# $\displaystyle q =a x + b + 2 x^{5} + x^{3} + 2 x^{2}$

# %%
Q=MyEq(m*x**3+n*x*x+p*x+1,'Q')
# Out:
# $\displaystyle Q =m x^{3} + n x^{2} + p x + 1$

# %%
A=MQ(P*Q,q)
# Out:
# $\displaystyle \left(x^{2} - 2 x + 1\right) \left(m x^{3} + n x^{2} + p x + 1\right) = a x + b + 2 x^{5} + x^{3} + 2 x^{2}$

# %%
A.expand()
# Out:
# $\displaystyle m x^{5} - 2 m x^{4} + m x^{3} + n x^{4} - 2 n x^{3} + n x^{2} + p x^{3} - 2 p x^{2} + p x + x^{2} - 2 x + 1 = a x + b + 2 x^{5} + x^{3} + 2 x^{2}$

# %%
compareandsolve(A,var=x)
# Out:
# $\displaystyle m =2$
# $\displaystyle n =4$
# $\displaystyle p =7$
# $\displaystyle a =5$
# $\displaystyle b =1$
# [2, 4, 7, 5, 1]

# %% [markdown]
# ![image.png](attachment:9ae86b6b-f45c-46fc-be16-7c5fdc1f36a8.png)

# %%
from  libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:73517cb3-98da-4c40-8d77-21db4972fcb9.png)

# %% [markdown]
# ![image.png](attachment:554e0426-3b9c-472b-ba88-23b1f8c9a550.png)

# %%
P=MyEq( x*x*x+8*x*x+(b+3)*x+21,'P',var=x)
Q=MyEq( x**4+6*x**3+13*x*x+4*p*x+15 ,'Q',var=x)
# Out:
# $\displaystyle P =x^{3} + 8 x^{2} + x \left(b + 3\right) + 21$
# $\displaystyle Q =4 p x + x^{4} + 6 x^{3} + 13 x^{2} + 15$

# %%
M=MyEq(x*x+x+3,'M')
# Out:
# $\displaystyle M =x^{2} + x + 3$

# %%
# if M if fcator then.---

# %%
R1=P.rem(M,'R1')
# Out:
# $\displaystyle R1 =b x - 7 x$

# %%
R2=Q.rem(M,'R2')
# Out:
# $\displaystyle R2 =4 p x - 20 x$

# %%
b=R1.solve(b)
# Out:
# $\displaystyle b =7$

# %%
p=R2.solve(p)
# Out:
# $\displaystyle p =5$

# %%
p+b
# Out:
# 12

# %% [markdown]
# ![image.png](attachment:9ae86b6b-f45c-46fc-be16-7c5fdc1f36a8.png)

# %%
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:73517cb3-98da-4c40-8d77-21db4972fcb9.png)

# %% [markdown]
# ![image.png](attachment:fe381526-5dff-403e-bff4-1a251a6a4e9d.png)

# %%
P=MyEq( x**4+m*x-9*x*x+n,'P',var=x)
M=MyEq( x*x-5*x+6 ,'M',var=x)
# Out:
# $\displaystyle P =m x + n + x^{4} - 9 x^{2}$
# $\displaystyle M =x^{2} - 5 x + 6$

# %%
R1=P.rem(M,'R1')
# Out:
# $\displaystyle R1 =m x + n + 20 x - 60$

# %%
m,n=compareandsolve(R1(x),var=x)
# Out:
# $\displaystyle m =-20$
# $\displaystyle n =60$

# %%
m/n
# Out:
# -1/3
