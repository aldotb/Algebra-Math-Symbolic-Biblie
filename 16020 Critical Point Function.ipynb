# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %%
from  libaldomath  import *
from lib_MyPlot import *
# %matplotlib widget

# %% [markdown]
# ![image.png](attachment:bd91bc93-1500-44a7-8694-16652e749d52.png)

# %%
fx=MyEq(2*x*x-4*x+5,'fx',var=x)
# Out:
# $\displaystyle fx =2 x^{2} - 4 x + 5$

# %%
MyPlot(fx)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
MyPlot(fx,-1,3)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
x1=simplesolve(fx.diff(x),x)
# Out:
# $\displaystyle x =1$

# %%
fx(x1)
# Out:
# 3

# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %%
from  libaldomath  import *

# %% [markdown]
# ![image.png](attachment:1e888c30-9f95-4828-b142-05afe8a0f1c4.png)

# %%
fx=MyEq(x**3-3*x*x+35,'fx',var=x)
# Out:
# $\displaystyle fx =x^{3} - 3 x^{2} + 35$

# %%
MyPlot(fx)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fmaxmin(fx)
# Out:
# [0, 2]

# %%
finflextion(fx)
# Out:
# 1

# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %%
from  libaldomath  import *

# %%
helpgui

# %%
from  libaldomath  import *
from lib_MyPlot import *
# %matplotlib widget

# %%
f1=MyEq(sqrt(12 - (x - 5)**2),'f1',var=x)
f2=MyEq((x - 5)**2,'f2',var=x)
f3=MyEq(x-1,'f3',var=x)
# Out:
# $\displaystyle f1 =\sqrt{12 - \left(x - 5\right)^{2}}$
# $\displaystyle f2 =\left(x - 5\right)^{2}$
# $\displaystyle f3 =x - 1$

# %%
MyPlot(f1,f2,f3)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %%
from  libaldomath  import *
from lib_MyPlot import *
# %matplotlib widget

# %%
f1=MyEq(x**3+3*x*x-2*x+1,'f1',var=x)
f2=MyEq(-x**3-3*x*x+2*x+3,'f2',var=x)
f3=MyEq(x-1,'f3',var=x)
# Out:
# $\displaystyle f1 =x^{3} + 3 x^{2} - 2 x + 1$
# $\displaystyle f2 =- x^{3} - 3 x^{2} + 2 x + 3$
# $\displaystyle f3 =x - 1$

# %%
MyPlot(f1,f2,f3)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %%
from  libaldomath  import *
from lib_MyPlot import *
# %matplotlib widget

# %%
f1=MyEq(3*x**4+16*x**3+24*x**2+3,'f1',var=x)
# Out:
# $\displaystyle f1 =3 x^{4} + 16 x^{3} + 24 x^{2} + 3$

# %%
MyPlot(f1)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
MyPlot(f1,-3,1)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %%
from  libaldomath  import *
from lib_MyPlot import *
# %matplotlib widget

# %%
f1=MyEq(x**3-3*x**2-144*x,'f1',var=x)
# Out:
# $\displaystyle f1 =x^{3} - 3 x^{2} - 144 x$

# %%
MyPlot(f1)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
