# %% [markdown]
# ![image.png](attachment:632d7b2a-9985-4ffc-969d-c65758988fed.png)

# %%
from  libaldomath  import *
from  MyMatrix  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:cce9350e-931a-4003-9e7d-5d5f67c1d5cf.png)

# %% [markdown]
# ![image.png](attachment:0c61ebe1-f97e-4ff8-beb3-86db73b6ea74.png)

# %% [markdown]
# ![image.png](attachment:cce9350e-931a-4003-9e7d-5d5f67c1d5cf.png)

# %% [markdown]
# ![image.png](attachment:7640f011-de3b-4229-8fe5-b8f8118496af.png)

# %%
A=MyVec(3,2,2)
B=MyVec(18,-22,-5)
C=MyVec(x,y,z)
# Out:
# Vector(3, 2, 2)
# Vector(18, -22, -5)
# Vector(x, y, z)

# %%
C.dot(A)
# Out:
# 3⋅x + 2⋅y + 2⋅z

# %%
C.dot(B)
# Out:
# 18⋅x - 22⋅y - 5⋅z

# %%
(C.module)**2
# Out:
#  2    2    2
# x  + y  + z

# %%
simplesolve(C.dot(A),C.dot(B),(C.module)**2-14*14,'show')
# Out:
# $\displaystyle z =12$
# $\displaystyle y =-6$
# $\displaystyle x =-4$
# [12, -6, -4]

# %%
C.set(z=12,x=-4,y=-6)
# Out:
# ⎡-4⎤
# ⎢  ⎥
# ⎢-6⎥
# ⎢  ⎥
# ⎣12⎦

# %% [markdown]
# ![image.png](attachment:cce9350e-931a-4003-9e7d-5d5f67c1d5cf.png)

# %% [markdown]
# ![image.png](attachment:8d230d80-6c65-4cde-aa07-97dbbf7e15bb.png)

# %%
A=MyVec(2,3,-1)
B=MyVec(1,-2,3)
X=MyVec(x,y,z)
# Out:
# Vector(2, 3, -1)
# Vector(1, -2, 3)
# Vector(x, y, z)

# %%
X.dot(A)
# Out:
# 2⋅x + 3⋅y - z

# %%
X.dot(B)
# Out:
# x - 2⋅y + 3⋅z

# %%
X.dot((2,-1,1))
# Out:
# 2⋅x - y + z

# %%
simplesolve(X.dot(A),X.dot(B),X.dot((2,-1,1))+6,'show')
# Out:
# $\displaystyle x =-3$
# $\displaystyle y =3$
# $\displaystyle z =3$
# [-3, 3, 3]

# %% [markdown]
# ![image.png](attachment:cce9350e-931a-4003-9e7d-5d5f67c1d5cf.png)

# %% [markdown]
# ![image.png](attachment:7f10a408-a385-4855-aab2-148444580601.png)

# %%
A=MyVec(a,-2,1)
B=MyVec(2*a,a,-4)
# Out:
# Vector(a, -2, 1)
# Vector(2*a, a, -4)

# %%
Q=MyEq(A.dot(B),'Q')
# Out:
# $\displaystyle Q =2 a^{2} - 2 a - 4$

# %%
Q.solve(a,'all')
# Out:
# $\displaystyle \left[ -1, \  2\right]$
# [-1, 2]

# %% [markdown]
# ![image.png](attachment:cce9350e-931a-4003-9e7d-5d5f67c1d5cf.png)

# %%
from  libaldomath  import *
from  MyMatrix  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:7f10a408-a385-4855-aab2-148444580601.png)

# %%
A=createVector3D('A')
# Out:
# Vector(Ax, Ay, Az)

# %%
Q1=MQ(Ax/2,cos(pi/3))
# Out:
# $\displaystyle \frac{Ax}{2} = \frac{1}{2}$

# %%
Q2=MQ(Ay/2,cos(2*pi/3))
# Out:
# $\displaystyle \frac{Ay}{2} = - \frac{1}{2}$

# %%
Q3=MQ(A.module,2)
# Out:
# $\displaystyle \sqrt{Ax^{2} + Ay^{2} + Az^{2}} = 2$

# %%
Q3.set(Ax=1,Ay=-1)
# Out:
# $\displaystyle \sqrt{Az^{2} + 2} = 2$
