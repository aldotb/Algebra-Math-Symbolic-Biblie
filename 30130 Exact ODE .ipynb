# %% [markdown]
# ![image.png](attachment:489bca0d-e38c-4178-8a51-589ac7d4de6e.png)

# %%
from Libaldomath import *
from lib_MyDiff  import *

# %% [markdown]
# ![image.png](attachment:56fc9020-ec7b-4d62-9d0f-20acb695c215.png)

# %%
M=MyEq(2*x*y*y+2*y,'M',var=y)
N=MyEq(2*x*x*y+2*x,'N',var=x)
# Out:
# $\displaystyle M =2 x y^{2} + 2 y$
# $\displaystyle N =2 x^{2} y + 2 x$

# %% [markdown]
# ![image.png](attachment:bc69f1e1-4cd3-4c5b-a3eb-eb73bd1d3536.png)

# %%
M.diff()
# Out:
# 4⋅x⋅y + 2

# %%
N.diff()
# Out:
# 4⋅x⋅y + 2

# %%
fx=MyEq(2*x*y*y+2*y,'fx',var=x)
fy=MyEq(2*x*x*y+2*x,'fy',var=y)
# Out:
# $\displaystyle fx =2 x y^{2} + 2 y$
# $\displaystyle fy =2 x^{2} y + 2 x$

# %%
dfx=fx.integral('dfx')
# Out:
# $\displaystyle dfx=\int \left(2 x y^{2} + 2 y\right)\, dx$

# %%
fxy=dfx.doit()
# Out:
# $\displaystyle dfx=C_{1} + x^{2} y^{2} + 2 x y$

# %% [markdown]
# ![image.png](attachment:489bca0d-e38c-4178-8a51-589ac7d4de6e.png)
