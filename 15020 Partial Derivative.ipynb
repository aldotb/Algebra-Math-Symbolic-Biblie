# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %%
from  Libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:ecfaba1c-bb22-41be-883f-78760720d819.png)

# %%
P=MyEq(3*x*x*y+5*y**3*x**2+3*x*y+y,'P',var=x)
# Out:
# $\displaystyle P =5 x^{2} y^{3} + 3 x^{2} y + 3 x y + y$

# %%
P.diff(x)
# Out:
#       3
# 10⋅x⋅y  + 6⋅x⋅y + 3⋅y

# %%
P.diff(y)
# Out:
#     2  2      2
# 15⋅x ⋅y  + 3⋅x  + 3⋅x + 1

# %%
P.diff(x,y)
# Out:
#       2
# 30⋅x⋅y  + 6⋅x + 3

# %%
dPx=P.diff(x,'dPx')
# Out:
# $\displaystyle dPx =10 x y^{3} + 6 x y + 3 y$

# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %%
from  Libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:8a88cac7-27de-4362-93f5-efa2223c9878.png)

# %%
P=MyEq(sin(5*x-2*y)+exp(3*x*x*y),'P',var=x)
# Out:
# $\displaystyle P =e^{3 x^{2} y} + \sin{\left(5 x - 2 y \right)}$

# %%
P.diff(x)
# Out:
#           2
#        3⋅x ⋅y
# 6⋅x⋅y⋅ℯ       + 5⋅cos(5⋅x - 2⋅y)

# %%
P.diff(y)
# Out:
#          2
#    2  3⋅x ⋅y
# 3⋅x ⋅ℯ       - 2⋅cos(5⋅x - 2⋅y)

# %%
P.diff(x,y)
# Out:
#             2             2
#     3    3⋅x ⋅y        3⋅x ⋅y
# 18⋅x ⋅y⋅ℯ       + 6⋅x⋅ℯ       + 10⋅sin(5⋅x - 2⋅y)

# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %%
from  Libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:614e0c94-29c3-4b10-a4f7-e086b5bb99a1.png)

# %%
F=MyEq(x*exp(x*x*y) ,'F',var=x)
# Out:
# $\displaystyle F =x e^{x^{2} y}$

# %%
Fdx=F.diff(x,'Fdx')
# Out:
# $\displaystyle Fdx =2 x^{2} y e^{x^{2} y} + e^{x^{2} y}$

# %%
Fdxdy=F.diff(y,'Fdxdx')
# Out:
# $\displaystyle Fdxdx =x^{3} e^{x^{2} y}$

# %%
Fdxdy(x=1,y=log(2))
# Out:
# 2

# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %%
from  Libaldomath  import *
# this cell will be initializing your variables

# %%
F=MyEq(1/(x**3-y**2) ,'F',var=x)
# Out:
# $\displaystyle F =\frac{1}{x^{3} - y^{2}}$

# %%
F.diff(x)
# Out:
#       2
#   -3⋅x
# ──────────
#          2
# ⎛ 3    2⎞
# ⎝x  - y ⎠

# %%
F.diff(y)
# Out:
#    2⋅y
# ──────────
#          2
# ⎛ 3    2⎞
# ⎝x  - y ⎠

# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %%
from  Libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:703d90fa-7782-4dd4-80b6-0ed19ed50578.png)

# %%
F=MyEq(3*x**3*y-2*x*x*y*y+y**3 ,'F',var=x)
# Out:
# $\displaystyle F =3 x^{3} y - 2 x^{2} y^{2} + y^{3}$

# %%
dFx=F.diff(x,'dFx')
# Out:
# $\displaystyle dFx =9 x^{2} y - 4 x y^{2}$

# %%
dFx(x=1,y=-2)
# Out:
# -34

# %%
dFy=F.diff(y,'dFy')
# Out:
# $\displaystyle dFy =3 x^{3} - 4 x^{2} y + 3 y^{2}$

# %%
dFy(x=1,y=-2)
# Out:
# 23

# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %%
from  Libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:bd3ebfd0-5e65-425a-9e6a-f9e989a5381b.png)

# %%
F=MyEq(ln(x*x+y),'F',var=x)
# Out:
# $\displaystyle F =\log{\left(x^{2} + y \right)}$

# %%
dFx=F.diff(x,'dFx')
# Out:
# $\displaystyle dFx =\frac{2 x}{x^{2} + y}$

# %%
dFx(x=1,y=2)
# Out:
# 2/3

# %%
dFy=F.diff(y,'dFy')
# Out:
# $\displaystyle dFy =\frac{1}{x^{2} + y}$

# %%
dFy(x=1,y=2)
# Out:
# 1/3

# %%
factor(F.diff(x,x))
# Out:
#    ⎛ 2    ⎞
# -2⋅⎝x  - y⎠
# ────────────
#          2
#  ⎛ 2    ⎞
#  ⎝x  + y⎠

# %%
factor(F.diff(y,y))
# Out:
#    -1
# ─────────
#         2
# ⎛ 2    ⎞
# ⎝x  + y⎠

# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %%
from  Libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:b8b05e99-3d68-46bc-957f-0da5c72110b1.png)

# %%
U=MyEq((a*x*x+b*y*y+c*z*z)**3,'U')
# Out:
# $\displaystyle U =\left(a x^{2} + b y^{2} + c z^{2}\right)^{3}$

# %%
U.diff(y,x,x)
# Out:
#     2    2              ⎛   2      2      2⎞
# 48⋅a ⋅b⋅x ⋅y + 24⋅a⋅b⋅y⋅⎝a⋅x  + b⋅y  + c⋅z ⎠

# %%
U.diff(x,x,y)
# Out:
#     2    2              ⎛   2      2      2⎞
# 48⋅a ⋅b⋅x ⋅y + 24⋅a⋅b⋅y⋅⎝a⋅x  + b⋅y  + c⋅z ⎠

# %%
U.diff(x,y,x)
# Out:
#     2    2              ⎛   2      2      2⎞
# 48⋅a ⋅b⋅x ⋅y + 24⋅a⋅b⋅y⋅⎝a⋅x  + b⋅y  + c⋅z ⎠
