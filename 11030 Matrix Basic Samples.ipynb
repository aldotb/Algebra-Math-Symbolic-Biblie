# %% [markdown]
# ![image.png](attachment:632d7b2a-9985-4ffc-969d-c65758988fed.png)

# %%
from  libaldomath  import *
from  MyMatrix  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:7042aa6f-b12c-4caf-9db7-1880e9b11706.png)

# %% [markdown]
# ![image.png](attachment:6c554dd4-ef71-47a1-a164-c3c3a54f7700.png)

# %%
A=MyMat((x-3*y,x),(1,y))
B=MyMat((2,6-y),(1,6-x))
C=MyMat((-4,-8),(2,3))
# Out:
# ⎡x - 3⋅y  x⎤
# ⎢          ⎥
# ⎣   1     y⎦
# ⎡2  6 - y⎤
# ⎢        ⎥
# ⎣1  6 - x⎦
# ⎡-4  -8⎤
# ⎢      ⎥
# ⎣2   3 ⎦

# %%
AB=MyMat(A-B)
# Out:
# ⎡x - 3⋅y - 2  x + y - 6⎤
# ⎢                      ⎥
# ⎣     0       x + y - 6⎦

# %%
x1,y1=AB.simplesolve('show')
# Out:
# $\displaystyle x =5$
# $\displaystyle y =1$

# %%
A.set(x=x1,y=y1)
# Out:
# ⎡2  5⎤
# ⎢    ⎥
# ⎣1  1⎦

# %%
3*A +2*C
# Out:
# ⎡-2  -1⎤
# ⎢      ⎥
# ⎣7   9 ⎦

# %%
from  libaldomath  import *
from  MyMatrix  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:6c554dd4-ef71-47a1-a164-c3c3a54f7700.png)

# %% [markdown]
# ![image.png](attachment:974b6997-d514-4f7e-b951-073fc89224fc.png)

# %%
H=MyMat((x*x,-3),(x,1))
# Out:
# ⎡ 2    ⎤
# ⎢x   -3⎥
# ⎢      ⎥
# ⎣x   1 ⎦

# %%
H.D
# Out:
#  2
# x  + 3⋅x

# %%
simplesolve(H.D-4)
# Out:
# $\displaystyle x =-4$
# -4

# %%
H.set(x=-4)
# Out:
# ⎡16  -3⎤
# ⎢      ⎥
# ⎣-4  1 ⎦

# %% [markdown]
# ![image.png](attachment:6c554dd4-ef71-47a1-a164-c3c3a54f7700.png)

# %%
from  libaldomath  import *
from  MyMatrix  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:985c6232-5704-4bd1-bea0-8e3a1ac5ba39.png)

# %%
A=MyMat((2+x,x),(x,3))
# Out:
# ⎡x + 2  x⎤
# ⎢        ⎥
# ⎣  x    3⎦

# %%
A.D
# Out:
#    2
# - x  + 3⋅x + 6

# %%
B=MyEq(x+b-A.D,'B')
# Out:
# $\displaystyle B =b + x^{2} - 2 x - 6$

# %%
Q=MQ(B,(x+c)**2)
# Out:
# $\displaystyle b + x^{2} - 2 x - 6 = \left(c + x\right)^{2}$

# %%
Q.expand()
# Out:
# $\displaystyle b + x^{2} - 2 x - 6 = c^{2} + 2 c x + x^{2}$

# %%
Q.all2L()
# Out:
# $\displaystyle b - c^{2} - 2 c x - 2 x - 6 = 0$

# %%
B2=MyEq(Q.L,'B2')
# Out:
# $\displaystyle B2 =b - c^{2} - 2 c x - 2 x - 6$

# %%
B2.set(c=-1)
# Out:
# $\displaystyle B2 =b - 7$

# %%
b=B2.solve(b)
# Out:
# $\displaystyle b =7$

# %% [markdown]
# ![image.png](attachment:6c554dd4-ef71-47a1-a164-c3c3a54f7700.png)

# %%
from  libaldomath  import *
from  MyMatrix  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:ea9166d3-6c29-4a56-b0b1-33d30e890fa2.png)

# %%
A=MyMat((2,-1),(3,-2))
B=MyMat((-3,0),(1,-2))
# Out:
# ⎡2  -1⎤
# ⎢     ⎥
# ⎣3  -2⎦
# ⎡-3  0 ⎤
# ⎢      ⎥
# ⎣1   -2⎦

# %%
M=A*B-B*A

# %%
deter(M)
# Out:
# -8

# %% [markdown]
# ![image.png](attachment:6c554dd4-ef71-47a1-a164-c3c3a54f7700.png)

# %%
from  libaldomath  import *
from  MyMatrix  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:b9058067-0b5e-4fbf-9063-e01d4d80a4b8.png)

# %%
A=MyMat((2,-1),(-1,2),(0,1))
B=MyMat((4,8,1),(2,-1,3))
# Out:
# ⎡2   -1⎤
# ⎢      ⎥
# ⎢-1  2 ⎥
# ⎢      ⎥
# ⎣0   1 ⎦
# ⎡4  8   1⎤
# ⎢        ⎥
# ⎣2  -1  3⎦

# %%
AB=MyMat(A*B)
# Out:
# ⎡6  17   -1⎤
# ⎢          ⎥
# ⎢0  -10  5 ⎥
# ⎢          ⎥
# ⎣2  -1   3 ⎦

# %%
BA=MyMat(B*A)
# Out:
# ⎡0  13⎤
# ⎢     ⎥
# ⎣5  -1⎦

# %%
AB.traz()+BA.traz()
# Out:
# -2

# %% [markdown]
# ![image.png](attachment:6c554dd4-ef71-47a1-a164-c3c3a54f7700.png)

# %%
from  libaldomath  import *
from  MyMatrix  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:1e0f82c8-0ea7-488b-862f-1ea3050fbd34.png)

# %%
A=MyMat((1,0),(-1,1))
# Out:
# ⎡1   0⎤
# ⎢     ⎥
# ⎣-1  1⎦

# %%
A.I
# Out:
# ⎡1  0⎤
# ⎢    ⎥
# ⎣1  1⎦

# %% [markdown]
# ![image.png](attachment:6c554dd4-ef71-47a1-a164-c3c3a54f7700.png)

# %%
from  libaldomath  import *
from  MyMatrix  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:5215094a-25bc-4fe7-ae9b-5567731a2cf5.png)

# %%
A=MyMat((2,-1),(3,0))
B=MyMat((-1,2),(1,1))
X=createMatrix(2,2,'a')
# Out:
# ⎡2  -1⎤
# ⎢     ⎥
# ⎣3  0 ⎦
# ⎡-1  2⎤
# ⎢     ⎥
# ⎣1   1⎦
# ⎡a₀₀  a₀₁⎤
# ⎢        ⎥
# ⎣a₁₀  a₁₁⎦

# %%
R=MyMat((A.T+B()).T+2*A-X())
# Out:
# ⎡5 - a₀₀   -a₀₁ - 2⎤
# ⎢                  ⎥
# ⎣11 - a₁₀  1 - a₁₁ ⎦

# %%
R.simplesolve('show')
# Out:
# $\displaystyle a00 =5$
# $\displaystyle a01 =-2$
# $\displaystyle a10 =11$
# $\displaystyle a11 =1$
# [5, -2, 11, 1]

# %% [markdown]
# ![image.png](attachment:6c554dd4-ef71-47a1-a164-c3c3a54f7700.png)

# %%
from  libaldomath  import *
from  MyMatrix  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:5215094a-25bc-4fe7-ae9b-5567731a2cf5.png)

# %%
A=MyMat((a-8,p-b,m-a),(a-5,b+9,n-b),(5-a,b-2,-2*c+5))
# Out:
# ⎡a - 8  -b + p  -a + m ⎤
# ⎢                      ⎥
# ⎢a - 5  b + 9   -b + n ⎥
# ⎢                      ⎥
# ⎣5 - a  b - 2   5 - 2⋅c⎦

# %%
B=MyMat((a-8,0,0),(0,b+9,0),(0,0,-2*c+5))
# Out:
# ⎡a - 8    0       0   ⎤
# ⎢                     ⎥
# ⎢  0    b + 9     0   ⎥
# ⎢                     ⎥
# ⎣  0      0    5 - 2⋅c⎦

# %%
D=MyMat(A-B)
# Out:
# ⎡  0    -b + p  -a + m⎤
# ⎢                     ⎥
# ⎢a - 5    0     -b + n⎥
# ⎢                     ⎥
# ⎣5 - a  b - 2     0   ⎦

# %%
R=D.simplesolve('show')
# Out:
# $\displaystyle a =5$
# $\displaystyle b =2$
# $\displaystyle m =5$
# $\displaystyle n =2$
# $\displaystyle p =2$

# %%
5-2+2
# Out:
# 5
