# %% [markdown]
# Volume

# %% [markdown]
# ![image.png](attachment:ac7f2e26-4ec9-4d08-8010-2b0f18bb7b85.png)

# %%
from  Libaldomath  import *
from lib_MyIntegral import *

# %% [markdown]
# ![image.png](attachment:96ac37db-8446-43ea-aa3e-c0fca413662d.png)

# %%
V=MyIntg(pi*(x*x)**2,'V',var=x,x1=1,x2=2)
# Out:
# $\displaystyle V=\int\limits_{1}^{2} \pi x^{4}\, dx$

# %%
V.doit()
# Out:
# $\displaystyle V=\frac{31 \pi}{5}$

# %% [markdown]
# ![image.png](attachment:ac7f2e26-4ec9-4d08-8010-2b0f18bb7b85.png)

# %%
from  Libaldomath  import *
from lib_MyIntegral import *

# %% [markdown]
# ![image.png](attachment:9f31e046-2b69-4c3a-a751-ee348719b859.png)

# %% [markdown]
# ![image.png](attachment:770612ca-0bfe-49b8-ab03-d366d79b6f2f.png)

# %%
V=MyIntg(pi*((2-x*x)-1)**2,'V',var=x,x1=-1,x2=1)
# Out:
# $\displaystyle V=\int\limits_{-1}^{1} \pi \left(1 - x^{2}\right)^{2}\, dx$

# %%
V.doit()
# Out:
# $\displaystyle V=\frac{16 \pi}{15}$

# %% [markdown]
# ![image.png](attachment:ac7f2e26-4ec9-4d08-8010-2b0f18bb7b85.png)

# %%
from  Libaldomath  import *
from lib_MyIntegral import *

# %% [markdown]
# ![image.png](attachment:2cd26e50-fa8b-4670-a51f-00e841a35a85.png)

# %% [markdown]
# ![image.png](attachment:d35cbf1f-3701-4722-bc87-0ec5f0656eb4.png)

# %%
f1=(x+3)**2
f2=(x**2+1)**2

# %%
V=MyIntg(pi*(f1-f2),'V',var=x,x1=-1,x2=2)
# Out:
# $\displaystyle V=\int\limits_{-1}^{2} \pi \left(\left(x + 3\right)^{2} - \left(x^{2} + 1\right)^{2}\right)\, dx$

# %%
V.expand()
# Out:
# $\displaystyle V=\int\limits_{-1}^{2} \left(- \pi x^{4} - \pi x^{2} + 6 \pi x + 8 \pi\right)\, dx$

# %%
V.doit()
# Out:
# $\displaystyle V=\frac{117 \pi}{5}$

# %% [markdown]
# ![image.png](attachment:ac7f2e26-4ec9-4d08-8010-2b0f18bb7b85.png)

# %%
from  Libaldomath  import *
from lib_MyIntegral import *

# %% [markdown]
# ![image.png](attachment:2cd26e50-fa8b-4670-a51f-00e841a35a85.png)

# %% [markdown]
# ![image.png](attachment:820e387d-c510-4dda-bc64-2575788e2f61.png)

# %% [markdown]
# ![image.png](attachment:9f665c51-1c2b-4b43-83d6-af39753a2c07.png)

# %%
f1=(4-y*y/4)**2
f2=(4-y)**2

# %%
V=MyIntg(pi*(f1-f2),'V',var=y,x1=0,x2=4)
# Out:
# $\displaystyle V=\int\limits_{0}^{4} \pi \left(- \left(4 - y\right)^{2} + \left(4 - \frac{y^{2}}{4}\right)^{2}\right)\, dy$

# %%
V.expand()
# Out:
# $\displaystyle V=\int\limits_{0}^{4} \left(\frac{\pi y^{4}}{16} - 3 \pi y^{2} + 8 \pi y\right)\, dy$

# %%
V.doit()
# Out:
# $\displaystyle V=\frac{64 \pi}{5}$

# %% [markdown]
# ![image.png](attachment:ac7f2e26-4ec9-4d08-8010-2b0f18bb7b85.png)

# %%
from  Libaldomath  import *
from lib_MyIntegral import *

# %% [markdown]
# ![image.png](attachment:86244ce3-b8aa-4022-8b2a-fae3ef5cfd19.png)

# %% [markdown]
# ![image.png](attachment:d77b20aa-5ffb-471e-95c7-983189516b56.png)

# %%
V=MyIntg(2*pi*x**3,'V',var=x,x1=0,x2=2)
# Out:
# $\displaystyle V=\int\limits_{0}^{2} 2 \pi x^{3}\, dx$

# %%
V.doit()
# Out:
# $\displaystyle V=8 \pi$

# %% [markdown]
# ![image.png](attachment:ac7f2e26-4ec9-4d08-8010-2b0f18bb7b85.png)

# %%
from  Libaldomath  import *
from lib_MyIntegral import *

# %% [markdown]
# ![image.png](attachment:54395b87-2002-436f-9f01-c239b4365f35.png)

# %% [markdown]
# ![image.png](attachment:5c31e6fa-844f-484d-8a3c-8d1e95ff2816.png)

# %%
V=MyIntg(2*pi*x*(2-3*x+x**3),'V',var=x,x1=0,x2=1)
# Out:
# $\displaystyle V=\int\limits_{0}^{1} 2 \pi x \left(x^{3} - 3 x + 2\right)\, dx$

# %%
V.doit()
# Out:
# $\displaystyle V=\frac{2 \pi}{5}$

# %% [markdown]
# ![image.png](attachment:ac7f2e26-4ec9-4d08-8010-2b0f18bb7b85.png)

# %%
from  Libaldomath  import *
from lib_MyIntegral import *

# %% [markdown]
# ![image.png](attachment:9c7051b4-967b-4ab8-bde7-c0cd2832404a.png)

# %% [markdown]
# ![image.png](attachment:ae3091fe-130e-414c-b655-9cd163dff6ba.png)

# %%
Q=MQ(x*x+y*y,r*r)
# Out:
# $\displaystyle x^{2} + y^{2} = r^{2}$

# %%
Q.Substrac(x*x)
# Out:
# $\displaystyle y^{2} = r^{2} - x^{2}$

# %%
Q.Rpow(2)
# Out:
# $\displaystyle \sqrt{y^{2}} = \sqrt{r^{2} - x^{2}}$

# %%
Q.mulexpo()
# Out:
# $\displaystyle y = \sqrt{r^{2} - x^{2}}$

# %% [markdown]
# Q.simplify()

# %%
y=Q.solve(y)
# Out:
# $\displaystyle y=\sqrt{r^{2} - x^{2}}$

# %%
f=MyEq(y,'f',var=x)
# Out:
# $\displaystyle f =\sqrt{r^{2} - x^{2}}$

# %% [markdown]
# ![image.png](attachment:38bad0d9-8bb2-4b03-8534-026cafb129a7.png)

# %%
df=f.diff('df')
# Out:
# $\displaystyle df =- \frac{x}{\sqrt{r^{2} - x^{2}}}$

# %%
df.Pow(2)
# Out:
# $\displaystyle df =\frac{x^{2}}{r^{2} - x^{2}}$

# %%
df.Add(1)
# Out:
# $\displaystyle df =\frac{x^{2}}{r^{2} - x^{2}} + 1$

# %%
df.Rpow(2)
# Out:
# $\displaystyle df =\sqrt{\frac{x^{2}}{r^{2} - x^{2}} + 1}$

# %% [markdown]
# ![image.png](attachment:d37f4dea-739b-403b-b23a-17455f83c81c.png)

# %%
S=MyIntg(4*pi*f*df,'S',var=x,x1=0,x2=r)
# Out:
# $\displaystyle S=\int\limits_{0}^{r} 4 \pi \sqrt{r^{2} - x^{2}} \sqrt{\frac{x^{2}}{r^{2} - x^{2}} + 1}\, dx$

# %%
S.joinbase()
# Out:
# $\displaystyle S=\int\limits_{0}^{r} 4 \pi \sqrt{\left(r^{2} - x^{2}\right) \left(\frac{x^{2}}{r^{2} - x^{2}} + 1\right)}\, dx$

# %%
S.simplify()
# Out:
# $\displaystyle S=\int\limits_{0}^{r} 4 \pi \sqrt{r^{2}}\, dx$

# %%
S.rsimplify()
# Out:
# $\displaystyle S=\int\limits_{0}^{r} 4 \pi r\, dx$

# %% [markdown]
# ![image.png](attachment:1c8c4fb7-0b52-409b-8f06-9ebd5c83f300.png)

# %%
S.doit()
# Out:
# $\displaystyle S=4 \pi r^{2}$

# %% [markdown]
# ![image.png](attachment:ac7f2e26-4ec9-4d08-8010-2b0f18bb7b85.png)

# %%
from  Libaldomath  import *
from lib_MyIntegral import *

# %% [markdown]
# ![image.png](attachment:056406d6-954f-4d3d-91bb-1f81cb29324e.png)

# %% [markdown]
# ![image.png](attachment:4cbe8a3d-e744-47c4-b1d2-a62f9fe97e14.png)

# %%
y=MyEq(sqrt(1-x*x),'y',var=x)
# Out:
# $\displaystyle y =\sqrt{1 - x^{2}}$

# %%
df=y.diff('df')
# Out:
# $\displaystyle df =- \frac{x}{\sqrt{1 - x^{2}}}$

# %%
df.Pow(2)
# Out:
# $\displaystyle df =\frac{x^{2}}{1 - x^{2}}$

# %%
df.Add(1)
# Out:
# $\displaystyle df =\frac{x^{2}}{1 - x^{2}} + 1$

# %%
df.Rpow(2)
# Out:
# $\displaystyle df =\sqrt{\frac{x^{2}}{1 - x^{2}} + 1}$

# %%
S=MyIntg(2*pi*y*df,'S',var=x,x1=0,x2=1)
# Out:
# $\displaystyle S=\int\limits_{0}^{1} 2 \pi \sqrt{1 - x^{2}} \sqrt{\frac{x^{2}}{1 - x^{2}} + 1}\, dx$

# %%
S.joinbase()
# Out:
# $\displaystyle S=\int\limits_{0}^{1} 2 \pi \sqrt{\left(1 - x^{2}\right) \left(\frac{x^{2}}{1 - x^{2}} + 1\right)}\, dx$

# %%
S.simplify()
# Out:
# $\displaystyle S=\int\limits_{0}^{1} 2 \pi\, dx$

# %%
S.doit()
# Out:
# $\displaystyle S=2 \pi$

# %%
from  Libaldomath  import *
from lib_MyIntegral import *

# %% [markdown]
# ![image.png](attachment:ac7f2e26-4ec9-4d08-8010-2b0f18bb7b85.png)

# %% [markdown]
# ![image.png](attachment:e048abb5-d6df-4b8e-9673-7f556dd1b964.png)

# %% [markdown]
# ![image.png](attachment:c621564e-ed1c-4e44-8176-ab2984d0579d.png)

# %%
f=(exp(x)+exp(-x))/2
f
# Out:
#  x    -x
# ℯ    ℯ
# ── + ───
# 2     2

# %%
f2=sqrt(1+diff(f,x)**2)
f2
# Out:
#       _________________
#      ╱           2
#     ╱  ⎛ x    -x⎞
#    ╱   ⎜ℯ    ℯ  ⎟
#   ╱    ⎜── - ───⎟  + 1
# ╲╱     ⎝2     2 ⎠

# %% [markdown]
# ![image.png](attachment:fb3678f2-6501-49e6-9de6-16e6fb2827c4.png)

# %%
S=MyIntg(4*pi*f*f2,'S',var=x,x1=0,x2=1)
# Out:
# $\displaystyle S=\int\limits_{0}^{1} 4 \pi \sqrt{\left(\frac{e^{x}}{2} - \frac{e^{- x}}{2}\right)^{2} + 1} \left(\frac{e^{x}}{2} + \frac{e^{- x}}{2}\right)\, dx$

# %%
S.expand()
# Out:
# $\displaystyle S=\int\limits_{0}^{1} \left(2 \pi \sqrt{\frac{e^{2 x}}{4} + \frac{1}{2} + \frac{e^{- 2 x}}{4}} e^{x} + 2 \pi \sqrt{\frac{e^{2 x}}{4} + \frac{1}{2} + \frac{e^{- 2 x}}{4}} e^{- x}\right)\, dx$

# %%
S.factor()
# Out:
# $\displaystyle S=\int\limits_{0}^{1} \pi \left(e^{2 x} + 1\right) \sqrt{e^{2 x} + 2 + e^{- 2 x}} e^{- x}\, dx$

# %%
S.changevar(exp(x),y)
# Out:
# $\displaystyle S=\int\limits_{0}^{1} \frac{\pi \left(y^{2} + 1\right) \sqrt{y^{2} + 2 + \frac{1}{y^{2}}}}{y^{2}}\, dy$

# %%
S.args()
# Out:
# $\displaystyle args(2)=\sqrt{y^{2} + 2 + \frac{1}{y^{2}}}$
# $\displaystyle args(2,0)=y^{2} + 2 + \frac{1}{y^{2}}$
# $\displaystyle args(2,0,2)=y^{2}$
# $\displaystyle args(3)=y^{2} + 1$

# %%
S.args(2,0)
# Out:
#  2       1
# y  + 2 + ──
#           2
#          y

# %%
S.tri2bin(str(S.args(2,0)),var=y)
# Out:
# $\displaystyle S=\int\limits_{0}^{1} \frac{\pi \left(y^{2} + 1\right) \sqrt{\left(\sqrt{y^{2}} + \frac{1}{\sqrt{y^{2}}}\right)^{2}}}{y^{2}}\, dy$

# %%
S.rsimplify()
# Out:
# $\displaystyle S=\int\limits_{0}^{1} \frac{\pi \left(y^{2} + 1\right) \left(y \sqrt{y^{2}} + 1\right)}{y^{3}}\, dy$

# %%
Sp=S.doit('Sp')
# Out:
# $\displaystyle S=\infty$

# %%
Sp.factor()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 Sp.factor()
#
# AttributeError: 'NoneType' object has no attribute 'factor'
