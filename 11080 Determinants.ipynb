# %% [markdown]
# ![image.png](attachment:632d7b2a-9985-4ffc-969d-c65758988fed.png)

# %%
from  libaldomath  import *
from  MyMatrix  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:cce9350e-931a-4003-9e7d-5d5f67c1d5cf.png)

# %% [markdown]
# ![image.png](attachment:19e9f6a2-d012-47d3-8547-e373c65027e0.png)

# %%
A=MyMat(3*x+2*y,2*x-3*y,2,1)
B=MyMat(a+2,2*a-2,2,1)
# Out:
# ⎡3⋅x + 2⋅y⎤
# ⎢         ⎥
# ⎣2⋅x - 3⋅y⎦
# ⎡ a + 2 ⎤
# ⎢       ⎥
# ⎣2⋅a - 2⎦

# %%
C=MyMat(A-B)
# Out:
# ⎡ -a + 3⋅x + 2⋅y - 2 ⎤
# ⎢                    ⎥
# ⎣-2⋅a + 2⋅x - 3⋅y + 2⎦

# %%
x,y=C.simplesolve(x,y)
# Out:
# $\displaystyle x =\frac{7 a}{13} + \frac{2}{13}$
# $\displaystyle y =\frac{10}{13} - \frac{4 a}{13}$

# %%
Q=MQ(x,3*y)
# Out:
# $\displaystyle \frac{7 a}{13} + \frac{2}{13} = \frac{30}{13} - \frac{12 a}{13}$

# %%
A=Q.solve(a)
# Out:
# $\displaystyle a =\frac{28}{19}$

# %% [markdown]
# ![image.png](attachment:cce9350e-931a-4003-9e7d-5d5f67c1d5cf.png)

# %%
from  libaldomath  import *
from  MyMatrix  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:a79957a4-61a7-445c-a439-8c65ae69e554.png)

# %%
Q1=MQ(3*sqrt(x)+2*sqrt(y),18)
# Out:
# $\displaystyle 3 \sqrt{x} + 2 \sqrt{y} = 18$

# %%
Q2=MQ(9*x-4*y,108)
# Out:
# $\displaystyle 9 x - 4 y = 108$

# %%
Q2.setL(squareadd2squaremul(Q2.L))
# Out:
# $\displaystyle \left(3 \sqrt{x} + 2 \sqrt{y}\right) \left(3 \sqrt{x} - 2 \sqrt{y}\right) = 108$

# %%
Q2.setL(18*Q2.args(0,0,1))
# Out:
# $\displaystyle 54 \sqrt{x} - 36 \sqrt{y} = 108$

# %%
Q2.Div(18)
# Out:
# $\displaystyle 3 \sqrt{x} - 2 \sqrt{y} = 6$

# %%
M=MyMat(Q1.L-Q1.R,Q2.L-Q2.R,2,1)
# Out:
# ⎡3⋅√x + 2⋅√y - 18⎤
# ⎢                ⎥
# ⎣3⋅√x - 2⋅√y - 6 ⎦

# %%
x,y=M.simplesolve()
# Out:
# $\displaystyle y =9$
# $\displaystyle x =16$

# %% [markdown]
# ![image.png](attachment:cce9350e-931a-4003-9e7d-5d5f67c1d5cf.png)

# %%
from  libaldomath  import *
from  MyMatrix  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:303ac7b9-f2f6-44d2-bf72-2094d9274367.png)

# %%
Q1=MQ(x*x/y**2+y**2/x**2,cfrac(13,6))
Q2=MQ(x**2+y**2,5)
# Out:
# $\displaystyle \frac{x^{2}}{y^{2}} + \frac{y^{2}}{x^{2}} = \frac{13}{6}$
# $\displaystyle x^{2} + y^{2} = 5$

# %%
M=MyMat(Q1.L-Q1.R,Q2.L-Q2.R,2,1)
# Out:
# ⎡ 2         2⎤
# ⎢x    13   y ⎥
# ⎢── - ── + ──⎥
# ⎢ 2   6     2⎥
# ⎢y         x ⎥
# ⎢            ⎥
# ⎢ 2    2     ⎥
# ⎣x  + y  - 5 ⎦

# %%
x,y=M.simplesolve()
# Out:
# $\displaystyle y =- \sqrt{3}$
# $\displaystyle x =- \sqrt{2}$

# %%
sqrt(2)*y+sqrt(3)*x
# Out:
# -1

# %% [markdown]
# ![image.png](attachment:cce9350e-931a-4003-9e7d-5d5f67c1d5cf.png)

# %%
from  libaldomath  import *
from  MyMatrix  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:4b12cafd-ea9c-4f05-8792-b6695b9f3693.png)

# %%
Q1=MyMat((3*p+1)*x+(3*p-1)*y-2,(p+6)*x+(p+3)*y-11,2,1)
# Out:
# ⎡x⋅(3⋅p + 1) + y⋅(3⋅p - 1) - 2⎤
# ⎢                             ⎥
# ⎣ x⋅(p + 6) + y⋅(p + 3) - 11  ⎦

# %%
x,y=simplesolve(Q1.vecdata(),x,y,'MyEq')
# Out:
# $\displaystyle x =\frac{31 p - 17}{7 p - 9}$
# $\displaystyle y =\frac{1 - 31 p}{7 p - 9}$

# %%
P=MyEq(x+y-1,'P')
# Out:
# $\displaystyle P =\frac{1 - 31 p}{7 p - 9} - 1 + \frac{31 p - 17}{7 p - 9}$

# %%
p=P.solve(p)
# Out:
# $\displaystyle p =-1$

# %%
x.update(p)
# Out:
# $\displaystyle x =3$

# %%
y.update(p)
# Out:
# $\displaystyle y =-2$

# %% [markdown]
# ![image.png](attachment:cce9350e-931a-4003-9e7d-5d5f67c1d5cf.png)
