# %% [markdown]
# ![image.png](attachment:20e0cd2a-95b2-4f69-8c93-5299e944d921.png)

# %% [markdown]
# ![image.png](attachment:54df9e1e-714e-4371-a5f2-ffb26663218e.png)

# %% [markdown]
# ![image.png](attachment:20e0cd2a-95b2-4f69-8c93-5299e944d921.png)

# %%
from Libaldomath import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:54289326-f8b1-441a-a788-18c9bb874596.png)

# %%
Q = MQ(4**(2*x-5), 64)
# Out:
# $\displaystyle 4^{2 x - 5} = 64$

# %%
Q.primefactor()
# Out:
# $\displaystyle 2^{4 x - 10} = 2^{6}$

# %%
Q.reduce()
# Out:
# $\displaystyle 4 x - 10 = 6$

# %%
x=Q.solve(x)
# Out:
# $\displaystyle x=4$

# %% [markdown]
# ![image.png](attachment:20e0cd2a-95b2-4f69-8c93-5299e944d921.png)

# %%
from Libaldomath import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:950ff156-5f79-44b9-a1c1-0494c656292c.png)

# %%
Q=MQ(27**(1-x),cfrac(1,9)**(2-x))
# Out:
# $\displaystyle 27^{1 - x} = \left(\frac{1}{9}\right)^{2 - x}$

# %%
Q.primefactor()
# Out:
# $\displaystyle 3^{3 - 3 x} = \left(1 \cdot \frac{1}{3^{2}}\right)^{2 - x}$

# %%
Q.simplify()
# Out:
# $\displaystyle 3 - 3 x = 2 x - 4$

# %%
Q.reduce()
# Out:
# $\displaystyle 3 - 3 x = 2 x - 4$

# %%
x=Q.solve(x)
# Out:
# $\displaystyle x=\frac{7}{5}$

# %% [markdown]
# ![image.png](attachment:20e0cd2a-95b2-4f69-8c93-5299e944d921.png)

# %% [markdown]
# ![image.png](attachment:e7346cea-49e6-4c5d-9159-491d8795baee.png)

# %%
from Libaldomath import *
# this cell will be initializing your variables

# %%
Q=MQ(ppow(2,x+2,3*x+1),8)
# Out:
# $\displaystyle 2^{\frac{x + 2}{3 x + 1}} = 8$

# %%
Q.primefactor()
# Out:
# $\displaystyle 2^{\frac{x + 2}{3 x + 1}} = 2^{3}$

# %%
Q.reduce()
# Out:
# $\displaystyle \frac{x + 2}{3 x + 1} = 3$

# %%
Q.crossmul()
# Out:
# $\displaystyle x + 2 = 9 x + 3$

# %%
x=Q.solve(x)
# Out:
# $\displaystyle x =- \frac{1}{8}$

# %% [markdown]
# ![image.png](attachment:20e0cd2a-95b2-4f69-8c93-5299e944d921.png)

# %% [markdown]
# ![image.png](attachment:6e91bd67-cf29-4d1e-9c9d-8d20aae346fc.png)

# %%
from Libaldomath import *
# this cell will be initializing your variables

# %%
Q=MQ(ppow(rpow(x,5),rpow(x,8)),(cfrac(16)**cfrac(5)))
# Out:
# $\displaystyle \left(x^{\frac{1}{5}}\right)^{x^{\frac{1}{8}}} = \left(\frac{1}{16}\right)^{\frac{1}{5}}$

# %%
Q.Pow(5)
# Out:
# $\displaystyle x^{\sqrt[8]{x}} = \frac{1}{16}$

# %%
Q.Rpow(8)
# Out:
# $\displaystyle \left(x^{\sqrt[8]{x}}\right)^{\frac{1}{8}} = \left(1 \cdot \frac{1}{16}\right)^{\frac{1}{8}}$

# %%
Q.mulexpo()
# Out:
# $\displaystyle x^{\sqrt[8]{x} \frac{1}{8}} = 16^{- \frac{1}{8}}$

# %%
Q.simplify()
# Out:
# $\displaystyle \sqrt[8]{x^{\sqrt[8]{x}}} = \frac{\sqrt{2}}{2}$

# %%
Q.setL(a**a)
# Out:
# $\displaystyle a^{a} = \frac{\sqrt{2}}{2}$

# %%
simplify(cfrac(4)**cfrac(4))
# Out:
# √2
# ──
# 2

# %%
P=MQ(rpow(x,8),cfrac(4))
# Out:
# $\displaystyle x^{\frac{1}{8}} = \frac{1}{4}$

# %%
P.Pow(8)
# Out:
# $\displaystyle x = \frac{1}{65536}$

# %% [markdown]
# ![image.png](attachment:20e0cd2a-95b2-4f69-8c93-5299e944d921.png)

# %% [markdown]
# ![image.png](attachment:56ae88dd-b1b1-4c5c-9776-dfde552d3f5c.png)

# %%
from Libaldomath import *
# this cell will be initializing your variables

# %%
Q=MQ(x**(x-x*x+13),x**2-12)
# Out:
# $\displaystyle x^{- x^{2} + x + 13} = x^{2} - 12$

# %%
Q.Mul(x**(x*x-13),'simplify')
# Out:
# $\displaystyle x^{x} = x^{x^{2} - 13} \left(x^{2} - 12\right)$

# %%
Q.Mul(x)
# Out:
# $\displaystyle x x^{x} = x x^{x^{2} - 13} \left(x^{2} - 12\right)$

# %%
Q.joinbase('R')
# Out:
# $\displaystyle x x^{x} = x^{x + 1}$

# %%
P=MQ(x,x*x-12)
# Out:
# $\displaystyle x = x^{2} - 12$

# %%
P.Substrac(x)
# Out:
# $\displaystyle 0 = x^{2} - x - 12$

# %%
P.factor()
# Out:
# $\displaystyle 0 = \left(x - 4\right) \left(x + 3\right)$

# %%
P.solve(x,'all')
# Out:
# $\displaystyle x1=-3$
# $\displaystyle x2=4$
# [-3, 4]
