# %% [markdown]
# ![image.png](attachment:a8b1ff51-1002-481d-8102-4b0d3e0fe8f7.png)

# %% [markdown]
# #### How set the Diferencial equation... es easy.. see

# %% [markdown]
# ![image.png](attachment:8611028b-07cb-4f7d-a471-06108b0ace61.png)

# %%
# first load main math library
from Libaldomath import *

# %%
# second Diferencial Calculos Library
from lib_MyDiff import *

# %% [markdown]
# ![image.png](attachment:8611028b-07cb-4f7d-a471-06108b0ace61.png)

# %%
Q=MyDiff("y'+x*y(x)","0",x,y)
# Out:
# $\displaystyle x y + y' = 0$

# %% [markdown]
# ![image.png](attachment:c2b67577-df87-4be6-9082-a70ef4247cc2.png)

# %%
Q=MyDiff("3*y-2*x*y'","7*x**5",x,y)
# Out:
# $\displaystyle - 2 x y' + 3 y = 7 x^{5}$

# %% [markdown]
# ![image.png](attachment:801e2dda-7c2c-4ac8-ad89-dfb43fbe2f77.png)

# %%
Q=MyDiff("y''-3*y'+2*(y)","8*exp(2*x)",x,y)
# Out:
# $\displaystyle 2 y - 3 y' + y'' = 8 e^{2 x}$

# %% [markdown]
# ### Incuding conditional values see bellow

# %% [markdown]
# ![image.png](attachment:6cb9f1e6-a753-48cd-8249-d7eecb26844a.png)

# %%
Q=MyDiff("y'","(y(x)-1)/(x+3)",x,y,ics="y(1)=-3")
# Out:
# $\displaystyle y' = \frac{y - 1}{x + 3}$

# %%
# then.....
Q.dsolve()
# Out:
# y(x) = -x - 2
