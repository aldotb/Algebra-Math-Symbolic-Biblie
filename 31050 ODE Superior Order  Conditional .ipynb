# %%
from libaldomath import *
from lib_MyDiff  import *

# %% [markdown]
# ![image.png](attachment:7c609b5d-777e-4c6f-bbf4-25b71007601d.png)

# %% [markdown]
# ![image.png](attachment:7843857d-f360-42aa-861f-3b837810bffd.png)

# %%
Q=MyDiff("y(x)+3*y'","3*x*x+20*x+18",x,y,ics="y'(0)=2,y(3)=45")
# Out:
# $\displaystyle y + 3 y' = 3 x^{2} + 20 x + 18$

# %%
Q.dsolve()
# Out:
#           2
# y(x) = 3⋅x  + 2⋅x + 12

# %%
from libaldomath import *
from lib_MyDiff  import *

# %% [markdown]
# ![image.png](attachment:7c609b5d-777e-4c6f-bbf4-25b71007601d.png)

# %% [markdown]
# ![image.png](attachment:ff8d131c-5877-4d05-a275-8f3fe2b1b2c1.png)

# %%
# and... y''(0)=2,y'(0)=1,y(0)=6

# %%
Qd=MyDiff("y''","20*x**3+24*x*x+60*x",x,y,ics="y''(0)=2,y'(0)=1,y(0)=6")
# Out:
# $\displaystyle y'' = 20 x^{3} + 24 x^{2} + 60 x$

# %%
Q.dsolve()
# Out:
#           2
# y(x) = 3⋅x  + 2⋅x + 12
