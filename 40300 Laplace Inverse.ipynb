# %% [markdown]
# ![imagen.png](attachment:6fe077e5-9821-4674-a8d4-8529d237cdba.png)

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)

# %%
from  Libaldomath  import *
from lib_MyDiff import *
from lib_MyIntegral import *

# %% [markdown]
# ![image.png](attachment:f4d1283c-309c-46dd-ac47-4bfc5a28a0f0.png)

# %%
F=MyEq((3*s-12)/(s*s+8),'F')
# Out:
# $\displaystyle F =\frac{3 s - 12}{s^{2} + 8}$

# %%
Ls=eQinverselaplace(F,'Ls')
# Out:
# $\displaystyle Ls =- 3 \sqrt{2} \sin{\left(2 \sqrt{2} t \right)} + 3 \cos{\left(2 \sqrt{2} t \right)}$

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)

# %%
from  Libaldomath  import *
from lib_MyDiff import *
from lib_MyIntegral import *

# %% [markdown]
# ![image.png](attachment:a1dc7644-687e-4813-bbff-b3a765dc412d.png)

# %%
F=MyEq(1/(2*s-5),'F')
# Out:
# $\displaystyle F =\frac{1}{2 s - 5}$

# %%
Ls=eQinverselaplace(F,'Ls')
# Out:
# $\displaystyle Ls =\frac{e^{\frac{5 t}{2}}}{2}$

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)

# %%
from  Libaldomath  import *
from lib_MyDiff import *
from lib_MyIntegral import *

# %% [markdown]
# ![image.png](attachment:63be92ca-6292-49cf-a661-137364235c50.png)

# %%
F=MyEq(s/(s*s-2*pi*s+2*pi*pi),'F')
# Out:
# $\displaystyle F =\frac{s}{s^{2} - 2 \pi s + 2 \pi^{2}}$

# %%
Ls=eQinverselaplace(F,'Ls')
# Out:
# $\displaystyle Ls =e^{\pi t} \sin{\left(\pi t \right)} + e^{\pi t} \cos{\left(\pi t \right)}$

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)

# %%
from  Libaldomath  import *
from lib_MyDiff import *
from lib_MyIntegral import *

# %% [markdown]
# ![image.png](attachment:3135abfb-141f-4772-a44f-2660caef2153.png)

# %%
F=MyEq((3*s-8)/(s*s+4)-(4*s-24)/(s*s-16),'F')
# Out:
# $\displaystyle F =\frac{3 s - 8}{s^{2} + 4} - \frac{4 s - 24}{s^{2} - 16}$

# %%
Ls=eQinverselaplace(F,'Ls')
# Out:
# $\displaystyle Ls =e^{4 t} - 4 \sin{\left(2 t \right)} + 3 \cos{\left(2 t \right)} - 5 e^{- 4 t}$

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)

# %%
from  Libaldomath  import *
from lib_MyDiff import *
from lib_MyIntegral import *

# %% [markdown]
# ![image.png](attachment:551dcfaf-2dbb-408f-8b4c-bd612c514a18.png)

# %%
F=MyEq((2*s-6)/(s**3-s),'F')
# Out:
# $\displaystyle F =\frac{2 s - 6}{s^{3} - s}$

# %% [markdown]
# ![image.png](attachment:71cabc8e-a50b-4333-8937-d0c520b63c9d.png)

# %%
F.apart()
# Out:
# $\displaystyle F =- \frac{4}{s + 1} - \frac{2}{s - 1} + \frac{6}{s}$

# %% [markdown]
# ![image.png](attachment:643c0e69-255e-4156-bd40-00ecd390c7da.png)

# %%
Ls=eQinverselaplace(F,'Ls')
# Out:
# $\displaystyle Ls =- 2 e^{t} + 6 - 4 e^{- t}$

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)

# %%
from  Libaldomath  import *
from lib_MyDiff import *
from lib_MyIntegral import *

# %% [markdown]
# ![image.png](attachment:d523d194-a589-44fc-ba55-cc839f46b170.png)

# %% [markdown]
# book methode??
# ![image.png](attachment:d8ebdd9c-8075-46f9-86bc-4a66ee225462.png)

# %% [markdown]
# more??
# ![image.png](attachment:b0ffca95-5394-4cec-a3b6-1f9a290a0aea.png)

# %% [markdown]
# ![image.png](attachment:93cd000f-0097-4e48-b8ab-0b5e6a830f3f.png)

# %%
# simple mthode..??

# %%
F=MyEq((1)/((s+1)*(s*s+1)),'F')
# Out:
# $\displaystyle F =\frac{1}{\left(s + 1\right) \left(s^{2} + 1\right)}$

# %%
F.Div(s-1)
# Out:
# $\displaystyle F =\frac{1}{\left(s - 1\right) \left(s + 1\right) \left(s^{2} + 1\right)}$

# %%
F.simplify()
# Out:
# $\displaystyle F =\frac{1}{s^{4} - 1}$

# %%
# fixin..Div by(s-1)
F.Mul(s-1)
# Out:
# $\displaystyle F =\frac{s - 1}{s^{4} - 1}$

# %%
F.apart()
# Out:
# $\displaystyle F =- \frac{s - 1}{2 \left(s^{2} + 1\right)} + \frac{1}{2 \left(s + 1\right)}$

# %%
Ls=eQinverselaplace(F,'Ls')
# Out:
# $\displaystyle Ls =\frac{\sin{\left(t \right)}}{2} - \frac{\cos{\left(t \right)}}{2} + \frac{e^{- t}}{2}$

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)
