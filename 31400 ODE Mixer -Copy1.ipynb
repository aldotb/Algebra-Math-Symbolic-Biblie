# %%
from libaldomath import *
from lib_MyDiff  import *

# %% [markdown]
# ![image.png](attachment:7c609b5d-777e-4c6f-bbf4-25b71007601d.png)

# %% [markdown]
# ![image.png](attachment:7d358f59-40f9-41a6-8fb5-48945ff8c9a2.png)

# %%
V0,V1,V2,X0,Vt,q=symbols('V0 V1 V2 X0 Vt q')

# %%
dq=symboldiff('q')
dt=symboldiff('t')
q0,Vi,x1,Ve,Vs=100,250,10,5,5

# %%
Q=MQ(dq/dt,Ve*x1-Vs*q/(Vi-(Vs-Ve)*t))
# Out:
# $\displaystyle \frac{q'}{t'} = 50 - \frac{q}{50}$

# %%
Q.factor()
# Out:
# $\displaystyle \frac{q'}{t'} = - \frac{q - 2500}{50}$

# %%
Q.Div(numer(Q.R))
# Out:
# $\displaystyle - \frac{50 q'}{t' \left(q - 2500\right)} = 1$

# %%
Q.Mul(dt)
# Out:
# $\displaystyle - \frac{50 q'}{q - 2500} = t'$

# %%
Q.integral(q,t)
# Out:
# $\displaystyle \int \left(- \frac{50}{q - 2500}\right)\, dq = \int 1\, dt$

# %%
Q.doit()
# Out:
# $\displaystyle - 50 \log{\left(q - 2500 \right)} = C_{1} + t$

# %%
Q.autofind(C1,t=0,q=100)
# Out:
# $\displaystyle t = - 50 \log{\left(q - 2500 \right)} + 50 \log{\left(2400 \right)} + 50 i \pi$

# %%
Q.alone(t)
# Out:
# $\displaystyle t = - 50 \log{\left(q - 2500 \right)} + 50 \log{\left(2400 \right)} + 50 i \pi$

# %%
Q('float',q=1300)
# Out:
# $\displaystyle t = 34.6573590279973$

# %% [markdown]
# ![image.png](attachment:260afeea-0986-4c61-96ba-64f0976b5f4b.png)

# %% [markdown]
# ![image.png](attachment:425a1b30-6690-4d3d-81c6-5ab6c2583c24.png)

# %% [markdown]
# ![image.png](attachment:7c609b5d-777e-4c6f-bbf4-25b71007601d.png)

# %%
from libaldomath import *
from lib_MyDiff  import *

# %% [markdown]
# ![image.png](attachment:eab9d6be-e9ba-4f04-a47b-7d1f42c4fc38.png)

# %%
Q1=MQ(dx,6*0-8*x/24+2*y/24,var=t)
Q2=MQ(dy,8*x/24 -y/3,var=t)
# Out:
# $\displaystyle x' = - \frac{x}{3} + \frac{y}{12}$
# $\displaystyle y' = \frac{x}{3} - \frac{y}{3}$

# %%
Q2.alone(x)
# Out:
# $\displaystyle x = y + 3 y'$

# %%
Q1.subs(x,Q2.R)
# Out:
# $\displaystyle x' = - \frac{y}{4} - y'$

# %%
Q2.diff(x,y)
# Out:
# $\displaystyle x' = y' + 3 y''$

# %%
Q1.setL(Q2.R)
# Out:
# $\displaystyle y' + 3 y'' = - \frac{y}{4} - y'$

# %%
Q1.all2L()
# Out:
# $\displaystyle \frac{y}{4} + 2 y' + 3 y'' = 0$

# %%
Q=MyDiff("y(t)/4+2*y'+3*y''","0",t,y,ics="y(0)=12")
# Out:
# $\displaystyle \frac{y}{4} + 2 y' + 3 y'' = 0$

# %%
y=Q.dsolve('y')
# Out:
# $\displaystyle y =C_{2} e^{- \frac{t}{6}} + \left(12 - C_{2}\right) e^{- \frac{t}{2}}$

# %%
Q3=MQ(y.diff(t),8*x/24 -y/3,var=t)
# Out:
# $\displaystyle - \frac{C_{2} e^{- \frac{t}{6}}}{6} - \frac{\left(12 - C_{2}\right) e^{- \frac{t}{2}}}{2} = - \frac{C_{2} e^{- \frac{t}{6}}}{3} + \frac{x}{3} - \frac{\left(12 - C_{2}\right) e^{- \frac{t}{2}}}{3}$

# %%
Q3.alone(x)
# Out:
# $\displaystyle x = \frac{\left(C_{2} e^{\frac{t}{2}} + \left(C_{2} - 12\right) e^{\frac{t}{6}}\right) e^{- \frac{2 t}{3}}}{2}$

# %%
C2=Q3.autosolve(C2,x=20,t=0)
# Out:
# $\displaystyle C2 =26$
# $\displaystyle x = \frac{\left(14 e^{\frac{t}{6}} + 26 e^{\frac{t}{2}}\right) e^{- \frac{2 t}{3}}}{2}$

# %%
Q3.expand()
# Out:
# $\displaystyle x = 7 e^{- \frac{t}{2}} + 13 e^{- \frac{t}{6}}$

# %%
y.update(C2)
# Out:
# $\displaystyle y =- 14 e^{- \frac{t}{2}} + 26 e^{- \frac{t}{6}}$

# %% [markdown]
# ![image.png](attachment:7c609b5d-777e-4c6f-bbf4-25b71007601d.png)

# %% [markdown]
# ![image.png](attachment:fe6e80e2-26f0-4acb-b484-471fe66f0e93.png)

# %%
from libaldomath import *
from lib_MyDiff  import *

# %%
Q1=MQ(dy,5*0-5*y/100)
Q2=MQ(dz,5*y/5-5*z/200)
# Out:
# $\displaystyle y' = - \frac{y}{20}$
# $\displaystyle z' = y - \frac{z}{40}$

# %%
Q2.alone(y)
# Out:
# $\displaystyle y = \frac{z}{40} + z'$

# %%
Q1.subs(y,Q2.R)
# Out:
# $\displaystyle y' = - \frac{z}{800} - \frac{z'}{20}$

# %%
Q2.diff(y,z)
# Out:
# $\displaystyle y' = \frac{z'}{40} + z''$

# %%
Q1.subs(dy,Q2.R)
# Out:
# $\displaystyle \frac{z'}{40} + z'' = - \frac{z}{800} - \frac{z'}{20}$

# %%
Q1.all2L()
# Out:
# $\displaystyle \frac{z}{800} + \frac{3 z'}{40} + z'' = 0$

# %%
Q1.Mul(800)
# Out:
# $\displaystyle z + 60 z' + 800 z'' = 0$

# %%
Q=MyDiff("z(t)+60*z'+800*z''","0",t,z,ics="z(0)=50")
# Out:
# $\displaystyle z + 60 z' + 800 z'' = 0$

# %%
z=Q.dsolve('z')
# Out:
# $\displaystyle z =C_{2} e^{- \frac{t}{40}} + \left(50 - C_{2}\right) e^{- \frac{t}{20}}$

# %%
Q2=MQ(z.diff(t),5*y/5-5*z/200)
# Out:
# $\displaystyle - \frac{C_{2} e^{- \frac{t}{40}}}{40} - \frac{\left(50 - C_{2}\right) e^{- \frac{t}{20}}}{20} = - \frac{C_{2} e^{- \frac{t}{40}}}{40} + y - \frac{\left(50 - C_{2}\right) e^{- \frac{t}{20}}}{40}$

# %%
Q2.all2L()
# Out:
# $\displaystyle \frac{\left(C_{2} - 40 y e^{\frac{t}{20}} - 50\right) e^{- \frac{t}{20}}}{40} = 0$

# %%
Q2.reducecero()
# Out:
# $\displaystyle C_{2} - 40 y e^{\frac{t}{20}} - 50 = 0$

# %%
Q2.alone(y)
# Out:
# $\displaystyle y = \frac{\left(C_{2} - 50\right) e^{- \frac{t}{20}}}{40}$

# %%
C2=Q2.autosolve(C2,t=0,y=50)
# Out:
# $\displaystyle C2 =2050$
# $\displaystyle y = 50 e^{- \frac{t}{20}}$

# %%
y=Q2.solve(y)
# Out:
# $\displaystyle y =50 e^{- \frac{t}{20}}$

# %%
z.update(C2)
# Out:
# $\displaystyle z =- 2000 e^{- \frac{t}{20}} + 2050 e^{- \frac{t}{40}}$

# %% [markdown]
# ![image.png](attachment:7d0c1613-fd78-49b7-983d-cee1920faa97.png)

# %% [markdown]
# ![image.png](attachment:7603ff50-cc12-42da-8761-08a11c603e76.png)

# %%
from libaldomath import *
from lib_MyDiff import *

# %%
v1,v2,Vo,q=symbols('v1 v2 Vo q')

# %%
Q=MQ(dx,3*2-3*x/300)
# Out:
# $\displaystyle x' = 6 - \frac{x}{100}$

# %%
Q1=MyDiff("x'","6-x(t)/100",t,x,ics="x(0)=50")
# Out:
# $\displaystyle x' = 6 - \frac{x}{100}$

# %%
x=Q1.dsolve('x')
# Out:
# $\displaystyle x =600 - 550 e^{- \frac{t}{100}}$
