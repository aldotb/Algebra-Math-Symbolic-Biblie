# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %% [markdown]
# ![image.png](attachment:de459c51-8048-4fbf-b3ba-791fb803bb62.png)

# %%
from  Libaldomath  import *
# this cell will be initializing your variables

# %%
f=MyEq(1/(x+1),'f',var=x)
# Out:
# $\displaystyle f =\frac{1}{x + 1}$

# %%
f.diff(x)
# Out:
#   -1
# ────────
#        2
# (x + 1)

# %%
f.diff(x,x)
# Out:
#    2
# ────────
#        3
# (x + 1)

# %%
f.diff(x,x,x)
# Out:
#   -6
# ────────
#        4
# (x + 1)

# %%
def fn(n):
    return (-1)**n*factorial(n)/((x+1)**(n+1))

# %%
fn(2)
# Out:
#    2
# ────────
#        3
# (x + 1)

# %%
fn(3)
# Out:
#   -6
# ────────
#        4
# (x + 1)

# %%
fn(n)
# Out:
#     n        -n - 1
# (-1) ⋅(x + 1)      ⋅n!

# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %% [markdown]
# ![image.png](attachment:ba214a52-feb5-456a-8814-028318fef0c7.png)

# %%
from  Libaldomath  import *
# this cell will be initializing your variables

# %%
f=MyEq(ln(x+a),'f',var=x)
# Out:
# $\displaystyle f =\log{\left(a + x \right)}$

# %%
f.diff(x)
# Out:
#   1
# ─────
# a + x

# %%
f.diff(x,x)
# Out:
#   -1
# ────────
#        2
# (a + x)

# %%
f.diff(x,x,x)
# Out:
#    2
# ────────
#        3
# (a + x)

# %%
def fn(n):
    return (-1)**(n+1)*factorial(n-1)/((x+a)**n)

# %%
fn(n)
# Out:
#     n + 1        -n
# (-1)     ⋅(a + x)  ⋅(n - 1)!

# %%
fn(3)
# Out:
#    2
# ────────
#        3
# (a + x)

# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %% [markdown]
# ![image.png](attachment:856f6627-aaa3-4f1b-a99c-94b7099790d5.png)

# %%
from  Libaldomath  import *
# this cell will be initializing your variables

# %%
f=MyEq(a*sin(3*x)+b*cos(3*x),'f')
# Out:
# $\displaystyle f =a \sin{\left(3 x \right)} + b \cos{\left(3 x \right)}$

# %%
Q=MQ(f.diff(x,x)+4*f.diff(x)+3*f(x),10*cos(3*x))
# Out:
# $\displaystyle - 6 a \sin{\left(3 x \right)} + 12 a \cos{\left(3 x \right)} - 12 b \sin{\left(3 x \right)} - 6 b \cos{\left(3 x \right)} = 10 \cos{\left(3 x \right)}$

# %%
Q.factor(sin(3*x))
# Out:
# $\displaystyle 6 \left(- a \sin{\left(3 x \right)} + 2 a \cos{\left(3 x \right)} - 2 b \sin{\left(3 x \right)} - b \cos{\left(3 x \right)}\right) = 10 \cos{\left(3 x \right)}$

# %%
Q.factor(cos(3*x))
# Out:
# $\displaystyle 6 \left(- a \sin{\left(3 x \right)} + 2 a \cos{\left(3 x \right)} - 2 b \sin{\left(3 x \right)} - b \cos{\left(3 x \right)}\right) = 10 \cos{\left(3 x \right)}$

# %%
a,b=simplesolve(12*a-6*b-10,-6*a-12*b,a,b)
# Out:
# $\displaystyle a =\frac{2}{3}$
# $\displaystyle b =- \frac{1}{3}$

# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)
