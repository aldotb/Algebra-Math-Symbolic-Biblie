# %%
from libaldomath import *
from lib_MyDiff  import *

# %% [markdown]
# ![image.png](attachment:7c609b5d-777e-4c6f-bbf4-25b71007601d.png)

# %% [markdown]
# ![image.png](attachment:46263d32-d632-4920-9c3c-f1793a10fd9b.png)

# %%
y=Function('y')(x)

# %%
diff(y,x,x,x)
# Out:
#   3
#  d
# ───(y(x))
#   3
# dx

# %%
Q=MQ(diff(y,x,x,x),x*exp(x))
# Out:
# $\displaystyle \frac{d^{3}}{d x^{3}} y{\left(x \right)} = x e^{x}$

# %%
Q.integral('',x)
# Out:
# $\displaystyle \frac{d^{2}}{d x^{2}} y{\left(x \right)} = \int x e^{x}\, dx$

# %%
Q.doit()
# Out:
# $\displaystyle \frac{d^{2}}{d x^{2}} y{\left(x \right)} = C_{1} + \left(x - 1\right) e^{x}$

# %%
Q.integral('',x)
# Out:
# $\displaystyle \frac{d}{d x} y{\left(x \right)} = \int \left(C_{1} + \left(x - 1\right) e^{x}\right)\, dx$

# %%
Q.doit()
# Out:
# $\displaystyle \frac{d}{d x} y{\left(x \right)} = C_{1} x + C_{2} + \left(x - 2\right) e^{x}$

# %%
Q.integral('',x)
# Out:
# $\displaystyle y{\left(x \right)} = \int \left(C_{1} x + C_{2} + \left(x - 2\right) e^{x}\right)\, dx$

# %%
Q.doit()
# Out:
# $\displaystyle y{\left(x \right)} = \frac{C_{1} x^{2}}{2} + C_{2} x + C_{3} + \left(x - 3\right) e^{x}$

# %%
from libaldomath import *
from lib_MyDiff  import *

# %% [markdown]
# ![image.png](attachment:7c609b5d-777e-4c6f-bbf4-25b71007601d.png)

# %% [markdown]
# ![image.png](attachment:d78e4eaf-e4c3-4422-82eb-d4415e039600.png)

# %%
Q=MyDiff("y''+a*y(x)","0",x,y
# Out:
# $\displaystyle a y + y'' = 0$

# %%
Q.dsolve()
# Out:
#                 ____           ____
#            -x⋅╲╱ -a        x⋅╲╱ -a
# y(x) = C₁⋅ℯ          + C₂⋅ℯ

# %%
from libaldomath import *
from lib_MyDiff  import *

# %% [markdown]
# ![image.png](attachment:7c609b5d-777e-4c6f-bbf4-25b71007601d.png)

# %% [markdown]
# ![image.png](attachment:e7b78031-4b8c-430c-b389-29d2de36b905.png)

# %%
Q=MyDiff("x*y''","y'*ln(y'/x)",x,y)
# Out:
# $\displaystyle x y'' = y' \log{\left(\frac{y'}{x} \right)}$

# %%
Q.dsolve()
# Out:
#                C₂⋅x + 1    C₂⋅x + 1
#             x⋅ℯ           ℯ
# y(x) = C₁ + ─────────── - ─────────
#                  C₂            2
#                              C₂

# %%
# neerd methode... like book example.. ejemm!!!

# %% [markdown]
# ![image.png](attachment:96458f59-1ff8-4b6f-af8e-3ac73ac0d616.png)

# %%
Q1=MQ(x*d2y,dy*ln(dy/x))
# Out:
# $\displaystyle x y'' = y' \log{\left(\frac{y'}{x} \right)}$

# %%
Q2=MQ(dy,z)
# Out:
# $\displaystyle y' = z$

# %%
Q3=MQ(dy,z)
# Out:
# $\displaystyle y' = z$

# %%
Q3.Div(x)
# Out:
# $\displaystyle \frac{y'}{x} = \frac{z}{x}$

# %%
Q3.log()
# Out:
# $\displaystyle \log{\left(\frac{y'}{x} \right)} = \log{\left(\frac{z}{x} \right)}$

# %%
Q3.Mul(Q2)
# Out:
# $\displaystyle y' \log{\left(\frac{y'}{x} \right)} = z \log{\left(\frac{z}{x} \right)}$

# %%
Q3.setL(x*d2y)
# Out:
# $\displaystyle x y'' = z \log{\left(\frac{z}{x} \right)}$

# %%
Q3.Div(x)
# Out:
# $\displaystyle y'' = \frac{z \log{\left(\frac{z}{x} \right)}}{x}$

# %%
Q3.setL(dz)
# Out:
# $\displaystyle z' = \frac{z \log{\left(\frac{z}{x} \right)}}{x}$

# %%
# if ...
Q4=MQ(z,u*x)
# Out:
# $\displaystyle z = u x$

# %%
# thrn...
Q4.diff(x,z,u)
# Out:
# $\displaystyle z' = u x' + u' x$

# %%
Q3.setL(Q4.R)
# Out:
# $\displaystyle u x' + u' x = \frac{z \log{\left(\frac{z}{x} \right)}}{x}$

# %%
Q3.set(z=u*x)
# Out:
# $\displaystyle u x' + u' x = u \log{\left(u \right)}$

# %%
# remeber that u'=du/dx... x'=dx setting this..then
Q3.Mul(dx,'R')
# Out:
# $\displaystyle u x' + u' x = u x' \log{\left(u \right)}$

# %%
Q3.Substrac(u*dx)
# Out:
# $\displaystyle u' x = u x' \log{\left(u \right)} - u x'$

# %%
Q3.factor(dx)
# Out:
# $\displaystyle u' x = x' \left(u \log{\left(u \right)} - u\right)$

# %%
Q3.Div((u*log(u)-u)*x)
# Out:
# $\displaystyle \frac{u'}{u \left(\log{\left(u \right)} - 1\right)} = \frac{x'}{x}$

# %%
Q3.integral(u,x)
# Out:
# $\displaystyle \int \frac{1}{u \left(\log{\left(u \right)} - 1\right)}\, du = \int \frac{1}{x}\, dx$

# %%
Q3.doit()
# Out:
# $\displaystyle \log{\left(\log{\left(u \right)} - 1 \right)} = C_{1} + \log{\left(x \right)}$

# %%
Q3.Substrac(log(x))
# Out:
# $\displaystyle - \log{\left(x \right)} + \log{\left(\log{\left(u \right)} - 1 \right)} = C_{1}$

# %%
Q3.lfactor()
# Out:
# $\displaystyle \log{\left(\frac{\log{\left(u \right)} - 1}{x} \right)} = C_{1}$

# %%
Q3.exp()
# Out:
# $\displaystyle \frac{\log{\left(u \right)} - 1}{x} = e^{C_{1}}$

# %%
Q3.Mul(x)
# Out:
# $\displaystyle \log{\left(u \right)} - 1 = x e^{C_{1}}$

# %%
Q3.Add(1)
# Out:
# $\displaystyle \log{\left(u \right)} = x e^{C_{1}} + 1$

# %%
Q3.set(u=z/x)
# Out:
# $\displaystyle \log{\left(\frac{z}{x} \right)} = x e^{C_{1}} + 1$

# %%
Q3.exp()
# Out:
# $\displaystyle \frac{z}{x} = e^{x e^{C_{1}} + 1}$

# %%
Q3.Mul(x)
# Out:
# $\displaystyle z = x e^{x e^{C_{1}} + 1}$

# %%
Q3.setL(dy)
# Out:
# $\displaystyle y' = x e^{x e^{C_{1}} + 1}$

# %%
Q3.integral(y,x)
# Out:
# $\displaystyle \int 1\, dy = \int x e^{x e^{C_{1}} + 1}\, dx$

# %%
Q3.doit()
# Out:
# $\displaystyle y = C_{2} + \left(x e^{C_{1}} - 1\right) e^{- 2 C_{1}} e^{x e^{C_{1}} + 1}$

# %%
Q3.expand()
# Out:
# $\displaystyle y = C_{2} + e x e^{- C_{1}} e^{x e^{C_{1}}} - e e^{- 2 C_{1}} e^{x e^{C_{1}}}$

# %%
Q3.simplify()
# Out:
# $\displaystyle y = C_{2} + x e^{- C_{1} + x e^{C_{1}} + 1} - e^{- 2 C_{1} + x e^{C_{1}} + 1}$
