# %% [markdown]
# ![image.png](attachment:489bca0d-e38c-4178-8a51-589ac7d4de6e.png)

# %%
from libaldomath import *
from lib_MyDiff  import *

# %% [markdown]
# ![image.png](attachment:eb777024-3d87-42a8-9404-eb61ace2650b.png)

# %% [markdown]
# ![image.png](attachment:ae085f51-1078-41c9-9bb1-9c7ddd820623.png)

# %%
L1=Line(x+3*y-5)
L2=Line(x-y-1)

# %%
L1.slope
# Out:
# -1/3

# %%
L2.slope
# Out:
# 1

# %%
L1.slope==L2.slope
# Out:
# False

# %% [markdown]
#  ![image.png](attachment:31a3512b-c697-44ba-924b-3eff6cf9647f.png)

# %%
L1.intersection(L2)
# Out:
# [Point2D(2, 1)]

# %%
Q1=MQ(x,z+2)
Q1.diff(x,z)
# Out:
# $\displaystyle x = z + 2$
# $\displaystyle dx = dz$

# %%
Q2=MQ(y,w+1)
Q2.diff(y,w)
# Out:
# $\displaystyle y = w + 1$
# $\displaystyle dy = dw$

# %% [markdown]
# ![image.png](attachment:1fc71ab6-09d3-492f-8336-768adaf8be32.png)

# %%
Q=MQ((x+3*y-5)*dx-(x-y-1)*dy,0)
# Out:
# $\displaystyle x' \left(x + 3 y - 5\right) - y' \left(x - y - 1\right) = 0$

# %%
Q.set(dx=dz,x=z+2,dy=dw,y=w+1)
# Out:
# $\displaystyle - w' \left(- w + z\right) + z' \left(3 w + z\right) = 0$

# %% [markdown]
# ![image.png](attachment:1e4aedea-14d0-45da-b2a9-91ca9dcc649c.png)

# %%
Q3=MQ(w,u*z,var=t)
# Out:
# $\displaystyle w = u z$

# %%
Q3.diff(w,u,z)
# Out:
# $\displaystyle dw = du z + dz u$

# %%
Q.set(dw=du*z+dz*u,w=u*z)
# Out:
# $\displaystyle z' \left(3 u z + z\right) - \left(- u z + z\right) \left(u z' + u' z\right) = 0$

# %%
Q.expand()
# Out:
# $\displaystyle u^{2} z z' + u u' z^{2} + 2 u z z' - u' z^{2} + z z' = 0$

# %%
Q.Div(z)
# Out:
# $\displaystyle u^{2} z' + u u' z + 2 u z' - u' z + z' = 0$

# %%
Q.factor(dz)
# Out:
# $\displaystyle u u' z - u' z + z' \left(u^{2} + 2 u + 1\right) = 0$

# %%
Q.factor(du)
# Out:
# $\displaystyle u' \left(u z - z\right) + z' \left(u^{2} + 2 u + 1\right) = 0$

# %%
Q.factor(z)
# Out:
# $\displaystyle u' z \left(u - 1\right) + z' \left(u^{2} + 2 u + 1\right) = 0$

# %%
Q.args()
# Out:
# $\displaystyle args(0,0)=z' \left(u^{2} + 2 u + 1\right)$
# $\displaystyle args(0,0,1)=u^{2} + 2 u + 1$
# $\displaystyle args(0,1)=u' z \left(u - 1\right)$
# $\displaystyle args(0,1,2)=u - 1$

# %%
Q.Substrac(Q.args(0,1))
# Out:
# $\displaystyle z' \left(u^{2} + 2 u + 1\right) = - u' z \left(u - 1\right)$

# %%
Q.factor()
# Out:
# $\displaystyle z' \left(u + 1\right)^{2} = - u' z \left(u - 1\right)$

# %%
Q.args()
# Out:
# $\displaystyle args(0,1)=\left(u + 1\right)^{2}$
# $\displaystyle args(0,1,0)=u + 1$
# $\displaystyle args(1,3)=u - 1$

# %%
Q.Div(Q.args(0,1)*Q.args(1,3))
# Out:
# $\displaystyle \frac{z'}{u - 1} = - \frac{u' z}{\left(u + 1\right)^{2}}$

# %%
Q.Mul((u-1)/z)
# Out:
# $\displaystyle \frac{z'}{z} = - \frac{u' \left(u - 1\right)}{\left(u + 1\right)^{2}}$

# %% [markdown]
# ![image.png](attachment:b518d37f-8354-4679-bf9f-57785eaf6250.png)

# %%
Q.integral(z,u)
# Out:
# $\displaystyle \int \frac{1}{z}\, dz = \int \left(- \frac{u - 1}{\left(u + 1\right)^{2}}\right)\, du$

# %%
Q.doit()
# Out:
# $\displaystyle \log{\left(z \right)} = C_{1} - \log{\left(u + 1 \right)} - \frac{2}{u + 1}$

# %%
Q.Add(log(u+1))
# Out:
# $\displaystyle \log{\left(z \right)} + \log{\left(u + 1 \right)} = C_{1} - \frac{2}{u + 1}$

# %%
Q.lfactor()
# Out:
# $\displaystyle \log{\left(z \left(u + 1\right) \right)} = C_{1} - \frac{2}{u + 1}$

# %%
Q.subs(u,w/z)
# Out:
# $\displaystyle \log{\left(\left(x - 2\right) \left(\frac{w}{z} + 1\right) \right)} = C_{1} - \frac{2}{\frac{w}{z} + 1}$

# %%
Q.subs(z,x-2)
# Out:
# $\displaystyle \log{\left(\left(x - 2\right) \left(\frac{w}{x - 2} + 1\right) \right)} = C_{1} - \frac{2}{\frac{w}{x - 2} + 1}$

# %%
Q.subs(w,y-1)
# Out:
# $\displaystyle \log{\left(\left(1 + \frac{y - 1}{x - 2}\right) \left(x - 2\right) \right)} = C_{1} - \frac{2}{1 + \frac{y - 1}{x - 2}}$

# %%
Q.simplify()
# Out:
# $\displaystyle \log{\left(x + y - 3 \right)} = \frac{C_{1} \left(x + y - 3\right) - 2 x + 4}{x + y - 3}$

# %%
Q.subs(x+y-3,w)
# Out:
# $\displaystyle \log{\left(w \right)} = \frac{C_{1} w - 2 x + 4}{w}$

# %%
Q.expand()
# Out:
# $\displaystyle \log{\left(w \right)} = C_{1} - \frac{2 x}{w} + \frac{4}{w}$

# %%
Q.Substrac(C1)
# Out:
# $\displaystyle - C_{1} + \log{\left(w \right)} = - \frac{2 x}{w} + \frac{4}{w}$

# %%
Q.factor()
# Out:
# $\displaystyle - C_{1} + \log{\left(w \right)} = - \frac{2 \left(x - 2\right)}{w}$

# %%
Q.subs(w,x+y-3)
# Out:
# $\displaystyle - C_{1} + \log{\left(x + y - 3 \right)} = - \frac{2 \left(x - 2\right)}{x + y - 3}$

# %% [markdown]
# ![image.png](attachment:489bca0d-e38c-4178-8a51-589ac7d4de6e.png)
