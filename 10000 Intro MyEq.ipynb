# %% [markdown]
# #### Library :  By Aldo Tamariz B  aldotb@gmail.com
# * This library include:
#
#   * sympy.py The best symbolic math library for me
#   * numpy as np, matplotlib.pyplot as plt IPython.display
#   * libaldo_math2.py this module have some util tools for classic math functions
#   * libaldo_algorith.py some algorith to manage simple math functions
#   * mathbasic.py include basic math
#   * mathexponencial all exponencial math procedures
#   * lib_MyEq , this module manage maths Eq
#   * lib_MyEqEq , this module will be MyEq=MyEq
# * Also include the most used variables like   ,x,y,z,alpha,mu..   etc... mayby 150 variables

# %% [markdown]
# #### MyEq class:  is a obj that will create Equations,
#     P=MyEq(math expretion, name(str), var=x indep var
# #### MyEqEq or MQ class:  is a obj that will create equallity equations ,
#     Q=MyEqEq(math expretion, math expretion)
#     Q=MyEqEq(P, math expretion)
#     Q=MyEqEq(math expretion, P)
#     Q=MyEqEq(P1, P2)
#
# #### All function can applied in both class, the diferenets is that in MyEqEq or MQ we add
#     'L' left, 'R' right to indicate only applied in right or let side..

# %% [markdown]
# #### code cell bellow initialize more 100 classic variables used in math and Physics

# %%
from  libaldomath import *  # this cell will be initializing your variables

# %% [markdown]
# * Math functions:
#     cfrac(1,2) return 1/2 not 0.5
#     ppow(x,y) return x**y
#     ppow(x,y,x) return (x**y)**(1/z)
#     rpow(x,y) return x**(1/y)
#     factor(),simplify(),expand()
#     fraction(x/y) return x,y
#
# * Take as example was created P=MyEq or MQ like P=MyEq(x*x+a+4....,'P',var=x)
# * In This Notebook we will use :
#
# In MyEq and MyEqEq:
#   * P.s() , show the math expr
#   * P.factor(), P.expand(), P.simplify() classic functions
#   * P.Add(), P.Substract(), P.Mul(), P.Div(), P.Pow(), P.Rpow()
#   * P.set(x=a) , replace x by a in P
#   * P.solve(a), solve a when P=0, and a will be a new class MyEq
#
# In MyEqEq:
#   * P.alone(a) , all expretionas will pass to rightside and leave a in left side

# %%
helpgui

# %% [markdown]
# ![image.png](attachment:095e8d3a-71f3-4b31-aa91-960eb4a27c4a.png)

# %%
A=MyEq(x*(2*y+z)-x*(3+2*z),'A')
# Out:
# $\displaystyle A =x \left(2 y + z\right) - x \left(2 z + 3\right)$

# %% [markdown]
# ![image.png](attachment:ed9b5f7f-d37b-421e-a700-4fb7871bb773.png)

# %%
A.s()  # show the Eq
# Out:
# $\displaystyle A =x \left(2 y + z\right) - x \left(2 z + 3\right)$

# %%
# idem in simplify, expand,factor , simplify
A.expand()
# Out:
# $\displaystyle A =2 x y - x z - 3 x$

# %%
B=MyEq(x*(2*y+z)-x*(3+2*z),'B')
# Out:
# $\displaystyle B =x \left(2 y + z\right) - x \left(2 z + 3\right)$

# %%
B.factor()
# Out:
# $\displaystyle B =x \left(2 y - z - 3\right)$

# %%
C=MyEq(x*(2*y+z)-x*(3+2*z),'C')
# Out:
# $\displaystyle C =x \left(2 y + z\right) - x \left(2 z + 3\right)$

# %%
C.simplify()
# Out:
# $\displaystyle C =x \left(2 y - z - 3\right)$

# %% [markdown]
# ![image.png](attachment:8e4e5e22-a915-4901-8f4c-79e0d079c890.png)

# %%
A+B
# Out:
# 2⋅x⋅y - x⋅z + x⋅(2⋅y - z - 3) - 3⋅x

# %%
2*(A+C)/B
# Out:
# 4⋅x⋅y - 2⋅x⋅z + 2⋅x⋅(2⋅y - z - 3) - 6⋅x
# ───────────────────────────────────────
#             x⋅(2⋅y - z - 3)

# %% [markdown]
# ![image.png](attachment:01280b2a-394e-4d99-b799-713b512f06c1.png)

# %% [markdown]
# ![image.png](attachment:f38a61a1-42a9-44ab-85d6-397b581833e1.png)

# %% [markdown]
# ![image.png](attachment:06c900fb-5fa5-452e-9252-5586134ae814.png)

# %%
P=MyEq(2*x+3,'P')
# Out:
# $\displaystyle P =2 x + 3$

# %%
P+3
# Out:
# 2⋅x + 6

# %%
P*P
# Out:
#          2
# (2⋅x + 3)

# %%
# Operations whit comman make the the MyEq set change see the diference
P+5
# Out:
# 2⋅x + 8

# %%
P.s() # not chahange
# Out:
# $\displaystyle P =2 x + 3$

# %%
P.Add(3)
# Out:
# $\displaystyle P =2 x + 6$

# %%
P.s()
# Out:
# $\displaystyle P =2 x + 6$

# %%
# we can use Add, Substrac, Mul, Div, Pow, Rpow, etc...

# %%
P.Mul(5)
# Out:
# $\displaystyle P =10 x + 30$

# %%
# also convined MyEq classes..

# %%
Q=MyEq(3*y+z)
# Out:
# $\displaystyle 3 y + z$

# %%
P*Q
# Out:
# (10⋅x + 30)⋅(3⋅y + z)

# %%
P()
# Out:
# 10⋅x + 30

# %%
P.Mul(Q)
# Out:
# $\displaystyle P =\left(10 x + 30\right) \left(3 y + z\right)$

# %%
P.s()
# Out:
# $\displaystyle P =\left(10 x + 30\right) \left(3 y + z\right)$

# %%
P()
# Out:
# (10⋅x + 30)⋅(3⋅y + z)

# %% [markdown]
# ![image.png](attachment:01280b2a-394e-4d99-b799-713b512f06c1.png)

# %%
# Exponencial functions

# %% [markdown]
# ![image.png](attachment:e595d743-72e1-4651-9d2b-c8fe1dc5d9d7.png)

# %% [markdown]
# ![image.png](attachment:33c0e597-a73a-4fb2-921d-bfb7b886976f.png)

# %% [markdown]
# ![image.png](attachment:06c900fb-5fa5-452e-9252-5586134ae814.png)

# %%
from  libaldomath import *  # this cell will be initializing your variables
# whit MyEq included in Libaldo.py

# %% [markdown]
# ![image.png](attachment:1201cdf5-1950-489e-9fe1-2ee94c2c95f1.png)

# %% [markdown]
# ![image.png](attachment:c4cb40c0-35b3-4d35-8286-16ef3f1d62e4.png)

# %%
e1=MyEq(2**2**(n+1),'e1')
e2=MyEq(2**2**n,'e2')
e3=MyEq(625,'e3')
e4=MyEq(8**2**n,'e4')
# Out:
# $\displaystyle e1 =2^{2^{n + 1}}$
# $\displaystyle e2 =2^{2^{n}}$
# $\displaystyle e3 =625$
# $\displaystyle e4 =8^{2^{n}}$

# %%
e1.Mul(e2)
# Out:
# $\displaystyle e1 =2^{2^{n}} 2^{2^{n + 1}}$

# %%
e1.Mul(2**2)
# Out:
# $\displaystyle e1 =4 \cdot 2^{2^{n}} 2^{2^{n + 1}}$

# %%
e1.simplify()
# Out:
# $\displaystyle e1 =2^{3 \cdot 2^{n} + 2}$

# %%
e3.primefactor()
# Out:
# $\displaystyle e3 =5^{4}$

# %%
e3.Pow(e4)
# Out:
# $\displaystyle e3 =625^{8^{2^{n}}}$

# %%
e3.primefactor()
# Out:
# $\displaystyle e3 =5^{4 \cdot 8^{2^{n}}}$

# %%
e3.simplifyexpo()
# Out:
#  ⎛    n    ⎞
#  ⎜ 3⋅2  + 2⎟
#  ⎝2        ⎠
# 5

# %%
M=MyEq(e3()**(1/e1),'M')
# Out:
# $\displaystyle M =\left(5^{4 \cdot 8^{2^{n}}}\right)^{2^{- 3 \cdot 2^{n} - 2}}$

# %%
M.mulexpo()
# Out:
# $\displaystyle M =\left(5^{4 \cdot 8^{2^{n}}}\right)^{2^{- 3 \cdot 2^{n} - 2}}$

# %%
M.simplify()
# Out:
# $\displaystyle M =\left(625^{8^{2^{n}}}\right)^{\frac{2^{- 3 \cdot 2^{n}}}{4}}$

# %%
M.mulexpo()
# Out:
# $\displaystyle M =625^{\frac{2^{- 3 \cdot 2^{n}} 8^{2^{n}}}{4}}$

# %%
M.simplify()
# Out:
# $\displaystyle M =5$

# %%
from  libaldomath import *  # this cell will be initializing your variables

# %%
M=MyEq(rpow(rpow(ppow(625,8**2**n,2**2),2**2**n),2**2**(n+1)),'M')
# Out:
# $\displaystyle M =\left(\left(625^{\frac{8^{2^{n}}}{4}}\right)^{2^{- 2^{n}} 1}\right)^{2^{- 2^{n + 1}} \cdot 1}$

# %%
M.mulexpo()
# Out:
# $\displaystyle M =\left(625^{\frac{8^{2^{n}}}{4}}\right)^{2^{- 2^{n + 1}} \cdot 1 \cdot 2^{- 2^{n}} 1}$

# %%
M.mulexpo()
# Out:
# $\displaystyle M =625^{2^{- 2^{n + 1}} \cdot 1 \cdot 2^{- 2^{n}} 1 \cdot \frac{8^{2^{n}}}{4}}$

# %%
M.mulexpo()
# Out:
# $\displaystyle M =625^{2^{- 2^{n + 1}} \cdot 1 \cdot 2^{- 2^{n}} 1 \cdot \frac{8^{2^{n}}}{4}}$

# %%
M.simplify()
# Out:
# $\displaystyle M =5$
