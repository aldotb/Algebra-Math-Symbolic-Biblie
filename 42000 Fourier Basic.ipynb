# %%
from libaldomath import *
from lib_MyFourier import *

# %% [markdown]
# ![image.png](attachment:95742aad-d445-41bd-ae3d-2bc76426dc7c.png)

# %%
Fx=MyFourier(x,'Fx',x1=-pi,x2=pi,var=x)

# %% [markdown]
# ![image.png](attachment:de794f80-5046-4494-bc14-0906ce015cf2.png)

# %%
a0=Fx.get_a0()
# Out:
# $\displaystyle a0=\int\limits_{- \pi}^{\pi} \frac{x}{\pi}\, dx$

# %% [markdown]
# ![image.png](attachment:519bcaf1-6e94-4fdc-97ce-af40c4d99485.png)

# %%
an=Fx.get_an()

# %% [markdown]
# ![image.png](attachment:1c9cb502-7b7e-499a-a803-8fd705e31536.png)

# %%
bn=Fx.get_bn()
# Out:
# $\displaystyle b_n=\int\limits_{- \pi}^{\pi} \frac{x \sin{\left(n x \right)}}{\pi}\, dx$

# %% [markdown]
# ![image.png](attachment:93189ca3-3d42-4870-82f8-ea5d4a5cad16.png)

# %%
Fx.fullfourier()
# Out:
#   ∞                                  ∞                                π
# ______                             ______                             ⌠
# ╲                                  ╲                                  ⎮  x
#  ╲                                  ╲                                 ⎮  ─ dx
#   ╲             π                    ╲             π                  ⎮  π
#    ╲            ⌠                     ╲            ⌠                  ⌡
#     ╲           ⎮  x⋅sin(n⋅x)          ╲           ⎮  x⋅cos(n⋅x)      -π
#     ╱  sin(n⋅x)⋅⎮  ────────── dx +     ╱  cos(n⋅x)⋅⎮  ────────── dx + ───────
#    ╱            ⎮      π              ╱            ⎮      π              2
#   ╱             ⌡                    ╱             ⌡
#  ╱              -π                  ╱              -π
# ╱                                  ╱
# ‾‾‾‾‾‾                             ‾‾‾‾‾‾
# n = 1                              n = 1

# %%
Fn=Fx.fourierfunc('Fn',x2=4)
# Out:
# $\displaystyle Fn =2 \sin{\left(x \right)} - \sin{\left(2 x \right)} + \frac{2 \sin{\left(3 x \right)}}{3} - \frac{\sin{\left(4 x \right)}}{2}$

# %%
Fx.plot() # default 5 args...

# %%
Fx.plot(100) # default 5 args...

# %% [markdown]
# ![image.png](attachment:99eaf1d8-8ae8-472d-bc33-86ea782bba25.png)

# %%
from libaldomath import *
from lib_MyFourier import *

# %% [markdown]
# ![image.png](attachment:73aa59cb-3b36-4e48-843a-8735d78dd1b3.png)

# %%
Fx=MyFourier(x*(x-3),'Fx',x1=0,x2=3,var=x)

# %%
Fx.fullfourier()
# Out:
#    ∞                                                      ∞
# _______                                                _______
# ╲                                                      ╲
#  ╲                                                      ╲
#   ╲                        3                             ╲
#    ╲                       ⌠                              ╲
#     ╲                      ⎮              ⎛π⋅n⋅x⎞          ╲
#      ╲                     ⎮ x⋅(x - 3)⋅sin⎜─────⎟           ╲
#      ╱     ⎛π⋅n⋅x⋅(x - 3)⎞ ⎮              ⎝  3  ⎠    +      ╱     ⎛π⋅n⋅x⋅(x -
#     ╱   sin⎜─────────────⎟⋅⎮ ──────────────────── dx       ╱   cos⎜───────────
#    ╱       ⎝      3      ⎠ ⎮          3                   ╱       ⎝      3
#   ╱                        ⌡                             ╱
#  ╱                         0                            ╱
# ╱                                                      ╱
# ‾‾‾‾‾‾‾                                                ‾‾‾‾‾‾‾
# ...

# %%
Fx.fourierserie()
# Out:
#      ⎛2⋅π⋅x⎞        ⎛4⋅π⋅x⎞
# 9⋅cos⎜─────⎟   9⋅cos⎜─────⎟
#      ⎝  3  ⎠        ⎝  3  ⎠   3
# ──────────── + ──────────── - ─ + …
#       2               2       2
#      π             4⋅π

# %%
Fx.plot()
