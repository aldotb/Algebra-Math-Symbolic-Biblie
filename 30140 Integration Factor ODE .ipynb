# %% [markdown]
# ![image.png](attachment:489bca0d-e38c-4178-8a51-589ac7d4de6e.png)

# %%
from Libaldomath import *
from lib_MyDiff  import *
from lib_MyIntegral import *

# %% [markdown]
# ![image.png](attachment:47da4286-5a2d-4e3c-920c-1db64a755aca.png)

# %%
M=MyEq(1-x*x*y,'M')
N=MyEq(x*x*(y-x),'N')
# Out:
# $\displaystyle M =- x^{2} y + 1$
# $\displaystyle N =x^{2} \left(- x + y\right)$

# %% [markdown]
# ![image.png](attachment:90c8a8cb-4628-4816-840d-9bf341b98128.png)

# %%
M.diff(y)
# Out:
#   2
# -x

# %%
N.diff(x)
# Out:
#    2
# - x  + 2⋅x⋅(-x + y)

# %% [markdown]
# ![image.png](attachment:890b94df-37f0-4e8c-9bd3-1630a10c4246.png)

# %%
f=MyEq((M.diff(y)-N.diff(x))/N,'F')
# Out:
# $\displaystyle F =- \frac{2}{x}$

# %%
f1=MyIntg(f,'f1',var=x)
# Out:
# $\displaystyle f1=\int \left(- \frac{2}{x}\right)\, dx$

# %%
f1.doit()
# Out:
# $\displaystyle f1=- 2 \log{\left(x \right)}$

# %% [markdown]
# ![image.png](attachment:be6ebe4a-bc2b-43d9-9713-2ba5f754d4d8.png)

# %%
u=MyEq(exp(f1()),'u')
# Out:
# $\displaystyle u =\frac{1}{x^{2}}$

# %% [markdown]
# ![image.png](attachment:489bca0d-e38c-4178-8a51-589ac7d4de6e.png)
