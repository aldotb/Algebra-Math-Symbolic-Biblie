# %% [markdown]
# ![image.png](attachment:20e0cd2a-95b2-4f69-8c93-5299e944d921.png)

# %%
from  Libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:73517cb3-98da-4c40-8d77-21db4972fcb9.png)

# %% [markdown]
# ![image.png](attachment:46dffeb1-7730-48b6-99f5-5b7fc2aaed71.png)

# %%
P=MyEq(x**4+4*a*b*x*x-(a*a-b*b)**2,'P')
# Out:
# $\displaystyle P =4 a b x^{2} + x^{4} - \left(a^{2} - b^{2}\right)^{2}$

# %%
P.expand()
# Out:
# $\displaystyle P =- a^{4} + 2 a^{2} b^{2} + 4 a b x^{2} - b^{4} + x^{4}$

# %%
P.factor()
# Out:
# $\displaystyle P =\left(- a + b + x\right) \left(a - b + x\right) \left(a^{2} + 2 a b + b^{2} + x^{2}\right)$

# %% [markdown]
# ![image.png](attachment:3509a246-d207-424d-9c3d-2c23c5164403.png)

# %% [markdown]
# ![image.png](attachment:9ae86b6b-f45c-46fc-be16-7c5fdc1f36a8.png)

# %%
from  Libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:73517cb3-98da-4c40-8d77-21db4972fcb9.png)

# %% [markdown]
# ![image.png](attachment:0a6a2826-04c6-4728-8280-cb1ed7b778a8.png)

# %%
P=MyEq((1+x+x*x+x**3+x**4+x**5)**2-x**5,'P')
# Out:
# $\displaystyle P =- x^{5} + \left(x^{5} + x^{4} + x^{3} + x^{2} + x + 1\right)^{2}$

# %%
P.factor() # Ok but... how chucha make it....??
# Out:
# $\displaystyle P =\left(x^{4} + x^{3} + x^{2} + x + 1\right) \left(x^{6} + x^{5} + x^{4} + x^{3} + x^{2} + x + 1\right)$

# %%
# bellow exclusive for nerds....

# %% [markdown]
#  ![image.png](attachment:9f9b2d16-d96d-43e5-bf47-c90de7a8e7eb.png)

# %% [markdown]
# ![image.png](attachment:9ae86b6b-f45c-46fc-be16-7c5fdc1f36a8.png)

# %%
from  Libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:73517cb3-98da-4c40-8d77-21db4972fcb9.png)

# %% [markdown]
# ![image.png](attachment:741e6729-dcda-4a9d-97e1-9c0505bf4d85.png)

# %%
# nerd procedure......

# %%
P=MyEq((a+b)**3*(c-d)**2-3*a*b*(a+b)*(c-d)**2+(a**3+b**3)*(c+d)**2,'P')
# Out:
# $\displaystyle P =- 3 a b \left(a + b\right) \left(c - d\right)^{2} + \left(a + b\right)^{3} \left(c - d\right)^{2} + \left(a^{3} + b^{3}\right) \left(c + d\right)^{2}$

# %%
P.factor()
# Out:
# $\displaystyle P =2 \left(a + b\right) \left(c^{2} + d^{2}\right) \left(a^{2} - a b + b^{2}\right)$

# %% [markdown]
# ![image.png](attachment:9ae86b6b-f45c-46fc-be16-7c5fdc1f36a8.png)

# %%
from  Libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:73517cb3-98da-4c40-8d77-21db4972fcb9.png)

# %% [markdown]
# ![image.png](attachment:52bd3768-9d79-4520-a258-42250f92e746.png)

# %%
# nerd procedure......

# %%
P=MyEq((2*x+1)**7+4*x*(x+1)+2,'P')
# Out:
# $\displaystyle P =4 x \left(x + 1\right) + \left(2 x + 1\right)^{7} + 2$

# %%
P.factor()
# Out:
# $\displaystyle P =\left(4 x^{2} + 6 x + 3\right) \left(32 x^{5} + 64 x^{4} + 48 x^{3} + 20 x^{2} + 4 x + 1\right)$

# %% [markdown]
# ![image.png](attachment:9ae86b6b-f45c-46fc-be16-7c5fdc1f36a8.png)

# %%
from  Libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:73517cb3-98da-4c40-8d77-21db4972fcb9.png)

# %% [markdown]
# ![image.png](attachment:6e5c01e4-f7f1-4906-aa4d-d2bde7e5b5e0.png)

# %%
# nerd methode

# %%
P=MyEq(A+B/(x-1)+C/(2*x+1),'P')
# Out:
# $\displaystyle P =A + \frac{B}{x - 1} + \frac{C}{2 x + 1}$

# %%
P.factor()
# Out:
# $\displaystyle P =\frac{2 A x^{2} - A x - A + 2 B x + B + C x - C}{\left(x - 1\right) \left(2 x + 1\right)}$

# %%
Q=MQ(P.numer,4*x*x-2*x+3)
# Out:
# $\displaystyle 2 A x^{2} - A x - A + 2 B x + B + C x - C = 4 x^{2} - 2 x + 3$

# %%
A,B,C=solve_coefcompare(Q,x)

# %%
A/3+B+C
# Out:
# -1

# %%
from  Libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:c405fad0-d767-42bc-b1be-812f51e2438d.png)

# %%
P=MyEq((2*x**3+x*x+2*x-1)/(x**4-1),'P')
# Out:
# $\displaystyle P =\frac{2 x^{3} + x^{2} + 2 x - 1}{x^{4} - 1}$

# %%
# libaldo method rush solution
P.apart()
# Out:
# $\displaystyle P =\frac{1}{x^{2} + 1} + \frac{1}{x + 1} + \frac{1}{x - 1}$
