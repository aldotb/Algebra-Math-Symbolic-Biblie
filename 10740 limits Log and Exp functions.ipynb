# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %%
from  libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:f346878c-3324-459e-a7b6-efd92755a94b.png)

# %% [markdown]
# ![image.png](attachment:94d7e6c9-4e98-4230-bc14-b93c8e0b527b.png)

# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %%
from  libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:c6e074a4-7251-4646-bdf4-8d6b502fa55d.png)

# %%
expr=(x-4)/(x+1);expr
# Out:
# x - 4
# ─────
# x + 1

# %%
P=MyEq(ppow(1+A/(x+1),x-2),'P',var=x)
# Out:
# $\displaystyle P =\left(\frac{A}{x + 1} + 1\right)^{x - 2}$

# %%
Q=MQ(expr,1+A/(x+1))
# Out:
# $\displaystyle \frac{x - 4}{x + 1} = \frac{A}{x + 1} + 1$

# %%
A=Q.solve(A)
# Out:
# $\displaystyle A =-5$

# %%
P.update(A)
# Out:
# $\displaystyle P =\left(1 - \frac{5}{x + 1}\right)^{x - 2}$

# %%
P.Pow(cfrac(-(x+1),5,evaluate=False))
# Out:
# $\displaystyle P =\left(\left(1 - \frac{5}{x + 1}\right)^{x - 2}\right)^{\frac{- x - 1}{5}}$

# %%
P.swapPow2Pow()
# Out:
# $\displaystyle P =\left(\left(1 - \frac{5}{x + 1}\right)^{\frac{- x - 1}{5}}\right)^{x - 2}$

# %%
P.mulexpo()
# Out:
# $\displaystyle P =\left(1 - \frac{5}{x + 1}\right)^{\left(x - 2\right) \frac{- x - 1}{5}}$

# %%
P1=MyEq(exp(-5*(x-2)/(x+1)),'P1',var=x)
# Out:
# $\displaystyle P1 =e^{\frac{10 - 5 x}{x + 1}}$

# %%
#test
P1.limit(oo)
# Out:
#  -5
# ℯ

# %%
P=MyEq(ppow(1+A/(x+1),x-2),'P',var=x)
P.limit(oo)
# Out:
# $\displaystyle P =\left(1 - \frac{5}{x + 1}\right)^{x - 2}$
#  -5
# ℯ

# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %%
from  libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:2b63f62f-7d4d-44d7-b436-86126f195967.png)

# %%
P1=(x*x+3)/(x*x+4*x);P1
# Out:
#   2
#  x  + 3
# ────────
#  2
# x  + 4⋅x

# %%
P2=(x*x-1)/x;P2
# Out:
#  2
# x  - 1
# ──────
#   x

# %%
P=MyEq(ppow(P1,P2),'P',var=x)
# Out:
# $\displaystyle P =\left(\frac{x^{2} + 3}{x^{2} + 4 x}\right)^{\frac{x^{2} - 1}{x}}$

# %%
P.limit(oo)
# Out:
#  -4
# ℯ

# %% [markdown]
# ![image.png](attachment:d59ef2ba-831e-4524-ae94-0178aa26a974.png)

# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %%
from  libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:616420fa-7ac6-49d9-8d96-1a1fbf159c14.png)

# %%
P1=sqrt(x)+1-sqrt(x+1);P1
# Out:
#        _______
# √x - ╲╱ x + 1  + 1

# %%
P2=sqrt(x);P2
# Out:
# √x

# %%
P=MyEq(ppow(P1,P2),'P',var=x)
# Out:
# $\displaystyle P =\left(\sqrt{x} - \sqrt{x + 1} + 1\right)^{\sqrt{x}}$

# %%
P.limit(oo)
# Out:
#  -1/2
# ℯ

# %% [markdown]
# ![image.png](attachment:73a9ca2c-909e-4da5-a360-389659ba097f.png)

# %%
P=MyEq(ppow(P1,P2),'P',var=x)
P.limit(oo)
# Out:
# $\displaystyle P =\left(\sqrt{x} - \sqrt{x + 1} + 1\right)^{\sqrt{x}}$
#  -1/2
# ℯ

# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %%
from  libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:69563fa9-2aa7-4923-a11b-1fbad3abb1fd.png)

# %%
P=MyEq((cos(x)+a*sin(b*x))**cfrac(x),'P',var=x)
# Out:
# $\displaystyle P =\left(a \sin{\left(b x \right)} + \cos{\left(x \right)}\right)^{\frac{1}{x}}$

# %%
P.limit(0)
# Out:
# 1
