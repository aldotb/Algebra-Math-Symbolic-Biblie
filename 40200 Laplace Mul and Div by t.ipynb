# %% [markdown]
# ![imagen.png](attachment:6fe077e5-9821-4674-a8d4-8529d237cdba.png)

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)

# %%
from  libaldomath  import *
from lib_MyDiff import *
# this cell will be initializing your variables

# %% [markdown]
# ![imagen.png](attachment:7443a300-5277-43d7-b2a2-565a76bc6d59.png)

# %%
Q=MyEqDiff("4*y''+y(t)","-2",t,y,ics="y'(0)=1/2,y(0)=0")
# Out:
# $\displaystyle y + 4 y'' = -2$

# %%
# Convert Function in Lapalce expr
Ls=func2laplace(Q)
# Out:
# $\displaystyle \mathcal{L} = 4 s^{2} \mathcal{L}_{t}\left[y{\left(t \right)}\right]\left(s\right) - 4 s y{\left(0 \right)} + \mathcal{L}_{t}\left[y{\left(t \right)}\right]\left(s\right) - 4 \left. \frac{d}{d t} y{\left(t \right)} \right|_{\substack{ t=0 }} + \frac{2}{s}$

# %%
# rempmplace   ics="y'(0)=1/2,y(0)=0" in Ls
Ls=subsics(Ls,t,y,Q.ics)
Ls
# Out:
#    2                                                                   2
# 4⋅s ⋅LaplaceTransform(y(t), t, s) + LaplaceTransform(y(t), t, s) - 2 + ─
#                                                                        s

# %%
# then solve Lt in LS
Lt=solvelaplace(Ls,t,y)
# Out:
# $\displaystyle L_t =\frac{2 s - 2}{4 s^{3} + s}$

# %% [markdown]
# ![imagen.png](attachment:5ba77ead-a752-4686-806d-f6b258007395.png)

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)

# %%
from  libaldomath  import *
from lib_MyDiff import *
# this cell will be initializing your variables

# %% [markdown]
# ![imagen.png](attachment:7443a300-5277-43d7-b2a2-565a76bc6d59.png)

# %%
Q=MyEqDiff("y'-3*y(t)","exp(2*t)",t,y,ics="y(0)=1")
# Out:
# $\displaystyle - 3 y + y' = e^{2 t}$

# %%
# Convert Function in Lapalce expr
Ls=func2laplace(Q)
# Out:
# $\displaystyle \mathcal{L} = s \mathcal{L}_{t}\left[y{\left(t \right)}\right]\left(s\right) - 3 \mathcal{L}_{t}\left[y{\left(t \right)}\right]\left(s\right) - y{\left(0 \right)} - \frac{1}{s - 2}$

# %%
# rempmplace   ics="y'(0)=1/2,y(0)=0" in Ls
Ls=subsics(Ls,t,y,Q.ics)
Ls
# Out:
#                                                                         1
# s⋅LaplaceTransform(y(t), t, s) - 3⋅LaplaceTransform(y(t), t, s) - 1 - ─────
#                                                                       s - 2

# %%
# then solve Lt in LS
Lt=solvelaplace(Ls,t,y)
# Out:
# $\displaystyle L_t =\frac{s - 1}{s^{2} - 5 s + 6}$

# %%
Lt.factor()
# Out:
# $\displaystyle L_t =\frac{s - 1}{\left(s - 3\right) \left(s - 2\right)}$

# %% [markdown]
# ![imagen.png](attachment:cf1235c2-0e42-4e35-91c5-24c0a762bc0b.png)

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)

# %% [markdown]
# ![imagen.png](attachment:df8c29c2-4b64-4c1b-8e39-2d3c27dd863c.png)

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)

# %%
from  libaldomath  import *
from lib_MyDiff import *
# this cell will be initializing your variables

# %% [markdown]
# ![imagen.png](attachment:056c3a89-6dc0-4260-b94b-aef353d7f341.png)

# %%
F=MyEq(t*cos(a*t),'F',var=t)
# Out:
# $\displaystyle F =t \cos{\left(a t \right)}$

# %%
Ls=eQlaplace(F,'Ls') # ??
# Out:
# $\displaystyle Ls =- \frac{2 s^{2}}{\left(a^{2} + s^{2}\right)^{2}} + \frac{1}{a^{2} + s^{2}}$

# %%
Ls.factor()
# Out:
# $\displaystyle Ls =- \frac{\left(- a + s\right) \left(a + s\right)}{\left(a^{2} + s^{2}\right)^{2}}$

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)

# %%
from  libaldomath  import *
from lib_MyDiff import *
# this cell will be initializing your variables

# %% [markdown]
# ![imagen.png](attachment:8c7c6e91-0ebe-488c-89de-79c37bf426ba.png)

# %%
F=MyEq(t*(3*sin(2*t)-2*cos(2*t)),'F',var=t)
# Out:
# $\displaystyle F =t \left(3 \sin{\left(2 t \right)} - 2 \cos{\left(2 t \right)}\right)$

# %%
Ls=eQlaplace(F,'Ls')
# Out:
# $\displaystyle Ls =\frac{4 s^{2}}{\left(s^{2} + 4\right)^{2}} - \frac{12 s}{\left(s^{2} + 4\right)^{2}} - \frac{2}{s^{2} + 4}$

# %%
Ls.factor()
# Out:
# $\displaystyle Ls =\frac{2 \left(s^{2} - 6 s - 4\right)}{\left(s^{2} + 4\right)^{2}}$

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)

# %% [markdown]
# ![imagen.png](attachment:a91c9160-e99d-4da1-9600-a34a00ace504.png)

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)

# %% [markdown]
# ![imagen.png](attachment:dc3c3081-9fef-45f3-82f3-4da6f6d20e2e.png)

# %%
Q=MyEq((exp(-a*t)-exp(-b*t))/t,'Q',var=t)
# Out:
# $\displaystyle Q =\frac{- e^{- b t} + e^{- a t}}{t}$

# %%
Ls=eQlaplace(Q,'Ls')
# Out:
# $\displaystyle Ls =\frac{1}{\left(b + s\right)^{2}} - \frac{1}{\left(a + s\right)^{2}}$

# %%
Ls.factor()
# Out:
# $\displaystyle Ls =\frac{\left(a - b\right) \left(a + b + 2 s\right)}{\left(a + s\right)^{2} \left(b + s\right)^{2}}$

# %%
func2laplace(Q) #''
# Out:
# $\displaystyle \mathcal{L} = \mathcal{L}_{t}\left[\frac{1}{t}\right]\left(a + s\right) - \mathcal{L}_{t}\left[\frac{1}{t}\right]\left(b + s\right)$
#                 ⎛1          ⎞                   ⎛1          ⎞
# LaplaceTransform⎜─, t, a + s⎟ - LaplaceTransform⎜─, t, b + s⎟
#                 ⎝t          ⎠                   ⎝t          ⎠

# %%
translaplacedivt(Q)
# Out:
# log(a + s) - log(b + s)

# %%
translaplacedivt(Q)
# Out:
# log(a + s) - log(b + s)

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)

# %% [markdown]
# ![imagen.png](attachment:dc3c3081-9fef-45f3-82f3-4da6f6d20e2e.png)

# %%
Q=MyEq((cos(t)-cosh(t))/t,'Q',var=t)
# Out:
# $\displaystyle Q =\frac{\cos{\left(t \right)} - \cosh{\left(t \right)}}{t}$

# %%
func2laplace(Q) #??
# Out:
# $\displaystyle \mathcal{L} = - \frac{\mathcal{L}_{t}\left[\frac{1}{t}\right]\left(s - 1\right)}{2} - \frac{\mathcal{L}_{t}\left[\frac{1}{t}\right]\left(s + 1\right)}{2} + \frac{\mathcal{L}_{t}\left[\frac{1}{t}\right]\left(s - i\right)}{2} + \frac{\mathcal{L}_{t}\left[\frac{1}{t}\right]\left(s + i\right)}{2}$
#                   ⎛1          ⎞                   ⎛1          ⎞
#   LaplaceTransform⎜─, t, s - 1⎟   LaplaceTransform⎜─, t, s + 1⎟   LaplaceTrans
#                   ⎝t          ⎠                   ⎝t          ⎠
# - ───────────────────────────── - ───────────────────────────── + ────────────
#                 2                               2
#
#     ⎛1          ⎞                   ⎛1          ⎞
# form⎜─, t, s - ⅈ⎟   LaplaceTransform⎜─, t, s + ⅈ⎟
#     ⎝t          ⎠                   ⎝t          ⎠
# ───────────────── + ─────────────────────────────
#   2                               2

# %%
translaplacedivt(Q)
# Out:
#      ⎛ 2    ⎞      ⎛ 2    ⎞
#   log⎝s  - 1⎠   log⎝s  + 1⎠
# - ─────────── + ───────────
#        2             2

# %%
translaplacedivt(Q)
# Out:
# log(a + s) - log(b + s)

# %%
inverse_laplace_transform((3*s-12)/(s*s+8),s,t)
# Out:
# (-3⋅√2⋅sin(2⋅√2⋅t) + 3⋅cos(2⋅√2⋅t))⋅θ(t)

# %%
inversa_Ls((3*s-12))
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 inversa_Ls((3*s-12))
#
# Cell In[22], line 9, in inversa_Ls(Q, kname, omega)
#       6     kres=inverse_laplace_transform(Q.ksym, s, t)
#       8 else:
# ----> 9     kres=inverse_laplace_transform(Q, s, t)
#      11 if omega==False:
#      12     sres = str(kres)
#
# UnboundLocalError: local variable 's' referenced before assignment

# %%
inversa_Ls??
# Out:
# Signature: inversa_Ls(Q, kname='', omega=False)
# Docstring: <no docstring>
# Source:
# def inversa_Ls(Q,kname='',omega=False):
#
#     if type(Q)==MyEq:
#         s = Q.var
#         t = Q.var1
#         kres=inverse_laplace_transform(Q.ksym, s, t)
#
#     else:
#         kres=inverse_laplace_transform(Q, var, var1)
#
#     if omega==False:
#         sres = str(kres)
#         kfind = 'Heaviside('+str(t)+')'
#         sres = sres.replace(kfind,'1')
#
#         kres = parse_expr(sres)
#         try:
#             kres = apart(expand(simplify(kres)))
#         except:
#             pass
#     if kname=='':
#         return kres
#     else:
#         nname=str(kname)
#         return MyEq(kres,nname,ktype='F')
# File:      d:\libaldo3\aaa\libaldo\lib_mydiff.py
# Type:      function

# %%
def eQinverselaplace(Q,kname='',omega=False):
    s,t=symbols('s t') 
    if type(Q)==MyEq:
        kres=inverse_laplace_transform(Q.ksym, s, t)       
    else:
        kres=inverse_laplace_transform(Q, s, t)
    
    if omega==False:
        sres = str(kres)
        kfind = 'Heaviside('+str(t)+')' 
        sres = sres.replace(kfind,'1')
        
        kres = parse_expr(sres)
        try:
            kres = apart(expand(simplify(kres)))
        except:
            pass
    if kname=='':
        return kres
    else:    
        return MyEq(kres,kname=kname,var=t)

# %%
L=MyEq((3*s-12)/(s*s+8),'L')
# Out:
# $\displaystyle L =\frac{3 s - 12}{s^{2} + 8}$

# %%
Ls=eQinverselaplace(L,'Ls')
# Out:
# $\displaystyle Ls =- 3 \sqrt{2} \sin{\left(2 \sqrt{2} t \right)} + 3 \cos{\left(2 \sqrt{2} t \right)}$
