# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %% [markdown]
# ![image.png](attachment:adc10cff-69f7-4e00-81e9-c943d447579a.png)

# %%
from  libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:ef292e26-40c9-467b-9293-3a9c09641bff.png)

# %%
z=a+b*I

# %%
(z+conjugada(z))/2
# Out:
# a

# %%
rpart(z)
# Out:
# a

# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %%
from  libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:f9971227-7736-48c8-844b-fab01a784e09.png)

# %%
z=a+b*I

# %%
(z-conjugada(z))/(2*I)
# Out:
# b

# %%
ipart(z)
# Out:
# b

# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %%
from  libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:3b5f5116-0250-41df-b589-b521f0e63c6a.png)

# %%
z=a+b*I
w=c+d*I

# %%
Q1=MyEq(z/(z+w),'Q1')
# Out:
# $\displaystyle Q1 =\frac{a + i b}{a + i b + c + i d}$

# %%
Q1.Div(a+c-(b+d)*I)
# Out:
# $\displaystyle Q1 =\frac{a + i b}{\left(a + c - i \left(b + d\right)\right) \left(a + i b + c + i d\right)}$

# %%
Q1.expand()
# Out:
# $\displaystyle Q1 =\frac{a}{a^{2} + 2 a c + b^{2} + 2 b d + c^{2} + d^{2}} + \frac{i b}{a^{2} + 2 a c + b^{2} + 2 b d + c^{2} + d^{2}}$

# %%
Q1.Mul(a+c-(b+d)*I)
# Out:
# $\displaystyle Q1 =\left(\frac{a}{a^{2} + 2 a c + b^{2} + 2 b d + c^{2} + d^{2}} + \frac{i b}{a^{2} + 2 a c + b^{2} + 2 b d + c^{2} + d^{2}}\right) \left(a + c - i \left(b + d\right)\right)$

# %%
Q1.numerexpand()
# Out:
# $\displaystyle Q1 =\frac{a^{2}}{a^{2} + 2 a c + b^{2} + 2 b d + c^{2} + d^{2}} + \frac{a c}{a^{2} + 2 a c + b^{2} + 2 b d + c^{2} + d^{2}} - \frac{i a d}{a^{2} + 2 a c + b^{2} + 2 b d + c^{2} + d^{2}} + \frac{b^{2}}{a^{2} + 2 a c + b^{2} + 2 b d + c^{2} + d^{2}} + \frac{i b c}{a^{2} + 2 a c + b^{2} + 2 b d + c^{2} + d^{2}} + \frac{b d}{a^{2} + 2 a c + b^{2} + 2 b d + c^{2} + d^{2}}$

# %%
p1=rpart(Q1());p1
# Out:
#                  2
#                 a                                  a⋅c
# ───────────────────────────────── + ───────────────────────────────── + ──────
#  2            2            2    2    2            2            2    2    2
# a  + 2⋅a⋅c + b  + 2⋅b⋅d + c  + d    a  + 2⋅a⋅c + b  + 2⋅b⋅d + c  + d    a  + 2
#
#            2
#           b                                  b⋅d
# ─────────────────────────── + ─────────────────────────────────
#         2            2    2    2            2            2    2
# ⋅a⋅c + b  + 2⋅b⋅d + c  + d    a  + 2⋅a⋅c + b  + 2⋅b⋅d + c  + d

# %%
Q2=MyEq(w/(z+w),'Q2')
# Out:
# $\displaystyle Q2 =\frac{c + i d}{a + i b + c + i d}$

# %%
Q2.Div(a+c-(b+d)*I)
# Out:
# $\displaystyle Q2 =\frac{c + i d}{\left(a + c - i \left(b + d\right)\right) \left(a + i b + c + i d\right)}$

# %%
Q2.expand()
# Out:
# $\displaystyle Q2 =\frac{c}{a^{2} + 2 a c + b^{2} + 2 b d + c^{2} + d^{2}} + \frac{i d}{a^{2} + 2 a c + b^{2} + 2 b d + c^{2} + d^{2}}$

# %%
Q2.Mul(a+c-(b+d)*I)
# Out:
# $\displaystyle Q2 =\left(\frac{c}{a^{2} + 2 a c + b^{2} + 2 b d + c^{2} + d^{2}} + \frac{i d}{a^{2} + 2 a c + b^{2} + 2 b d + c^{2} + d^{2}}\right) \left(a + c - i \left(b + d\right)\right)$

# %%
Q2.numerexpand()
# Out:
# $\displaystyle Q2 =\frac{a c}{a^{2} + 2 a c + b^{2} + 2 b d + c^{2} + d^{2}} + \frac{i a d}{a^{2} + 2 a c + b^{2} + 2 b d + c^{2} + d^{2}} - \frac{i b c}{a^{2} + 2 a c + b^{2} + 2 b d + c^{2} + d^{2}} + \frac{b d}{a^{2} + 2 a c + b^{2} + 2 b d + c^{2} + d^{2}} + \frac{c^{2}}{a^{2} + 2 a c + b^{2} + 2 b d + c^{2} + d^{2}} + \frac{d^{2}}{a^{2} + 2 a c + b^{2} + 2 b d + c^{2} + d^{2}}$

# %%
p2=rpart(Q2());p2
# Out:
#
#                a⋅c                                 b⋅d
# ───────────────────────────────── + ───────────────────────────────── + ──────
#  2            2            2    2    2            2            2    2    2
# a  + 2⋅a⋅c + b  + 2⋅b⋅d + c  + d    a  + 2⋅a⋅c + b  + 2⋅b⋅d + c  + d    a  + 2
#
#            2                                   2
#           c                                   d
# ─────────────────────────── + ─────────────────────────────────
#         2            2    2    2            2            2    2
# ⋅a⋅c + b  + 2⋅b⋅d + c  + d    a  + 2⋅a⋅c + b  + 2⋅b⋅d + c  + d

# %%
simplify(p1+p2)
# Out:
# 1

# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %%
from  libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:9375e698-5108-4f6b-99ce-a04418ae782b.png)

# %%
z=MyEq((3-2*I)/(-1+4*I),'z')
# Out:
# $\displaystyle z =\frac{\left(-1 - 4 i\right) \left(3 - 2 i\right)}{17}$

# %%
z.expand()
# Out:
# $\displaystyle z =- \frac{11}{17} - \frac{10 i}{17}$

# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)
