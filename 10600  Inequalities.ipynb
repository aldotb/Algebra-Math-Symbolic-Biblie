# %% [markdown]
# ![image.png](attachment:fe4d89c2-2fe0-4968-89ec-eacf08018c0b.png)

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)

# %% [markdown]
# ![image.png](attachment:14a3cf97-5117-4ba9-b9ce-bdb34bee0ebe.png)

# %% [markdown]
# ![image.png](attachment:9472e8f6-51b3-4232-a728-ca2228f19b34.png)

# %% [markdown]
# ![image.png](attachment:14a3cf97-5117-4ba9-b9ce-bdb34bee0ebe.png)

# %% [markdown]
# ![image.png](attachment:5a90b90a-efc1-4756-8a52-9fe376791887.png)

# %%
import sys
sys.path.append('Libaldo')
from  libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:a9796cb6-a0a3-42db-81ba-fa0ff6fa2e40.png)

# %%
Q=MyEqEq(4*x+1,'>',x+5,x)
# Out:
# $\displaystyle 4 x + 1 > x + 5$

# %%
Qr=Q.isolve('Qr')
# Out:
# $\displaystyle Qr =\frac{4}{3} < x \wedge x < \infty$

# %% [markdown]
# ![image.png](attachment:14a3cf97-5117-4ba9-b9ce-bdb34bee0ebe.png)

# %% [markdown]
# ![image.png](attachment:66e08457-b9e9-4014-83c7-626f2c04a9b4.png)

# %% [markdown]
# ![image.png](attachment:72ea7a0f-12a2-4913-a55f-d64c438a0587.png)![image.png](attachment:7f83d7ab-ba9b-46ee-a036-c91f679df1c3.png)

# %%
import sys
sys.path.append('Libaldo')
from  libaldomath  import *
# this cell will be initializing your variables

# %%
Q=MQ(abs(3*x+1),'<',4,x)
# Out:
# $\displaystyle \left|{3 x + 1}\right| < 4$

# %%
Qr=Q.isolve('Qr')
# Out:
# $\displaystyle Qr =- \frac{5}{3} < x \wedge x < 1$

# %% [markdown]
# ![image.png](attachment:14a3cf97-5117-4ba9-b9ce-bdb34bee0ebe.png)

# %%
import sys
sys.path.append('Libaldo')
from  libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:4a335489-b5c7-40da-ab95-bd3ea2ae565a.png)

# %%
Q=MQ(abs(3*x-4),'>',2)
# Out:
# $\displaystyle \left|{3 x - 4}\right| > 2$

# %%
Qr=Q.isolve('Qr')
# Out:
# $\displaystyle Qr =\left(-\infty < x \wedge x < \frac{2}{3}\right) \vee \left(2 < x \wedge x < \infty\right)$

# %% [markdown]
# ![image.png](attachment:14a3cf97-5117-4ba9-b9ce-bdb34bee0ebe.png)

# %% [markdown]
# ![image.png](attachment:fb7eb918-643c-4148-bfa6-44591dc9b733.png)

# %%
import sys
sys.path.append('Libaldo')
from  libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:e5615058-40ea-41d9-a9c3-6a5c29f47ae0.png)

# %%
Q=MQ((t+1)/(3*t-6),'>',0,var=t)
# Out:
# $\displaystyle \frac{t + 1}{3 t - 6} > 0$

# %%
Qr=Q.isolve('Qr')
# Out:
# $\displaystyle Qr =\left(-\infty < t \wedge t < -1\right) \vee \left(2 < t \wedge t < \infty\right)$

# %% [markdown]
# ![image.png](attachment:14a3cf97-5117-4ba9-b9ce-bdb34bee0ebe.png)

# %% [markdown]
# ![image.png](attachment:e0116771-3410-41a7-91d0-92547eac0563.png)

# %% [markdown]
# ![image.png](attachment:dc8b7c06-950c-424e-8c15-c690b557d0b3.png)

# %%
import sys
sys.path.append('Libaldo')
from  libaldomath  import *
# this cell will be initializing your variables

# %%
Q=MQ((2*z+1)**2,'>',9,var=z)
# Out:
# $\displaystyle \left(2 z + 1\right)^{2} > 9$

# %%
Qr=Q.isolve('Qr')
# Out:
# $\displaystyle Qr =\left(-\infty < z \wedge z < -2\right) \vee \left(1 < z \wedge z < \infty\right)$

# %% [markdown]
# ![image.png](attachment:14a3cf97-5117-4ba9-b9ce-bdb34bee0ebe.png)

# %% [markdown]
# ![image.png](attachment:2e6c708a-f1ce-42d3-9000-54e819d4d61c.png)

# %% [markdown]
# ![image.png](attachment:65013c20-c6f5-4506-b93a-df60509d0acd.png)

# %%
import sys
sys.path.append('Libaldo')
from  libaldomath  import *
# this cell will be initializing your variables

# %%
Q=MQ(x**2+2*x-3,'>',0)
# Out:
# $\displaystyle x^{2} + 2 x - 3 > 0$

# %%
Qr=Q.isolve('Qr')
# Out:
# $\displaystyle Qr =\left(-\infty < x \wedge x < -3\right) \vee \left(1 < x \wedge x < \infty\right)$

# %% [markdown]
# ![image.png](attachment:14a3cf97-5117-4ba9-b9ce-bdb34bee0ebe.png)
