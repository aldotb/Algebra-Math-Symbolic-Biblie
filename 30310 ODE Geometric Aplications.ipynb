# %% [markdown]
# ![image.png](attachment:489bca0d-e38c-4178-8a51-589ac7d4de6e.png)

# %% [markdown]
# ![image.png](attachment:77c33f88-b113-49d6-b0ba-71608aff6ee6.png)

# %% [markdown]
# ![image.png](attachment:1cc8560e-d931-43d9-8071-7d95b8be3a28.png)

# %% [markdown]
# ![image.png](attachment:54654d5a-8fdd-475a-8fcb-93e0f8a4c6ed.png)

# %% [markdown]
# ![image.png](attachment:005efca0-3597-4506-8d23-978be5d4e672.png)

# %% [markdown]
# ![image.png](attachment:e017f3b2-58b1-43e5-a4f2-f852188d01c1.png)

# %% [markdown]
# ![image.png](attachment:134bc3cc-2402-46bc-9d16-b4cf7e329728.png)

# %% [markdown]
# ![image.png](attachment:9f05444b-c4c8-49cc-92b5-c87e9b9f5e16.png)

# %% [markdown]
# ![image.png](attachment:3fd371f6-7006-4730-a55a-cd94ffcb7188.png)

# %%
from libaldomath import *
from lib_MyDiff  import *

# %% [markdown]
# ![image.png](attachment:489bca0d-e38c-4178-8a51-589ac7d4de6e.png)

# %% [markdown]
# ![image.png](attachment:f80f4540-0d67-43ed-a744-45e5352be2b2.png)

# %% [markdown]
# ![image.png](attachment:2a902dbf-288d-4d16-bff1-cc53b27e35d4.png)

# %%
Q=MQ(dy/dx,2*y/x)
# Out:
# $\displaystyle \frac{y'}{x'} = \frac{2 y}{x}$

# %%
Q.Mul(dx/y)
# Out:
# $\displaystyle \frac{y'}{y} = \frac{2 x'}{x}$

# %%
Q.integral(y,x)
# Out:
# $\displaystyle \int \frac{1}{y}\, dy = \int \frac{2}{x}\, dx$

# %%
Q.doit()
# Out:
# $\displaystyle \log{\left(y \right)} = C_{1} + 2 \log{\left(x \right)}$

# %%
Q.exp()
# Out:
# $\displaystyle y = x^{2} e^{C_{1}}$

# %%
Q.subs(exp(C1),C)
# Out:
# $\displaystyle y = C x^{2}$

# %%
from libaldomath import *
from lib_MyDiff  import *

# %% [markdown]
# ![image.png](attachment:489bca0d-e38c-4178-8a51-589ac7d4de6e.png)

# %% [markdown]
# ![image.png](attachment:5767bc8b-df2e-4ebc-8917-aeca8c8d207e.png)

# %% [markdown]
# ![image.png](attachment:32c88947-a454-447e-9570-a7d2c848fb17.png)

# %% [markdown]
# ![image.png](attachment:c612426d-9851-4409-86f3-889f2281b411.png)

# %%
Q=MQ(y*dy,a*dx)
# Out:
# $\displaystyle y y' = a x'$

# %%
Q.integral(y,x)
# Out:
# $\displaystyle \int y\, dy = \int a\, dx$

# %%
Q.doit()
# Out:
# $\displaystyle \frac{y^{2}}{2} = C_{1} + a x$

# %% [markdown]
# ![image.png](attachment:489bca0d-e38c-4178-8a51-589ac7d4de6e.png)

# %%
from libaldomath import *
from lib_MyDiff  import *

# %% [markdown]
# ![image.png](attachment:5b73eb72-da84-4eac-b770-4607e2a5d173.png)

# %%
Q=MQ((x-b/m)/2,-0)
# Out:
# $\displaystyle - \frac{b}{2 m} + \frac{x}{2} = 0$

# %%
Q.alone(x)
# Out:
# $\displaystyle x = \frac{b}{m}$

# %%
Q2=MQ(y/2,b)
# Out:
# $\displaystyle \frac{y}{2} = b$

# %%
Q3=MQ(y/2,-x*dx/dy)
# Out:
# $\displaystyle \frac{y}{2} = - \frac{x x'}{y'}$

# %%
Q3.crossmul()
# Out:
# $\displaystyle y y' = - 2 x x'$

# %%
Q3.integral(y,x)
# Out:
# $\displaystyle \int y\, dy = \int \left(- 2 x\right)\, dx$

# %%
Q3.doit()
# Out:
# $\displaystyle \frac{y^{2}}{2} = C_{1} - x^{2}$

# %%
Q3=MQ(y/2,-x*dx/dy)

# %%
dQ=MyDiff("y'*y(x)/2","-x",x,y)
# Out:
# $\displaystyle \frac{y y'}{2} = - x$

# %%
dQ.dsolve()
# Out:
# ⎡           ___________            ___________⎤
# ⎢          ╱         2            ╱         2 ⎥
# ⎣y(x) = -╲╱  C₁ - 2⋅x  , y(x) = ╲╱  C₁ - 2⋅x  ⎦

# %% [markdown]
# ![image.png](attachment:5836d9e5-ee73-4ffd-9ad3-d67331fd14bc.png)

# %% [markdown]
# ![image.png](attachment:489bca0d-e38c-4178-8a51-589ac7d4de6e.png)

# %%
from libaldomath import *
from lib_MyDiff  import *

# %% [markdown]
# ![image.png](attachment:f9813350-0f32-4321-b7d8-77cf78014afe.png)

# %%
Q=MQ(-dx/dy,(y-k)/(x-h))
# Out:
# $\displaystyle - \frac{x'}{y'} = \frac{- k + y}{- h + x}$

# %%
Q.crossmul()
# Out:
# $\displaystyle - x' \left(- h + x\right) = y' \left(- k + y\right)$

# %%
Q.swap()
# Out:
# $\displaystyle y' \left(- k + y\right) = - x' \left(- h + x\right)$

# %%
Q.integral(y,x)
# Out:
# $\displaystyle \int \left(- k + y\right)\, dy = \int \left(h - x\right)\, dx$

# %%
Q.doit()
# Out:
# $\displaystyle - k y + \frac{y^{2}}{2} = C_{1} + h x - \frac{x^{2}}{2}$

# %%
Q.Mul(2)
# Out:
# $\displaystyle y \left(- 2 k + y\right) = 2 C_{1} + 2 h x - x^{2}$

# %%
Q.all2L()
# Out:
# $\displaystyle - 2 C_{1} - 2 h x + x^{2} - y \left(2 k - y\right) = 0$

# %%
Q.Add(2*C1)
# Out:
# $\displaystyle - 2 h x + x^{2} - y \left(2 k - y\right) = 2 C_{1}$

# %%
Q.expand()
# Out:
# $\displaystyle - 2 h x - 2 k y + x^{2} + y^{2} = 2 C_{1}$

# %%
Q.Add(h*h+k*k)
# Out:
# $\displaystyle h^{2} - 2 h x + k^{2} - 2 k y + x^{2} + y^{2} = 2 C_{1} + h^{2} + k^{2}$

# %%
Q.trinom2binom(x*x-2*h*x+h*h)
# Out:
# $\displaystyle k^{2} - 2 k y + y^{2} + \left(- h + x\right)^{2} = 2 C_{1} + h^{2} + k^{2}$

# %%
Q.setR(C)
# Out:
# $\displaystyle \left(- h + x\right)^{2} + \left(- k + y\right)^{2} = C$

# %% [markdown]
# ![image.png](attachment:489bca0d-e38c-4178-8a51-589ac7d4de6e.png)
