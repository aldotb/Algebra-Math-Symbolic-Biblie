# %% [markdown]
# ![image.png](attachment:20e0cd2a-95b2-4f69-8c93-5299e944d921.png)

# %%
from  Libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:73517cb3-98da-4c40-8d77-21db4972fcb9.png)

# %% [markdown]
# ![image.png](attachment:c57d27b3-20b4-4d53-ab1f-be68e4e10533.png)

# %%
P=MyEq(x**8+a*x**4+b,'P')
d=MyEq(x*x+x+1,'d')
# Out:
# $\displaystyle P =a x^{4} + b + x^{8}$
# $\displaystyle d =x^{2} + x + 1$

# %%
P.rem(d) # remainder
# Out:
# a⋅x + b - x - 1

# %%
R=MyEq(P.rem(d),'R')
# Out:
# $\displaystyle R =a x + b - x - 1$

# %%
R.coef_list(x)
# Out:
# [a - 1, b - 1]

# %%
a,b=simplesolve(R.coef_list(x),'eQ')
# Out:
# $\displaystyle a =1$
# $\displaystyle b =1$

# %% [markdown]
# ![image.png](attachment:9ae86b6b-f45c-46fc-be16-7c5fdc1f36a8.png)

# %%
from  Libaldomath import *  # this cell will be initializing your variables
# for hrlp run helpgui

# %% [markdown]
# ![image.png](attachment:73517cb3-98da-4c40-8d77-21db4972fcb9.png)

# %% [markdown]
# ![image.png](attachment:d6503bb3-2cfe-4a77-a2ae-38f1ca228fda.png)

# %%
P=MyEq(2*x**5+3*x**4+b*x**3+6*b*x*x+x+a,'P')
d=MyEq(x*x-x+b,'d')
R=MyEq(2*x+3,'R')
# Out:
# $\displaystyle P =a + b x^{3} + 6 b x^{2} + 2 x^{5} + 3 x^{4} + x$
# $\displaystyle d =b + x^{2} - x$
# $\displaystyle R =2 x + 3$

# %%
R1=P.rem(d,'R1') # some function if put string at last return a new MyEq called strig
# Out:
# $\displaystyle R1 =a + b^{2} x - 5 b x - 5 b + 6 x$

# %%
A=MyEq(R-R1,'A')
# Out:
# $\displaystyle A =- a - b^{2} x + 5 b x + 5 b - 4 x + 3$

# %%
vec=A.coef_list(x)
vec
# Out:
# ⎡   2                        ⎤
# ⎣- b  + 5⋅b - 4, -a + 5⋅b + 3⎦

# %%
b1,b2,a1,a2=simplesolve(vec,'eQ')
# Out:
# $\displaystyle b0 =1$
# $\displaystyle b1 =4$
# $\displaystyle a0 =8$
# $\displaystyle a1 =23$

# %% [markdown]
# ![image.png](attachment:9ae86b6b-f45c-46fc-be16-7c5fdc1f36a8.png)

# %%
from  Libaldomath import *  # this cell will be initializing your variables
# for hrlp run helpgui

# %% [markdown]
# ![image.png](attachment:73517cb3-98da-4c40-8d77-21db4972fcb9.png)

# %% [markdown]
# ![image.png](attachment:59d8de30-86f0-45ae-b572-58aeeba0fbc7.png)

# %%
P=MyEq(n*x**5+m*x**4+16*x**3-9*x*x+x+10,'P')
d1=MyEq(x-1,'d1')
d2=MyEq(3*x+2,'d2')
# Out:
# $\displaystyle P =m x^{4} + n x^{5} + 16 x^{3} - 9 x^{2} + x + 10$
# $\displaystyle d1 =x - 1$
# $\displaystyle d2 =3 x + 2$

# %%
R1=P.rem(d1,'R1')
R2=P.rem(d2,'R2')
# Out:
# $\displaystyle R1 =m + n + 18$
# $\displaystyle R2 =\frac{16 m}{81} - \frac{32 n}{243} + \frac{16}{27}$

# %%
m=R1.solve('m')
# Out:
# $\displaystyle m =- n - 18$

# %%
R2.set(m)
# Out:
# $\displaystyle R2 =- \frac{80 n}{243} - \frac{80}{27}$

# %%
n=R2.solve('n')
# Out:
# $\displaystyle n =-9$

# %%
m.set(n)
# Out:
# $\displaystyle m =-9$

# %%
from  Libaldomath  import *
# for help run helpgui

# %% [markdown]
# ![image.png](attachment:73517cb3-98da-4c40-8d77-21db4972fcb9.png)

# %% [markdown]
# ![image.png](attachment:a8f12cec-dd33-48ec-8553-e148a8859263.png)

# %%
F=MyEq(a*x**3+b*x*x+c*x+d,'F')
D1=MyEq(x*x+3,'D1')
D2=MyEq(x*x+6,'D2')
R1=MyEq(2*x+1,'R1')
R2=MyEq(3*x+1,'R2')
# Out:
# $\displaystyle F =a x^{3} + b x^{2} + c x + d$
# $\displaystyle D1 =x^{2} + 3$
# $\displaystyle D2 =x^{2} + 6$
# $\displaystyle R1 =2 x + 1$
# $\displaystyle R2 =3 x + 1$

# %%
Q1=MQ(F.rem(D1),R1)
# Out:
# $\displaystyle - 3 a x - 3 b + c x + d = 2 x + 1$

# %%
vec=Q1.coef_list()
vec
# Out:
# ([-3⋅a + c, -3⋅b + d], [2, 1])

# %%
vec2=[data1-data2 for data1,data2 in zip(vec[0],vec[1])]
vec2
# Out:
# [-3⋅a + c - 2, -3⋅b + d - 1]

# %%
a,b=simplesolve(vec2[0],vec2[1],a,b,'eQ')
# Out:
# $\displaystyle a =\frac{c}{3} - \frac{2}{3}$
# $\displaystyle b =\frac{d}{3} - \frac{1}{3}$

# %%
F.set(a,b)
# Out:
# $\displaystyle F =c x + d + x^{3} \left(\frac{c}{3} - \frac{2}{3}\right) + x^{2} \left(\frac{d}{3} - \frac{1}{3}\right)$

# %%
F.expand()
# Out:
# $\displaystyle F =\frac{c x^{3}}{3} + c x + \frac{d x^{2}}{3} + d - \frac{2 x^{3}}{3} - \frac{x^{2}}{3}$

# %%
Q2=MQ(F.rem(D2),R2)
# Out:
# $\displaystyle - c x - d + 4 x + 2 = 3 x + 1$

# %%
vec2=Q2.coef_list()
vec2
# Out:
# ([4 - c, 2 - d], [3, 1])

# %%
vec3=[data1-data2 for data1,data2 in zip(vec2[0],vec2[1])]
vec3
# Out:
# [1 - c, 1 - d]

# %%
F.set(c=1,d=1)
# Out:
# $\displaystyle F =- \frac{x^{3}}{3} + x + 1$

# %% [markdown]
# ![image.png](attachment:982fb008-2f80-4bc9-9c92-c9625b779bc2.png)

# %% [markdown]
# ![image.png](attachment:9ae86b6b-f45c-46fc-be16-7c5fdc1f36a8.png)

# %%
from  Libaldomath  import *
# for hrlp run helpgui

# %% [markdown]
# ![image.png](attachment:73517cb3-98da-4c40-8d77-21db4972fcb9.png)

# %% [markdown]
# ![image.png](attachment:a4e54983-7bad-43ac-85ac-379799b5760c.png)

# %%
P=MyEq(3*x**4+a*x**3+b*x*x+c*x+d,'P')
D1=MyEq(x*x+1,'D1')
D2=MyEq(x-2,'D2')
D=MyEq(x*x-1,'D')
# Out:
# $\displaystyle P =a x^{3} + b x^{2} + c x + d + 3 x^{4}$
# $\displaystyle D1 =x^{2} + 1$
# $\displaystyle D2 =x - 2$
# $\displaystyle D =x^{2} - 1$

# %%
R1=P.rem(D1,'R1')
# Out:
# $\displaystyle R1 =- a x - b + c x + d + 3$

# %%
R1.factoriza(x)
# Out:
# $\displaystyle R1 =- b + d + x \left(- a + c\right) + 3$

# %%
P.set(a=c)
# Out:
# $\displaystyle P =b x^{2} + c x^{3} + c x + d + 3 x^{4}$

# %%
R1=P.rem(D1,'R1')
# Out:
# $\displaystyle R1 =- b + d + 3$

# %%
P.set(b=d+3)
# Out:
# $\displaystyle P =c x^{3} + c x + d + 3 x^{4} + x^{2} \left(d + 3\right)$

# %%
R2=P.rem(D2,'R2')
# Out:
# $\displaystyle R2 =10 c + 5 d + 60$

# %%
R2.Div(5)
# Out:
# $\displaystyle R2 =2 c + d + 12$

# %%
P.set(d=-12-2*c)
# Out:
# $\displaystyle P =c x^{3} + c x - 2 c + 3 x^{4} + x^{2} \left(- 2 c - 9\right) - 12$

# %%
q=MyEq(3*x*x+m*x-m-3,'q')
# Out:
# $\displaystyle q =m x - m + 3 x^{2} - 3$

# %%
Q2=MQ(P,q*D1)
# Out:
# $\displaystyle c x^{3} + c x - 2 c + 3 x^{4} + x^{2} \left(- 2 c - 9\right) - 12 = \left(x^{2} + 1\right) \left(m x - m + 3 x^{2} - 3\right)$

# %%
Q2.expand()
# Out:
# $\displaystyle c x^{3} - 2 c x^{2} + c x - 2 c + 3 x^{4} - 9 x^{2} - 12 = m x^{3} - m x^{2} + m x - m + 3 x^{4} - 3$

# %%
Q3=MQ(coef_list(Q2.L,x)[2],coef_list(Q2.R,x)[2])
# Out:
# $\displaystyle - 2 c - 9 = - m$

# %%
Q4=MQ(coef_list(Q2.L,x)[1],coef_list(Q2.R,x)[1])
# Out:
# $\displaystyle c = m$

# %%
Q3.set(m=c)
# Out:
# $\displaystyle - 2 c - 9 = - c$

# %%
c=Q3.solve(c)
# Out:
# $\displaystyle c=-9$

# %%
P.set(c=-9)
# Out:
# $\displaystyle P =3 x^{4} - 9 x^{3} + 9 x^{2} - 9 x + 6$

# %% [markdown]
# ![image.png](attachment:9ae86b6b-f45c-46fc-be16-7c5fdc1f36a8.png)

# %%
from  Libaldomath  import *
# for hrlp run helpgui

# %% [markdown]
# ![image.png](attachment:73517cb3-98da-4c40-8d77-21db4972fcb9.png)

# %% [markdown]
# ![image.png](attachment:c0c330dd-4401-405b-a100-767213ed7c99.png)

# %%
#P=MyEq(a*x**3+b*x*x+c*x+d,'P')
Q=MyEq(x+b,'Q',var=x)
# Out:
# $\displaystyle Q =b + x$

# %%
A=MQ(P,Q*(x*x+5)+2*x-5)
# Out:
# $\displaystyle P = 2 x + \left(b + x\right) \left(x^{2} + 5\right) - 5$

# %%
A.expand()
# Out:
# $\displaystyle P = b x^{2} + 5 b + x^{3} + 7 x - 5$

# %%
B=MQ(Q.rem(x+2),4)
# Out:
# $\displaystyle b - 2 = 4$

# %%
b=B.solve(b)
# Out:
# $\displaystyle b=6$

# %%
A.set(b=6)
# Out:
# $\displaystyle P = x^{3} + 6 x^{2} + 7 x + 25$

# %%
P=A.solve('P')
# Out:
# $\displaystyle P =x^{3} + 6 x^{2} + 7 x + 25$

# %%
P.rem(x+2)
# Out:
# 27
