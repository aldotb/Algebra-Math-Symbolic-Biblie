# %% [markdown]
# ![image.png](attachment:20e0cd2a-95b2-4f69-8c93-5299e944d921.png)

# %% [markdown]
# ![image.png](attachment:fe4d89c2-2fe0-4968-89ec-eacf08018c0b.png)

# %%
 
from Libaldomath  import *
# this cell will be initializing your variables
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from Libaldomath  import *

# %% [markdown]
# ![image.png](attachment:20e0cd2a-95b2-4f69-8c93-5299e944d921.png)

# %%
# classic metohode
solve(x+2,x)
# Out:
# [-2]

# %%
# usin MyEq and MyEqEq
Q=MyEq(3*x*y+x+2,'Q')
# Out:
# $\displaystyle Q =3 x y + x + 2$

# %%
x=Q.solve(x) # solve(x) return the value of variable finding
# Out:
# $\displaystyle x =- \frac{2}{3 y + 1}$

# %%
# what is the difference of these methode... see beloww..
# x(y=2)   this jump error..because x is a symbol variables..but...

# %%
x=Q.solve('x')
# Out:
# $\displaystyle x =- \frac{2}{3 y + 1}$

# %%
x(y=3)
# Out:
# -1/5

# %% [markdown]
# ![image.png](attachment:20e0cd2a-95b2-4f69-8c93-5299e944d921.png)

# %%
from Libaldomath import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:73517cb3-98da-4c40-8d77-21db4972fcb9.png)

# %% [markdown]
# ![image.png](attachment:bb60df4d-4679-42ad-9091-489bd8f21732.png)

# %%
P=MyEq(x*x-6*x+c,'P')
# Out:
# $\displaystyle P =c + x^{2} - 6 x$

# %%
P.solve(x)
# Out:
# $\displaystyle x =3 - \sqrt{9 - c}$
# 3 - sqrt(9 - c)

# %%
A=MyEq(x+4,'A')
# Out:
# $\displaystyle A =x + 4$

# %%
A.simplesolve(x)
# Out:
# -4

# %%
P.simplesolve(x)
# Out:
#       _______
# 3 - ╲╱ 9 - c

# %%
eqSolve(P.ksym,x)
# Out:
# $\displaystyle x1 =3 - \sqrt{9 - c}$
# $\displaystyle x2 =\sqrt{9 - c} + 3$
# ⎡      _______    _______    ⎤
# ⎣3 - ╲╱ 9 - c , ╲╱ 9 - c  + 3⎦

# %%
simplesolve(P(),x)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 simplesolve(P(),x)
#
# File D:\Libaldo2\Algebra-Math-Symbolic-Biblie-main\Libaldo\lib_MyFunctions.py:26, in simplesolve(kshow, *args, **kwargs)
#      25 def simplesolve(*args,kshow=True,**kwargs):
# ---> 26     return simplesolve2(*args,kshow=True,**kwargs)
#
# File D:\Libaldo2\Algebra-Math-Symbolic-Biblie-main\Libaldo\lib_MyFunctions.py:130, in simplesolve2(kshow, *args, **kwargs)
#     128         lvalor=list(kres[i])
#     129         nvecval.append(lvalor[i])
# --> 130         nvecname.append(vecname[i]+str(i+1))
#     131 sname=nvecname
#     132 vvar=nvecval
#
# UnboundLocalError: local variable 'vecname' referenced before assignment

# %%
a,b=P.solve('x')
# Out:
# $\displaystyle x =3 - \sqrt{9 - c}$
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 a,b=P.solve('x')
#
# TypeError: cannot unpack non-iterable MyEq object

# %%
P.expand()
# Out:
# $\displaystyle c + x^{2} - 6 x = a b - a x - b x + x^{2}$

# %%
P.coef_list()
# Out:
# ([1, -6, c], [1, -a - b, a⋅b])

# %%
Q=MQ(a+b,6) #a*b=c
P=MQ((a*a+b*b+2*c)/9,0)
# Out:
# $\displaystyle a + b = 6$
# $\displaystyle \frac{a^{2}}{9} + \frac{b^{2}}{9} + \frac{2 c}{9} = 0$

# %%
Q.Pow(2)
# Out:
# $\displaystyle \left(a + b\right)^{2} = 36$

# %%
Q.expand()
# Out:
# $\displaystyle a^{2} + 2 a b + b^{2} = 36$

# %%
Q.Substrac(2*a*b)
# Out:
# $\displaystyle a^{2} + b^{2} = - 2 a b + 36$

# %%
P.Mul(9)
# Out:
# $\displaystyle a^{2} + b^{2} + 2 c = 0$

# %%
P.Substrac(2*c)
# Out:
# $\displaystyle a^{2} + b^{2} = - 2 c$

# %%
Q1.expand()
# Out:
# $\displaystyle Q1 =a^{2} + 2 a b + b^{2}$

# %%
R=MyEq((a*a+b*b+2*c)/9,'R')
# Out:
# $\displaystyle R =\frac{a^{2}}{9} + \frac{b^{2}}{9} + \frac{2 c}{9}$

# %%
R.set(c=a*b)
# Out:
# $\displaystyle R =\frac{a^{2}}{9} + \frac{2 a b}{9} + \frac{b^{2}}{9}$

# %%
R.factor()
# Out:
# $\displaystyle R =\frac{\left(a + b\right)^{2}}{9}$

# %%
R.subsubs(a+b,6)
# Out:
# $\displaystyle R =4$

# %% [markdown]
# ![image.png](attachment:20e0cd2a-95b2-4f69-8c93-5299e944d921.png)

# %%
from Libaldomath import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:73517cb3-98da-4c40-8d77-21db4972fcb9.png)

# %% [markdown]
# ![image.png](attachment:d36392dc-6913-4870-bebf-bc88922efb57.png)

# %%
q=symbols('q')
P=MQ(x*x+2*b*x+2*c,(x-p)*(x-q))
# Out:
# $\displaystyle 2 b x + 2 c + x^{2} = \left(- p + x\right) \left(- q + x\right)$

# %%
P.expand()
# Out:
# $\displaystyle 2 b x + 2 c + x^{2} = p q - p x - q x + x^{2}$

# %%
p,q=solvecoefflist(P,p,q)
# Out:
# $\displaystyle p= - b - \sqrt{b^{2} - 2 c}$
# $\displaystyle q= - b + \sqrt{b^{2} - 2 c}$

# %%
R=MyEq(1/(p*p)+1/(q*q),'R')
# Out:
# $\displaystyle R =\frac{1}{\left(- b + \sqrt{b^{2} - 2 c}\right)^{2}} + \frac{1}{\left(- b - \sqrt{b^{2} - 2 c}\right)^{2}}$

# %%
R.expand()
# Out:
# $\displaystyle R =\frac{1}{2 b^{2} + 2 b \sqrt{b^{2} - 2 c} - 2 c} + \frac{1}{2 b^{2} - 2 b \sqrt{b^{2} - 2 c} - 2 c}$

# %%
R.factor()
# Out:
# $\displaystyle R =\frac{b^{2} - c}{\left(b^{2} - b \sqrt{b^{2} - 2 c} - c\right) \left(b^{2} + b \sqrt{b^{2} - 2 c} - c\right)}$

# %%
R.expand()
# Out:
# $\displaystyle R =\frac{b^{2}}{c^{2}} - \frac{1}{c}$

# %%
R.factor()
# Out:
# $\displaystyle R =\frac{b^{2} - c}{c^{2}}$

# %% [markdown]
# ![image.png](attachment:20e0cd2a-95b2-4f69-8c93-5299e944d921.png)

# %%
from Libaldomath import *

# %% [markdown]
# ![image.png](attachment:73517cb3-98da-4c40-8d77-21db4972fcb9.png)

# %% [markdown]
# ![image.png](attachment:4aa4fcc0-8f6d-4df1-baa7-df2f5d2d7bfc.png)

# %%
r2=(r1+2)/3

# %%
q=symbols('q')
P=MQ(x*x-2*n*x+n*n-4,(x-r1)*(x-r2))
# Out:
# $\displaystyle n^{2} - 2 n x + x^{2} - 4 = \left(- r_{1} + x\right) \left(- \frac{r_{1}}{3} + x - \frac{2}{3}\right)$

# %%
P.expand()
# Out:
# $\displaystyle n^{2} - 2 n x + x^{2} - 4 = \frac{r_{1}^{2}}{3} - \frac{4 r_{1} x}{3} + \frac{2 r_{1}}{3} + x^{2} - \frac{2 x}{3}$

# %%
P.Mul(3)
# Out:
# $\displaystyle 3 n^{2} - 6 n x + 3 x^{2} - 12 = r_{1}^{2} - 4 r_{1} x + 2 r_{1} + 3 x^{2} - 2 x$

# %%
P.sortdegree(x)
# Out:
# $\displaystyle 3 n^{2} - 6 n x + 3 x^{2} - 12 = r_{1}^{2} + 2 r_{1} + 3 x^{2} + x \left(- 4 r_{1} - 2\right)$

# %%
r1,n=solvecoefflist(P,r1,n)
# Out:
# $\displaystyle r1= -5$
# $\displaystyle n= -3$

# %%
R=MyEq(1/(p*p)+1/(q*q),'R')
# Out:
# $\displaystyle R =\frac{1}{q^{2}} + \frac{1}{p^{2}}$

# %%
R.expand()
# Out:
# $\displaystyle R =\frac{1}{q^{2}} + \frac{1}{p^{2}}$

# %%
R.factor()
# Out:
# $\displaystyle R =\frac{p^{2} + q^{2}}{p^{2} q^{2}}$

# %%
R.expand()
# Out:
# $\displaystyle R =\frac{1}{q^{2}} + \frac{1}{p^{2}}$

# %%
R.factor()
# Out:
# $\displaystyle R =\frac{p^{2} + q^{2}}{p^{2} q^{2}}$

# %% [markdown]
# ![image.png](attachment:20e0cd2a-95b2-4f69-8c93-5299e944d921.png)

# %%
from Libaldomath import *

# %% [markdown]
# ![image.png](attachment:73517cb3-98da-4c40-8d77-21db4972fcb9.png)

# %% [markdown]
# ![image.png](attachment:aa0da48b-c2a4-4fe8-9154-7aaa032885a0.png)

# %%
q=symbols('q')
P=MQ(x*x+p*x+q,(x-r)*(x-s))
# Out:
# $\displaystyle p x + q + x^{2} = \left(- r + x\right) \left(- s + x\right)$

# %%
P.expand()
# Out:
# $\displaystyle p x + q + x^{2} = r s - r x - s x + x^{2}$

# %%
Q1=MQ(r*r-s*s,32)
Q2=MQ(r-s,4)
# Out:
# $\displaystyle r^{2} - s^{2} = 32$
# $\displaystyle r - s = 4$

# %%
r,s=simplesolve(Q1,Q2,'eq')
# Out:
# $\displaystyle r =6$
# $\displaystyle s =2$

# %%
P.set(s,r)
# Out:
# $\displaystyle p x + q + x^{2} = x^{2} - 8 x + 12$

# %%
q,p=solvecoefflist(P)
# Out:
# $\displaystyle q= 12$
# $\displaystyle p= -8$

# %%
p*p/(q*q)
# Out:
# 4/9

# %% [markdown]
# ![image.png](attachment:20e0cd2a-95b2-4f69-8c93-5299e944d921.png)

# %%
from Libaldomath import *

# %% [markdown]
# ![image.png](attachment:73517cb3-98da-4c40-8d77-21db4972fcb9.png)

# %% [markdown]
# ![image.png](attachment:5b456c0a-bee8-4e7b-8d13-3587ba9d6c53.png)

# %% [markdown]
# ![image.png](attachment:20e0cd2a-95b2-4f69-8c93-5299e944d921.png)

# %%
A1=MyEq(pi*L*L*alpha/360,'A1')
# Out:
# $\displaystyle A1 =\frac{\pi L^{2} \alpha}{360}$

# %%
L2=L+10
A2=MyEq(pi*L2*L2*alpha/360,'A2')
# Out:
# $\displaystyle A2 =\frac{\pi \alpha \left(L + 10\right)^{2}}{360}$

# %%
Q=MQ(4*A1,A2)
# Out:
# $\displaystyle \frac{\pi L^{2} \alpha}{90} = \frac{\pi \alpha \left(L + 10\right)^{2}}{360}$

# %%
Q.crossMul()
# Out:
# $\displaystyle 360 \pi L^{2} \alpha = 90 \pi \alpha \left(L + 10\right)^{2}$

# %%
Q.Div(pi*90*alpha)
# Out:
# $\displaystyle 4 L^{2} = \left(L + 10\right)^{2}$

# %%
Q.Rpow(2)
# Out:
# $\displaystyle \left(4 L^{2}\right)^{\frac{1}{2}} = \left(\left(L + 10\right)^{2}\right)^{\frac{1}{2}}$

# %%
Q.rsimplify()
# Out:
# $\displaystyle \left(4 L^{2}\right)^{\frac{1}{2}} = \left(\left(L + 10\right)^{2}\right)^{\frac{1}{2}}$

# %%
L=Q.solve(L)
# Out:
# $\displaystyle L =- \frac{10}{3}$
