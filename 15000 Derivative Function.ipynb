# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %%
from  libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:8af0691b-0533-49f0-9e55-d7e1a47ca60e.png)

# %% [markdown]
# ![image.png](attachment:02c250eb-afc2-494d-b1c1-0b86775dd4c8.png)

# %% [markdown]
# ![image.png](attachment:34dace18-adb9-4c23-b5c4-c8ddd9971522.png)

# %%
P=MyEq(x**7+x**5+x**-3+4*x,'P',var=x)
# Out:
# $\displaystyle P =x^{7} + x^{5} + 4 x + \frac{1}{x^{3}}$

# %%
P.diff()
# Out:
#    6      4       3
# 7⋅x  + 5⋅x  + 4 - ──
#                    4
#                   x

# %%
dP=P.diff('dP')
# Out:
# $\displaystyle dP =7 x^{6} + 5 x^{4} + 4 - \frac{3}{x^{4}}$

# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %% [markdown]
# ![image.png](attachment:e2801c16-6e49-4f99-8633-c5aa847f594f.png)

# %%
P=MyEq((x**5+2*x)*(x**3+x*x+x+7),'P',var=x)
# Out:
# $\displaystyle P =\left(x^{5} + 2 x\right) \left(x^{3} + x^{2} + x + 7\right)$

# %%
P.diff()
# Out:
# ⎛   4    ⎞ ⎛ 3    2        ⎞   ⎛ 5      ⎞ ⎛   2          ⎞
# ⎝5⋅x  + 2⎠⋅⎝x  + x  + x + 7⎠ + ⎝x  + 2⋅x⎠⋅⎝3⋅x  + 2⋅x + 1⎠

# %%
dP=P.diff('dP')
# Out:
# $\displaystyle dP =\left(5 x^{4} + 2\right) \left(x^{3} + x^{2} + x + 7\right) + \left(x^{5} + 2 x\right) \left(3 x^{2} + 2 x + 1\right)$

# %%
dP.expand()
# Out:
# $\displaystyle dP =8 x^{7} + 7 x^{6} + 6 x^{5} + 35 x^{4} + 8 x^{3} + 6 x^{2} + 4 x + 14$

# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %% [markdown]
# ![image.png](attachment:f086cc7b-0f00-4aec-8b10-05abbc12ead1.png)

# %%
P=MyEq((x**3+2*x*x+7)/(x**4+x**3+x),'P',var=x)
# Out:
# $\displaystyle P =\frac{x^{3} + 2 x^{2} + 7}{x^{4} + x^{3} + x}$

# %%
dP=P.diff('dP')
# Out:
# $\displaystyle dP =\frac{3 x^{2} + 4 x}{x^{4} + x^{3} + x} + \frac{\left(- 4 x^{3} - 3 x^{2} - 1\right) \left(x^{3} + 2 x^{2} + 7\right)}{\left(x^{4} + x^{3} + x\right)^{2}}$

# %%
dP.factor()
# Out:
# $\displaystyle dP =- \frac{x^{6} + 4 x^{5} + 2 x^{4} + 26 x^{3} + 19 x^{2} + 7}{x^{2} \left(x^{3} + x^{2} + 1\right)^{2}}$

# %%
from  libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %%
P=MyEq(x*x*y+3*x*y**4+3*x+7*y,'P',var=x)
# Out:
# $\displaystyle P =x^{2} y + 3 x y^{4} + 3 x + 7 y$

# %%
P.diff()
# Out:
#            4
# 2⋅x⋅y + 3⋅y  + 3

# %%
Pd=P.diff('dP')
# Out:
# $\displaystyle dP =2 x y + 3 y^{4} + 3$

# %%
P.diff(y)
# Out:
#  2         3
# x  + 12⋅x⋅y  + 7

# %%
dPy=P.diff('dPy',y)
# Out:
# $\displaystyle dPy =x^{2} + 12 x y^{3} + 7$

# %%
from  libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %%
p1=acos(x)/x**2
p2=1-sqrt(1-x*x)
p3=1+sqrt(1-x*x)
p4=ln(p2/p3)/2
p5=p1+p4

# %%
P=MyEq(p5,'P',var=x)
# Out:
# $\displaystyle P =\frac{\log{\left(\frac{1 - \sqrt{1 - x^{2}}}{\sqrt{1 - x^{2}} + 1} \right)}}{2} + \frac{\operatorname{acos}{\left(x \right)}}{x^{2}}$

# %%
dP=P.diff('dP')
# Out:
# $\displaystyle dP =\frac{\left(\frac{x \left(1 - \sqrt{1 - x^{2}}\right)}{\sqrt{1 - x^{2}} \left(\sqrt{1 - x^{2}} + 1\right)^{2}} + \frac{x}{\sqrt{1 - x^{2}} \left(\sqrt{1 - x^{2}} + 1\right)}\right) \left(\sqrt{1 - x^{2}} + 1\right)}{2 \cdot \left(1 - \sqrt{1 - x^{2}}\right)} - \frac{1}{x^{2} \sqrt{1 - x^{2}}} - \frac{2 \operatorname{acos}{\left(x \right)}}{x^{3}}$

# %%
dP.simplify()
# Out:
# $\displaystyle dP =\frac{x^{2} - x - 2 \sqrt{1 - x^{2}} \operatorname{acos}{\left(x \right)}}{x^{3} \sqrt{1 - x^{2}}}$
