# %% [markdown]
# ![image.png](attachment:489bca0d-e38c-4178-8a51-589ac7d4de6e.png)

# %% [markdown]
# ![image.png](attachment:abe86e25-c81b-4adb-927a-512d6ed9f942.png)

# %% [markdown]
# ![image.png](attachment:ea45ba9a-f4d5-492d-bd5e-73c26277bb98.png)

# %% [markdown]
# ![image.png](attachment:489bca0d-e38c-4178-8a51-589ac7d4de6e.png)

# %% [markdown]
# ![image.png](attachment:3a6eceea-b0f7-435a-a124-e4f3638036f2.png)

# %% [markdown]
# ![image.png](attachment:b388060c-0512-4551-8429-fe78eb5e304c.png)

# %%
from libaldomath import *
from lib_MyDiff  import *

# %%
Q=MyDiff("T'","k*(T(t)-Tm)",t,T)
# Out:
# $\displaystyle T' = k \left(T - Tm\right)$

# %%
Qt=Q.dsolve(T)
# Out:
# $\displaystyle T = C_{1} e^{k t} + Tm$

# %% [markdown]
# ![image.png](attachment:0ca5d611-ff3f-49a4-8a0c-90dd4111df27.png)

# %% [markdown]
# ![image.png](attachment:02afca85-d3cf-4f2a-afaf-619f5c40ca6c.png)

# %%
Qt.set(Tm=100)
# Out:
# $\displaystyle T = C_{1} e^{k t} + 100$

# %% [markdown]
# ![image.png](attachment:a70c9b7b-4ec1-45c7-aa40-c8d47de1b9f4.png)

# %%
Qt.autofind(C1,t=0,T=20)
# Out:
# $\displaystyle T = 100 - 80 e^{k t}$

# %%
Qt.autofind(k,'float',t=1,T=22,)
# Out:
# $\displaystyle T = 100 - 80 e^{- 0.025317807984289876 t}$

# %%
Qt.Substrac(100)
# Out:
# $\displaystyle T - 100 = - 80 e^{- 0.025317807984289876 t}$

# %%
Qt.Mul(-1)
# Out:
# $\displaystyle 100 - T = 80 e^{- 0.025317807984289876 t}$

# %%
Qt.Div(80)
# Out:
# $\displaystyle \frac{5}{4} - \frac{T}{80} = e^{- 0.025317807984289876 t}$

# %%
Qt.log()
# Out:
# $\displaystyle \log{\left(\frac{5}{4} - \frac{T}{80} \right)} = \log{\left(e^{- 0.025317807984289876 t} \right)}$

# %%
Qt.lexpand()
# Out:
# $\displaystyle \log{\left(\frac{5}{4} - \frac{T}{80} \right)} = - 0.025317807984289876 t$

# %%
Qt.alone(t)
# Out:
# $\displaystyle t = - 39.4978902052072 \log{\left(1.25 - 0.0125 T \right)}$

# %% [markdown]
# ![image.png](attachment:f16d728c-fe01-4b72-8609-f81f3bda46c0.png)

# %%
Qt(T=90)
# Out:
# $\displaystyle t = 82.1335537014169$

# %%
Qt(T=98)
# Out:
# $\displaystyle t = 145.702955658837$

# %% [markdown]
# ![image.png](attachment:18762423-3346-4af8-83a4-5c2b3f5470b2.png)

# %% [markdown]
# ![image.png](attachment:489bca0d-e38c-4178-8a51-589ac7d4de6e.png)

# %% [markdown]
# ![image.png](attachment:be2338c8-e86c-4c06-a512-13379f578de5.png)

# %%
from libaldomath import *
from lib_MyDiff  import *

# %%
Q=MyDiff("P'","-k*P(t)",t,P)
# Out:
# $\displaystyle P' = - P k$

# %%
Qc=Q.dsolve(P)
# Out:
# $\displaystyle P = C_{1} e^{- k t}$

# %%
Qc.autofind(C1,P=1000,t=0)
# Out:
# $\displaystyle P = 1000 e^{- k t}$

# %%
Qc.Div(1000)
# Out:
# $\displaystyle \frac{P}{1000} = e^{- k t}$

# %%
Qc.log()
# Out:
# $\displaystyle \log{\left(\frac{P}{1000} \right)} = \log{\left(e^{- k t} \right)}$

# %%
Qc.lexpand()
# Out:
# $\displaystyle \log{\left(P \right)} - 3 \log{\left(10 \right)} = - k t$

# %%
Qc.autofind(k,P=2000,t=3)
# Out:
# $\displaystyle \log{\left(P \right)} - 3 \log{\left(10 \right)} = t \left(- \log{\left(10 \right)} + \frac{\log{\left(2000 \right)}}{3}\right)$

# %%
Qc.Substrac(-3*log(10))
# Out:
# $\displaystyle \log{\left(P \right)} = t \left(- \log{\left(10 \right)} + \frac{\log{\left(2000 \right)}}{3}\right) + 3 \log{\left(10 \right)}$

# %%
Qc.exp()
# Out:
# $\displaystyle P = 1000 e^{t \left(- \log{\left(10 \right)} + \frac{\log{\left(2000 \right)}}{3}\right)}$

# %% [markdown]
# ![image.png](attachment:9a076578-602b-49c8-b064-014fc7c18e41.png)

# %%
from libaldomath import *
from lib_MyDiff  import *

# %%
Q=MyDiff("P'","k*P(t)",t,P)
# Out:
# $\displaystyle P' = P k$

# %%
Qc=Q.dsolve(P)
# Out:
# $\displaystyle P = C_{1} e^{k t}$

# %%
Qc.autofind(C1,P=N1,t=0)
# Out:
# $\displaystyle P = N_{1} e^{k t}$

# %%
Qc.autofind(k,P=N1*3/2,t=1)
# Out:
# $\displaystyle P = N_{1} e^{t \log{\left(\frac{3}{2} \right)}}$

# %%
Qc.alone(t)
# Out:
# $\displaystyle t = \frac{\log{\left(\frac{P}{N_{1}} \right)}}{\log{\left(\frac{3}{2} \right)}}$

# %%
Qc(P=3*N1)
# Out:
# $\displaystyle t = \frac{\log{\left(3 \right)}}{\log{\left(\frac{3}{2} \right)}}$

# %% [markdown]
# ![image.png](attachment:489bca0d-e38c-4178-8a51-589ac7d4de6e.png)
