# %%
from  Libaldomath  import *
from lib_MyIntegral import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:e31313f2-d8f2-4240-9eb6-dbaf2488827b.png)

# %% [markdown]
# ![image.png](attachment:1ba6b893-cae5-46eb-a800-f4a86397e06f.png)

# %%
y=MyIntg(x*rpow(x-2,3) ,'y')
# Out:
# $\displaystyle y=\int x \sqrt[3]{x - 2}\, dx$

# %%
y.doit()
# Out:
# $\displaystyle y=\begin{cases} \frac{3 x^{2} \sqrt[3]{x - 2}}{7} - \frac{3 x \sqrt[3]{x - 2}}{14} - \frac{9 \sqrt[3]{x - 2}}{7} & \text{for}\: \left|{x}\right| > 2 \\\frac{3 x^{2} \sqrt[3]{2 - x} e^{\frac{i \pi}{3}}}{7} - \frac{3 x \sqrt[3]{2 - x} e^{\frac{i \pi}{3}}}{14} - \frac{9 \sqrt[3]{2 - x} e^{\frac{i \pi}{3}}}{7} & \text{otherwise} \end{cases}$

# %%
from  Libaldomath  import *
from lib_simpleintegral import *
# this cell will be initializing your variables
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 2
#       1 from  Libaldomath  import *
# ----> 2 from lib_simpleintegral import *
#       3 # this cell will be initializing your variables
#
# ModuleNotFoundError: No module named 'lib_simpleintegral'

# %% [markdown]
# ![image.png](attachment:e31313f2-d8f2-4240-9eb6-dbaf2488827b.png)

# %% [markdown]
# ![image.png](attachment:f6fa3ad5-ab67-43e0-b298-7c5f467d4ed2.png)

# %%
y=MyIntg((3*x-1)/sqrt(x*x+2*x+2),'y')
# Out:
# $\displaystyle y=\int \frac{3 x - 1}{\sqrt{x^{2} + 2 x + 2}}\, dx$

# %%
y.doit()
# Out:
# $\displaystyle y=3 \sqrt{x^{2} + 2 x + 2} - 4 \operatorname{asinh}{\left(x + 1 \right)}$

# %% [markdown]
# ![image.png](attachment:e31313f2-d8f2-4240-9eb6-dbaf2488827b.png)

# %% [markdown]
# ![image.png](attachment:aed34642-6761-4363-91e9-608eaad32550.png)

# %%
y=MyIntg(sin(8*x)*sin(2*x),'y')
# Out:
# $\displaystyle y=\int \sin{\left(2 x \right)} \sin{\left(8 x \right)}\, dx$

# %%
y.doit()
# Out:
# $\displaystyle y=- \frac{2 \sin{\left(2 x \right)} \cos{\left(8 x \right)}}{15} + \frac{\sin{\left(8 x \right)} \cos{\left(2 x \right)}}{30}$
