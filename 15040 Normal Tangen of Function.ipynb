# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %%
from  libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:d1ae325d-e1a0-482c-8891-7cca2bac5322.png)

# %%
y=MyEq(x**2-5*x+6,'y',var=x)
# Out:
# $\displaystyle y =x^{2} - 5 x + 6$

# %%
y.eQtangent() #  in P(x1,f(x1))
# Out:
#   2
# x₁  - 5⋅x₁ + (x - x₁)⋅(2⋅x₁ - 5) + 6

# %%
y.eQnormal() #  in P(x1,f(x1))
# Out:
#   2          -x + x₁
# x₁  - 5⋅x₁ + ──────── + 6
#              2⋅x₁ - 5

# %%
y.eQtangent(1) #  in P(1,f(1))
# Out:
# 5 - 3⋅x

# %%
y.eQnormal(1) #  in P(1,f(1))
# Out:
# x   5
# ─ + ─
# 3   3

# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %%
from  libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![imagen.png](attachment:735c7838-3129-4c39-8e51-be9acbd9a8fe.png)

# %%
Q=MyEq(x**3-3*x,'Q',var=x)
# Out:
# $\displaystyle Q =x^{3} - 3 x$

# %%
Q.eQtangent(2)
# Out:
# 9⋅x - 16

# %%
Q.eQnormal(2)
# Out:
# 20   x
# ── - ─
# 9    9

# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %%
from  libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:998d0e40-304b-492d-ba47-b45c3668565b.png)

# %%
Q=MyEq(x**5+y**5-2*x*y,'Q',var=x)
# Out:
# $\displaystyle Q =x^{5} - 2 x y + y^{5}$

# %%
dQ=Q.diff('dQ',func=y)
# Out:
# $\displaystyle dQ =5 x^{4} - 2 x y' + 5 y^{4} y' - 2 y$

# %%
dy=dQ.solve(symboldiff(y))
# Out:
# $\displaystyle y' =\frac{5 x^{4} - 2 y}{2 x - 5 y^{4}}$

# %%
dy(x=1,y=1)
# Out:
# -1

# %%
Lt=eQrecta(1,1,-1,'Lt')
# Out:
# $\displaystyle Lt =2 - x$

# %%
Ln=eQrecta(1,1,1,'Ln')
# Out:
# $\displaystyle Ln =x$

# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %%
from  libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:615d0885-2dee-48d6-92b7-4bf5222bb4ff.png)

# %%
L=MyEq((8-x)/8,'L',var=x)
# Out:
# $\displaystyle L =1 - \frac{x}{8}$

# %%
sL=L.diff('sL') # slope
# Out:
# $\displaystyle sL =- \frac{1}{8}$

# %%
y=MyEq(x**3-4*x,'y',var=x)
# Out:
# $\displaystyle y =x^{3} - 4 x$

# %%
oL=sL.neginverse('oL')
# Out:
# $\displaystyle oL =8$

# %%
dy1=y1.diff('dy1')
# Out:
# $\displaystyle dy1 =- \frac{1}{8}$

# %%
dy2=dy1.neginverse('dy2')
# Out:
# $\displaystyle dy2 =8$

# %%
y=MyEq(x**3-4*x,'y',var=x)
# Out:
# $\displaystyle y =x^{3} - 4 x$

# %%
yN=MyEq(y.eQnormal(),'yN',var=x)
# Out:
# $\displaystyle yN =x_{1}^{3} - 4 x_{1} + \frac{- x + x_{1}}{3 x_{1}^{2} - 4}$

# %%
dyN=yN.diff('dyN')
# Out:
# $\displaystyle dyN =- \frac{1}{3 x_{1}^{2} - 4}$

# %%
Q=MQ(dyN,dy1)
# Out:
# $\displaystyle - \frac{1}{3 x_{1}^{2} - 4} = - \frac{1}{8}$

# %%
x1=simplesolve(Q,x1)
# Out:
# $\displaystyle x1 =-2$

# %%
yN(x1=-2)
# Out:
#   x   1
# - ─ - ─
#   8   4

# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %%
from  libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:615d0885-2dee-48d6-92b7-4bf5222bb4ff.png)

# %%
Q=MyEq(3*y-(x**3-3*x*x+6*x+4),'Q')
# Out:
# $\displaystyle Q =- x^{3} + 3 x^{2} - 6 x + 3 y - 4$

# %%
dy=simplesolve(Q.diff(func=y),symboldiff(y),'Eq')
# Out:
# $\displaystyle y' =x^{2} - 2 x + 2$

# %%
slope=2

# %%
dy.Substrac(slope)
# Out:
# $\displaystyle y' =x^{2} - 2 x$

# %%
x1,x2=dy.solve(x,'all')
# Out:
# $\displaystyle \left[ 0, \  2\right]$

# %%
y1=simplesolve(Q.eQtangent(0),y)
y2=simplesolve(Q.eQtangent(2),y)
# Out:
# $\displaystyle y =2 x + \frac{4}{3}$
# $\displaystyle y =2 x$
