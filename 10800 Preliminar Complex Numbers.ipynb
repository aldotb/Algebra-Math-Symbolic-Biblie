# %%
from  libaldomath  import *
# this cell will be initializing your variables

# %%
helpgui

# %% [markdown]
# ![image.png](attachment:e43b18ca-0210-4667-9ca6-63065cf2ce23.png)

# %%
z=3+4*I
z
# Out:
# 3 + 4⋅ⅈ

# %% [markdown]
# ![image.png](attachment:e2d9e392-57db-4a37-be65-3a5e5ab4c4ba.png)

# %%
im(z)
# Out:
# 4

# %% [markdown]
# ![image.png](attachment:9ef62d32-620a-487f-9eae-fd6ecda73d77.png)

# %%
re(z)
# Out:
# 3

# %% [markdown]
# ![image.png](attachment:8b2fe9c8-ef6c-4719-8f6e-7baa795387d0.png)

# %%
z.conjugate()
# Out:
# 3 - 4⋅ⅈ

# %% [markdown]
# ![image.png](attachment:9c03124c-994a-4d4f-9fef-b30adf78d76b.png)

# %%
imodule(z)
# Out:
#   1
#   ─
#   2
# 25

# %%
img2polar(z)
# Out:
# ⎛  1           ⎞
# ⎜  ─           ⎟
# ⎜  2           ⎟
# ⎝25 , atan(3/4)⎠

# %%
polar2img(5,atan(frs(3,4)))
# Out:
# 4.0 + 3.0⋅ⅈ

# %%
expand(z**2)
# Out:
# -7 + 24⋅ⅈ

# %%
powi(z,2)
# Out:
# -7 + 24⋅ⅈ

# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %%
from  libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %% [markdown]
# ![image.png](attachment:1f9639b1-df34-40af-8e45-24066fc92efa.png)

# %%
M1=1+2*I
M2=3-5*I
Q=M1*x+M2*y-(1-3*I)

# %%
x,y=simplesolve((imgpart(Q),repart(Q)),(x,y),'show')
# Out:
# $\displaystyle x =- \frac{4}{11}$
# $\displaystyle y =\frac{5}{11}$

# %%
x+y
# Out:
# 1/11

# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %%
from  libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:25115b89-da25-4c19-8a64-b4a830f58ee4.png)

# %%
M1=-1+I
M2=1+2*I
Q=M1*a+M2*b-1

# %%
a,b=simplesolve((imgpart(Q),repart(Q)),(a,b),'show')
# Out:
# $\displaystyle a =- \frac{2}{3}$
# $\displaystyle b =\frac{1}{3}$

# %%
b-a
# Out:
# 1

# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %%
from  libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %% [markdown]
# ![image.png](attachment:e9e3bb2b-9a5d-495d-8cdd-167dc9fe52b8.png)

# %%
 F=MyEq((1+I)**2*(1+3*I)/(I-3),'F')
# Out:
# $\displaystyle F =\frac{\left(-3 - i\right) \left(1 + i\right)^{2} \cdot \left(1 + 3 i\right)}{10}$

# %%
F.expand()
# Out:
# $\displaystyle F =2$

# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %%
from  libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %% [markdown]
# ![image.png](attachment:34375984-14b1-4697-8370-3de31b2130a7.png)

# %%
Q=MQ(5*I/(x-y),(y-I)/(1+I))
# Out:
# $\displaystyle \frac{5 i}{x - y} = \frac{\left(1 - i\right) \left(y - i\right)}{2}$

# %%
Q.crossMul()
# Out:
# $\displaystyle 10 i = \left(1 - i\right) \left(x - y\right) \left(y - i\right)$

# %%
Q.expand()
# Out:
# $\displaystyle 10 i = x y - i x y - x - i x - y^{2} + i y^{2} + y + i y$

# %%
Q.all2L()
# Out:
# $\displaystyle x y \left(-1 + i\right) + x \left(1 + i\right) + y^{2} \cdot \left(1 - i\right) - y \left(1 + i\right) + 10 i = 0$

# %%
x,y=simplesolve(rpart(Q.L),ipart(Q.L),x,y,'show')
# Out:
# $\displaystyle x =-4$
# $\displaystyle y =1$

# %%
x+y
# Out:
# -3

# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %%
from  libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %% [markdown]
# ![image.png](attachment:1216e6b1-3f1f-4fcb-9f79-25af05bbb7e8.png)

# %%
 Q=MQ((1+I)**3,a+b+c*I)
# Out:
# $\displaystyle \left(1 + i\right)^{3} = a + b + i c$

# %%
Q.expand()
# Out:
# $\displaystyle -2 + 2 i = a + b + i c$

# %%
Q.set(c=2)
# Out:
# $\displaystyle -2 + 2 i = a + b + 2 i$

# %%
Q.simplify()
# Out:
# $\displaystyle -2 + 2 i = a + b + 2 i$

# %%
Q.Add(MQ(2,c))
# Out:
# $\displaystyle 2 = c$
# $\displaystyle 2 i = a + b + c + 2 i$

# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)
