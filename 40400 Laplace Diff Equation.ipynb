# %% [markdown]
# ![imagen.png](attachment:6fe077e5-9821-4674-a8d4-8529d237cdba.png)

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)

# %%
from  Libaldomath  import *
from lib_MyDiff import *
from lib_MyIntegral import *

# %% [markdown]
# ![image.png](attachment:e1489650-0b29-4902-ae37-7e54c043695e.png)

# %%
Q=MQ(eQdiff2laplace(d2x-10*dx+9*x,x0=-1,dx0=2),func2laplace(5*t))
# Out:
# $\displaystyle \mathcal{L} = \frac{5}{s^{2}}$
# $\displaystyle L s^{2} - 10 L s + 9 L + s - 12 = \frac{5}{s^{2}}$

# %%
Q.alone(L)
# Out:
# $\displaystyle L = \frac{- s^{3} + 12 s^{2} + 5}{s^{2} \left(s^{2} - 10 s + 9\right)}$

# %%
eQinverselaplace(Q.R)
# Out:
#           9⋅t
# 5⋅t   31⋅ℯ         t   50
# ─── + ─────── - 2⋅ℯ  + ──
#  9       81            81

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)

# %%
from  Libaldomath  import *
from lib_MyDiff import *
from lib_MyIntegral import *

# %% [markdown]
# ![image.png](attachment:2f7b2cbf-b3d5-4d79-8d61-d1d5e091bef6.png)

# %%
Q1=MQ(eQdiff2laplace(dx+x+dy,x0=2,dx0=0,y0=1,dy0=0,varx=L,vary=M),0)
Q2=MQ(eQdiff2laplace(4*x+dy+y,x0=2,dx0=0,y0=1,dy0=0,varx=L,vary=M),0)
# Out:
# $\displaystyle L s + L + M s - 3 = 0$
# $\displaystyle 4 L + M s + M - 1 = 0$

# %%
L,M=simplesolve(Q1,Q2,L,M)
# Out:
# $\displaystyle L =\frac{2 s + 3}{s^{2} - 2 s + 1}$
# $\displaystyle M =\frac{s - 11}{s^{2} - 2 s + 1}$

# %%
x=eQinverselaplace(L,'x')
# Out:
# $\displaystyle x =5 t e^{t} + 2 e^{t}$

# %%
y=eQinverselaplace(L,'y')
# Out:
# $\displaystyle y =5 t e^{t} + 2 e^{t}$

# %% [markdown]
# ![image.png](attachment:4fc789f4-fbdd-4efd-ac3d-8888029750e6.png)

# %% [markdown]
# ![image.png](attachment:76e1f8ba-ec8f-4f82-b253-d4aa6d60482d.png)

# %% [markdown]
# ![image.png](attachment:2125b70a-6d15-429e-874e-4402a8af8219.png)

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)
