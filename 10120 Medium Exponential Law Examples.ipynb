# %%
from  Libaldomath  import *
# this cell will be initializing your variables

# %%
Q=MyEq(kpow(x,x*(rpow(2)-1)),'Q')
# Out:
# $\displaystyle Q =x^{x \left(-1 + \sqrt{2}\right)}$

# %%
Q.expandexpo()
# Out:
# $\displaystyle Q =x^{- x + \sqrt{2} x}$

# %% [markdown]
# ![image.png](attachment:274a06a9-a4dc-4a04-81c7-c9eac8a4cc55.png)

# %% [markdown]
# ![image.png](attachment:bfc46060-a4d8-4c2d-b2b4-f938148f017d.png)

# %% [markdown]
# ![image.png](attachment:4a6b6e99-8c62-43a5-b505-b49445b804ef.png)

# %%
from  Libaldomath  import *

# %% [markdown]
# ![image.png](attachment:274a06a9-a4dc-4a04-81c7-c9eac8a4cc55.png)

# %%
P=MQ( x**(kpow(x-1,2)),2*x+1)
# Out:
# $\displaystyle x^{\left(x - 1\right)^{2}} = 2 x + 1$

# %%
P.expandexpo()
# Out:
# $\displaystyle x^{x^{2} - 2 x + 1} = 2 x + 1$

# %%
P.Mul(x**(2*x))
# Out:
# $\displaystyle x^{2 x} x^{x^{2} - 2 x + 1} = x^{2 x} \left(2 x + 1\right)$

# %%
P.simplify()
# Out:
# $\displaystyle x^{x^{2} + 1} = x^{2 x} \left(2 x + 1\right)$

# %%
P.Mul(x)
# Out:
# $\displaystyle x x^{x^{2} + 1} = x x^{2 x} \left(2 x + 1\right)$

# %%
P.simplify()
# Out:
# $\displaystyle x^{x^{2} + 2} = x^{2 x + 1} \cdot \left(2 x + 1\right)$

# %%
P.disjoinbase('L')
# Out:
# $\displaystyle x^{2} x^{x^{2}} = x^{2 x + 1} \cdot \left(2 x + 1\right)$

# %%
#then...
Q=MQ(x*x,2*x+1)
# Out:
# $\displaystyle x^{2} = 2 x + 1$

# %%
Q.Add(-2*x+1)
# Out:
# $\displaystyle x^{2} - 2 x + 1 = 2$

# %%
Q.factor()
# Out:
# $\displaystyle \left(x - 1\right)^{2} = 2$

# %%
Q.Rpow(2)
# Out:
# $\displaystyle \sqrt{\left(x - 1\right)^{2}} = \sqrt{2}$

# %%
Q.alone(x)
# Out:
# $\displaystyle x = 1 - \sqrt{2}$

# %% [markdown]
# ![image.png](attachment:9a703d46-457d-455f-8e9b-f701a5b8c2cf.png)

# %% [markdown]
# ![image.png](attachment:a4d93ae2-8b98-4cd7-9767-a1fb0361272e.png)

# %% [markdown]
# ![image.png](attachment:4a6b6e99-8c62-43a5-b505-b49445b804ef.png)

# %%
from  Libaldomath  import *

# %% [markdown]
# ![image.png](attachment:274a06a9-a4dc-4a04-81c7-c9eac8a4cc55.png)

# %%
A=MQ(x,sqrs(t,t-1))
B=MQ(y,kpow(t,t-1))
# Out:
# $\displaystyle x = t^{\frac{1}{t - 1}}$
# $\displaystyle y = t^{t - 1}$

# %%
A.Pow(t-1) # Q.Pow(a) = Q**a
# Out:
# $\displaystyle x^{t - 1} = \left(t^{\frac{1}{t - 1}}\right)^{t - 1}$

# %%
A.simplifyexpo()
# Out:
# $\displaystyle x^{t - 1} = \left(t^{\frac{1}{t - 1}}\right)^{t - 1}$

# %%
B.Rpow(t-1)
# Out:
# $\displaystyle y^{\frac{1}{t - 1}} = \left(t^{t - 1}\right)^{\frac{1}{t - 1}}$

# %%
B.simplifyexpo()
# Out:
# $\displaystyle y^{\frac{1}{t - 1}} = \left(t^{t - 1}\right)^{\frac{1}{t - 1}}$

# %%
C=MQ(A.L,B.L) # Q.L = return Q left side
# Out:
# $\displaystyle x^{t - 1} = y^{\frac{1}{t - 1}}$

# %% [markdown]
# ![image.png](attachment:e15db32b-13c8-4ab7-9d47-2dd35c5c9cc5.png)

# %% [markdown]
# ![image.png](attachment:d9d62bbf-550a-46b2-b86c-cdd2b98e2297.png)

# %% [markdown]
# ![image.png](attachment:e0313cdb-f6d6-4d67-8a97-5750b205b59b.png)

# %%
from  Libaldomath  import *
# this cell will be initializing your variables

# %%
Q=MQ(2*x+1,3*sqrs(1/x,2,4*x-1)/2)
# Out:
# $\displaystyle 2 x + 1 = \frac{3 \left(\frac{1}{x}\right)^{2 x - \frac{1}{2}}}{2}$

# %%
Q.Mul(2)
# Out:
# $\displaystyle 4 x + 2 = 3 \left(\frac{1}{x}\right)^{2 x - \frac{1}{2}}$

# %%
#we will se 4*x+2=b then
Q.setL(b)
# Out:
# $\displaystyle b = 3 \left(\frac{1}{x}\right)^{2 x - \frac{1}{2}}$

# %%
Q.Div(3)
# Out:
# $\displaystyle \frac{b}{3} = \left(\frac{1}{x}\right)^{2 x - \frac{1}{2}}$

# %%
Q.Pow(2)
# Out:
# $\displaystyle \frac{b^{2}}{9} = \left(\frac{1}{x}\right)^{4 x - 1}$

# %%
Q.setR(cfrac((x**3),(b**b)))
# Out:
# $\displaystyle \frac{b^{2}}{9} = b^{- b} x^{3}$

# %%
Q.Mul(9)
# Out:
# $\displaystyle b^{2} = 9 b^{- b} x^{3}$

# %%
Q.Mul(b**b)
# Out:
# $\displaystyle b^{2} b^{b} = 9 x^{3}$

# %%
#  then  x=3

# %% [markdown]
# ![image.png](attachment:e92d2e8f-fa11-4dea-9209-c52665feb264.png)

# %% [markdown]
# ![image.png](attachment:346e7bf0-fa6c-4aed-bb6f-aafd2016dcee.png)

# %% [markdown]
# ![image.png](attachment:8802849d-4207-4f37-ad83-65875b733414.png)

# %%
from  Libaldomath  import *

# %% [markdown]
# ![image.png](attachment:2ab5e670-032f-4d2e-9973-10b5f0e83020.png)

# %%
def P3(x1,x2,x3):
    return((x1*x)**(x2*x)**(x3*x))

# %%
e1=MyEq((-x**(-x**-x+x**x))*(P3(1,-1,1)+P3(1,1,-1))/(P3(1,-1,-1)+P3(1,1,1)),'e1')
# Out:
# $\displaystyle e1 =- \frac{x^{x^{x} - x^{- x}} \left(x^{x^{- x}} + x^{\left(- x\right)^{x}}\right)}{x^{x^{x}} + x^{\left(- x\right)^{- x}}}$

# %%
e1.subsubs(x**x,w)
# Out:
# $\displaystyle e1 =- \frac{x^{w - \frac{1}{w}} \left(x^{x^{- x}} + x^{\left(- x\right)^{x}}\right)}{x^{w} + x^{\left(- x\right)^{- x}}}$

# %%
e1.subsubs(x**-x,1/w)
# Out:
# $\displaystyle e1 =- \frac{x^{w - \frac{1}{w}} \left(x^{\frac{1}{w}} + x^{\left(- x\right)^{x}}\right)}{x^{w} + x^{\left(- x\right)^{- x}}}$

# %%
e1.subsubs('(-x)**(-x)',-1/w)
# Out:
# $\displaystyle e1 =- \frac{x^{w - \frac{1}{w}} \left(x^{\frac{1}{w}} + x^{\left(- x\right)^{x}}\right)}{x^{w} + x^{- \frac{1}{w}}}$

# %%
e1.subsubs('(-x)**x',-w)
# Out:
# $\displaystyle e1 =- \frac{x^{w - \frac{1}{w}} \left(x^{\frac{1}{w}} + x^{- w}\right)}{x^{w} + x^{- \frac{1}{w}}}$

# %%
e1.simplify()
# Out:
# $\displaystyle e1 =-1$

# %% [markdown]
# ![image.png](attachment:647adaed-4553-4c5f-8554-ce75dbb22e77.png)

# %%
from  Libaldomath  import *

# %% [markdown]
# ![image.png](attachment:32634580-7a6f-44c7-8751-31886093a69a.png)

# %%
Q1=MQ(x**(x**(x**cfrac(1,4)+cfrac(1,4))),cfrac(1,2)**(2**cfrac(1,2)/2**(2**cfrac(1,2))))
# Out:
# $\displaystyle x^{x^{\sqrt[4]{x} + \frac{1}{4}}} = \left(\frac{1}{2}\right)^{\frac{\sqrt{2}}{2^{\sqrt{2}}}}$

# %%
Q1.subsubs(sqrt(2),a)
# Out:
# $\displaystyle x^{x^{\sqrt[4]{x} + \frac{1}{4}}} = \left(\frac{1}{2}\right)^{2^{- a} a}$

# %%
Q1.subsubs(2,a**2)
# Out:
# $\displaystyle x^{x^{\sqrt[4]{x} + \frac{1}{4}}} = \left(\frac{1}{a^{2}}\right)^{a a^{- 2^{a}}}$

# %%
Q1.subsubs(4,a**4)
# Out:
# $\displaystyle x^{x^{x^{\frac{1}{a^{4}}} + \frac{1}{a^{4}}}} = \left(\frac{1}{a^{2}}\right)^{a a^{- 2^{a}}}$

# %%
Q1.mulexpo()
# Out:
# $\displaystyle x^{x^{x^{\frac{1}{a^{4}}} + \frac{1}{a^{4}}}} = a^{- 2 a a^{- 2^{a}}}$

# %%
Q1.simplify()
# Out:
# $\displaystyle x^{x^{x^{\frac{1}{a^{4}}} + \frac{1}{a^{4}}}} = a^{- 2 a^{1 - 2^{a}}}$

# %%
Q1.positivexpo('R')
# Out:
# $\displaystyle x^{x^{x^{\frac{1}{a^{4}}} + \frac{1}{a^{4}}}} = 1 \cdot \frac{1}{a^{2 a^{1 - 2^{a}}}}$

# %%
Q1.simplify()
# Out:
# $\displaystyle x^{x^{x^{\frac{1}{a^{4}}} + \frac{1}{a^{4}}}} = a^{- 2 a^{1 - 2^{a}}}$

# %%
Q1.simplifyexpo()
# Out:
# $\displaystyle x^{x^{x^{\frac{1}{a^{4}}} + \frac{1}{a^{4}}}} = a^{- 2 a^{1 - 2^{a}}}$

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#  if sqrt(3)=a then

# %%
Q2=MQ(x**x**9,a**a)
# Out:
# $\displaystyle x^{x^{9}} = a^{a}$

# %%
Q2.Pow(9)
# Out:
# $\displaystyle x^{9 x^{9}} = a^{9 a}$

# %%
Q2.setR((a**3)**(a**3))
# Out:
# $\displaystyle x^{9 x^{9}} = \left(a^{3}\right)^{a^{3}}$

# %%
Q3=MQ(x**9,a**3)
# Out:
# $\displaystyle x^{9} = a^{3}$

# %%
Q3=MQ(x**3,a)
# Out:
# $\displaystyle x^{3} = a$

# %%
Q3.set(a=sqrt(3))
# Out:
# $\displaystyle x^{3} = \sqrt{3}$

# %%
Q3.Rpow(3)
# Out:
# $\displaystyle \sqrt[3]{x^{3}} = \sqrt[6]{3}$

# %% [markdown]
# ![image.png](attachment:32634580-7a6f-44c7-8751-31886093a69a.png)

# %%
from  Libaldomath  import *
# this cell will be initializing your variables

# %%
Q4=MQ(y,x**(1/(y**y**x)))
# Out:
# $\displaystyle y = x^{y^{- y^{x}}}$

# %%
Q4.Pow((y**y**x))
# Out:
# $\displaystyle y^{y^{y^{x}}} = \left(x^{y^{- y^{x}}}\right)^{y^{y^{x}}}$

# %%
Q4.mulexpo()
# Out:
# $\displaystyle y^{y^{y^{x}}} = x$

# %%
# then..
Q5=MQ(y,x**(1/x))
# Out:
# $\displaystyle y = x^{\frac{1}{x}}$

# %%
Q5.Pow(3*x)
# Out:
# $\displaystyle y^{3 x} = \left(x^{\frac{1}{x}}\right)^{3 x}$

# %%
Q5.mulexpo()
# Out:
# $\displaystyle y^{3 x} = x^{3}$

# %%
Q5.setR(x=3**cfrac(1,6))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 Q5.setR(x=3**cfrac(1,6))
#
# TypeError: setR() got an unexpected keyword argument 'x'

# %%
(3**cfrac(1,6))**3

# %% [markdown]
# ![image.png](attachment:647adaed-4553-4c5f-8554-ce75dbb22e77.png)

# %% [markdown]
# ![image.png](attachment:32634580-7a6f-44c7-8751-31886093a69a.png)

# %% [markdown]
# ![image.png](attachment:27ad967a-8e0d-4584-85ef-71b82548da24.png)

# %% [markdown]
# ![image.png](attachment:d46d8bb9-40bf-4358-b2af-20026ba000c1.png)
