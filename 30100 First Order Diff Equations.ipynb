# %%
from Libaldomath import *
from lib_MyDiff import *

# %% [markdown]
# ![image.png](attachment:6cb9f1e6-a753-48cd-8249-d7eecb26844a.png)

# %% [markdown]
# ![image.png](attachment:43f617d3-37d0-4ac3-82a4-c70fc48fa500.png)

# %%
Q=MyDiff("y'","(y(x)-1)/(x+3)",x,y,ics="y(1)=-3")
# Out:
# $\displaystyle y' = \frac{y - 1}{x + 3}$

# %%
Q.dsolve()
# Out:
# y(x) = -x - 2

# %% [markdown]
# ![image.png](attachment:43f617d3-37d0-4ac3-82a4-c70fc48fa500.png)

# %%
from Libaldomath import *
from lib_MyDiff import *

# %% [markdown]
# ![image.png](attachment:58487f60-48f6-4cce-a7be-b4417a1e4755.png)

# %%
Q=MyDiff("(4*exp(x)*y(x)-1)+exp(x)*y'","0",x,y)
# Out:
# $\displaystyle 4 y e^{x} + y' e^{x} - 1 = 0$

# %%
S=Q.dsolve(y)
# Out:
# $\displaystyle y = \left(C_{1} e^{- 3 x} + \frac{1}{3}\right) e^{- x}$

# %%
S.expand()
# Out:
# $\displaystyle y = C_{1} e^{- 4 x} + \frac{e^{- x}}{3}$

# %%
S.set(C1=5)
# Out:
# $\displaystyle y = \frac{e^{- x}}{3} + 5 e^{- 4 x}$

# %% [markdown]
# ![image.png](attachment:43f617d3-37d0-4ac3-82a4-c70fc48fa500.png)

# %%
from Libaldomath import *
from lib_MyDiff import *

# %% [markdown]
# ![image.png](attachment:45601b08-4b3f-4a2b-8b46-71825de48792.png)

# %%
Q=MyDiff("sqrt(2*y(x))-(x+1)*y'","0",x,y)
# Out:
# $\displaystyle \sqrt{2} \sqrt{y} - y' \left(x + 1\right) = 0$

# %%
S=Q.dsolve(y)
# Out:
# $\displaystyle y = \frac{C_{1}^{2}}{4} + \frac{\sqrt{2} C_{1} \log{\left(x + 1 \right)}}{2} + \frac{\log{\left(x + 1 \right)}^{2}}{2}$

# %%
# autofind is like to say solve the value of C1 ..or whatever and then auto update it...

# %%
S.autofind(C1,x=0,y=cfrac(1,2))
# Out:
# $\displaystyle y = \frac{\log{\left(x + 1 \right)}^{2}}{2} - \log{\left(x + 1 \right)} + \frac{1}{2}$

# %%
S(x=exp(1)-1)
# Out:
# $\displaystyle y = 0$

# %%
from Libaldomath import *
from lib_MyDiff import *

# %% [markdown]
# ![image.png](attachment:6e61a6d0-d5f0-4c43-aa90-fb79413823a4.png)

# %%
Q=MyDiff("(x+x*y(x)**2)+y(x)*exp(x**2)*y'","0",x,y)
# Out:
# $\displaystyle x y^{2} + x + y y' e^{x^{2}} = 0$

# %%
Q.dsolve()
# Out:
# ⎡             ________________              ________________⎤
# ⎢            ╱     ⎛   2⎞                  ╱     ⎛   2⎞     ⎥
# ⎢           ╱      ⎜ -x ⎟                 ╱      ⎜ -x ⎟     ⎥
# ⎢          ╱       ⎝ℯ   ⎠                ╱       ⎝ℯ   ⎠     ⎥
# ⎣y(x) = -╲╱    C₁⋅ℯ       - 1 , y(x) = ╲╱    C₁⋅ℯ       - 1 ⎦

# %%
S1,S2=Q.dsolve(y)
# Out:
# $\displaystyle y = - \sqrt{C_{1} e^{e^{- x^{2}}} - 1}$
# $\displaystyle y = \sqrt{C_{1} e^{e^{- x^{2}}} - 1}$

# %%
S2.Pow(2)
# Out:
# $\displaystyle y^{2} = C_{1} e^{e^{- x^{2}}} - 1$

# %%
S2.Add(1)
# Out:
# $\displaystyle y^{2} + 1 = C_{1} e^{e^{- x^{2}}}$

# %%
S2.log()
# Out:
# $\displaystyle \log{\left(y^{2} + 1 \right)} = \log{\left(C_{1} e^{e^{- x^{2}}} \right)}$

# %%
S2.lsimplify()
# Out:
# $\displaystyle \log{\left(y^{2} + 1 \right)} = \log{\left(C_{1} e^{e^{- x^{2}}} \right)}$

# %%
S2.simplify()
# Out:
# $\displaystyle \log{\left(y^{2} + 1 \right)} = \log{\left(C_{1} e^{e^{- x^{2}}} \right)}$

# %%
S2.Substrac(exp(-x**2))
# Out:
# $\displaystyle \log{\left(y^{2} + 1 \right)} - e^{- x^{2}} = \log{\left(C_{1} e^{e^{- x^{2}}} \right)} - e^{- x^{2}}$

# %%
S2.setR(C1)
# Out:
# $\displaystyle \log{\left(y^{2} + 1 \right)} - e^{- x^{2}} = C_{1}$

# %% [markdown]
# ![image.png](attachment:43f617d3-37d0-4ac3-82a4-c70fc48fa500.png)

# %%
from Libaldomath import *
from lib_MyDiff import *

# %% [markdown]
# ![image.png](attachment:e6a7238d-5898-4ab6-92d8-909b593d7df2.png)

# %%
Q=MyDiff("y(x)+x*x*exp(x)-x*y'","0",x,y)
# Out:
# $\displaystyle x^{2} e^{x} - x y' + y = 0$

# %%
S=Q.dsolve(y)
# Out:
# $\displaystyle y = x \left(C_{1} + e^{x}\right)$

# %%
S2=S.xcopy()

# %%
S2.set(x=ln(2),y=0)
# Out:
# $\displaystyle 0 = \left(C_{1} + 2\right) \log{\left(2 \right)}$

# %%
C2=S2.solve(C1)
# Out:
# $\displaystyle C1=-2$

# %%
S.set(C1=-2)
# Out:
# $\displaystyle y = x \left(e^{x} - 2\right)$

# %%
S(x=ln(3))
# Out:
# $\displaystyle y = \log{\left(3 \right)}$

# %% [markdown]
# ![image.png](attachment:43f617d3-37d0-4ac3-82a4-c70fc48fa500.png)

# %%
from Libaldomath import *
from lib_MyDiff import *

# %% [markdown]
# ![image.png](attachment:88355808-b357-4675-86f9-fa3e76a46b92.png)

# %%
Q=MyDiff("y'/cos(x)","2*sqrt(y(x)+1)",x,y)
# Out:
# $\displaystyle \frac{y'}{\cos{\left(x \right)}} = 2 \sqrt{y + 1}$

# %%
S=Q.dsolve(y)
# Out:
# $\displaystyle y = \frac{C_{1}^{2}}{4} + C_{1} \sin{\left(x \right)} + \sin^{2}{\left(x \right)} - 1$

# %%
S.autofind(C1,x=pi,y=3)
# Out:
# $\displaystyle y = \sin^{2}{\left(x \right)} - 4 \sin{\left(x \right)} + 3$

# %%
S(x=0)
# Out:
# $\displaystyle y = 3$
