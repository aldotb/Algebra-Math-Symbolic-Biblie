# %%
from  libaldomath import *  # this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)

# %% [markdown]
# partialfraction(exp)

# %% [markdown]
# ![image.png](attachment:4963a61b-595d-4d40-b95f-b1c3e8a349ee.png)

# %%
helplib('partialfraction')

# %%
K=((4*x-5)/(x*x-x-2));K
# Out:
#  4⋅x - 5
# ──────────
#  2
# x  - x - 2

# %%
K.factor()
# Out:
#     4⋅x - 5
# ───────────────
# (x - 2)⋅(x + 1)

# %%
apart(K)
# Out:
#   3       1
# ───── + ─────
# x + 1   x - 2

# %%
from  libaldomath import *  # this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)

# %% [markdown]
# ![image.png](attachment:f23c4aa8-b20b-4131-8087-f464c7bfe1d4.png)

# %% [markdown]
# ![image.png](attachment:7423eea4-29c4-4f81-afd5-e2e2c50e3e73.png)

# %% [markdown]
# ![image.png](attachment:72dc586d-79e1-4bff-84c8-15ba53dec9e6.png)

# %% [markdown]
# ![image.png](attachment:f4b6faa9-a156-44a7-89a6-83d081191c29.png)

# %%
#  usin Libaldo lib...????

# %%
F=MyEq(((11-3*x)/(x*x+2*x-3)),'F',var=x) # creatin my F(x)
# Out:
# $\displaystyle F =\frac{11 - 3 x}{x^{2} + 2 x - 3}$

# %%
F.apart()
# Out:
# $\displaystyle F =- \frac{5}{x + 3} + \frac{2}{x - 1}$

# %%
from  libaldomath import *  # this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:7423eea4-29c4-4f81-afd5-e2e2c50e3e73.png)

# %% [markdown]
# ![image.png](attachment:ace0e8de-fb9c-41c3-b253-0c84f3352aa3.png)

# %% [markdown]
# ![image.png](attachment:564517a0-91e3-468c-8146-e591eb1fe84b.png)

# %%
K=MyEq((x*x*x-2*x*x-4*x-4)/(x*x+x-2),'K')
# Out:
# $\displaystyle K =\frac{x^{3} - 2 x^{2} - 4 x - 4}{x^{2} + x - 2}$

# %%
K.apart()
# Out:
# $\displaystyle K =x - 3 + \frac{4}{x + 2} - \frac{3}{x - 1}$

# %% [markdown]
# ![image.png](attachment:7423eea4-29c4-4f81-afd5-e2e2c50e3e73.png)

# %% [markdown]
# ![image.png](attachment:44d9b740-ebe7-430a-aad5-76ab616d2c60.png)

# %% [markdown]
# ![image.png](attachment:1e14dfb4-2ff0-4467-9b99-08b31c06987f.png)

# %%
K=MyEq((2*x+3)/((x-2)**2),'K')
# Out:
# $\displaystyle K =\frac{2 x + 3}{\left(x - 2\right)^{2}}$

# %%
K.apart()
# Out:
# $\displaystyle K =\frac{2}{x - 2} + \frac{7}{\left(x - 2\right)^{2}}$

# %%
from  libaldomath import *  # this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:7423eea4-29c4-4f81-afd5-e2e2c50e3e73.png)

# %% [markdown]
# ![image.png](attachment:8f5db68d-2358-4a6e-8897-062b99027424.png)

# %%
P=MyEq((5*x*x-2*x-19)/((x-1)*(x-1)*(x+3)),'P')
# Out:
# $\displaystyle P =\frac{5 x^{2} - 2 x - 19}{\left(x - 1\right)^{2} \left(x + 3\right)}$

# %%
P.apart()
# Out:
# $\displaystyle P =\frac{2}{x + 3} + \frac{3}{x - 1} - \frac{4}{\left(x - 1\right)^{2}}$
