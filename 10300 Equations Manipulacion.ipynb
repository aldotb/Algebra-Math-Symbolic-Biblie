# %% [markdown]
# ![image.png](attachment:b39ef867-cc4d-4087-a3bf-cd4aaeed85f9.png)

# %%
from  Libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)

# %% [markdown]
# ![image.png](attachment:3f64db8d-0447-4756-b4ca-aa723fe535d2.png)

# %%
expr=a*a-(2*a-a*b)-a*(3*b+a)
expr
# Out:
#  2
# a  + a⋅b - a⋅(a + 3⋅b) - 2⋅a

# %% [markdown]
# ![image.png](attachment:c9b880dd-26dd-4292-8193-df11cae91dd6.png)

# %%
expr=expand(expr);expr
# Out:
# -2⋅a⋅b - 2⋅a

# %%
expr=factor(expr);expr
# Out:
# -2⋅a⋅(b + 1)

# %%
# with MyEq
helplib('MyEq')

# %%
P=MyEq(a*a-(2*a-a*b)-a*(3*b+a),'P')
# Out:
# $\displaystyle P =a^{2} + a b - a \left(a + 3 b\right) - 2 a$

# %%
P.simplify()
# Out:
# $\displaystyle P =2 a \left(- b - 1\right)$

# %%
P=MyEq(5*x*x*x*y*y+3*x*x*y-2*x+3*y+12,'P')
# Out:
# $\displaystyle P =5 x^{3} y^{2} + 3 x^{2} y - 2 x + 3 y + 12$

# %% [markdown]
# ![image.png](attachment:ed9b5f7f-d37b-421e-a700-4fb7871bb773.png)

# %%
P.s()  # show the Eq
# Out:
# $\displaystyle P =5 x^{3} y^{2} + 3 x^{2} y - 2 x + 3 y + 12$

# %%
P.factor()
# Out:
# $\displaystyle P =5 x^{3} y^{2} + 3 x^{2} y - 2 x + 3 y + 12$

# %%
helplib('factoriza')

# %%
# but...
P.factoriza(x)
# Out:
# $\displaystyle P =x \left(5 x^{2} y^{2} + 3 x y - 2\right) + 3 y + 12$

# %%
P.expand()
# Out:
# $\displaystyle P =5 x^{3} y^{2} + 3 x^{2} y - 2 x + 3 y + 12$

# %%
P.factoriza(x*y)
# Out:
# $\displaystyle P =- 2 x + 3 y + x y \left(5 x^{2} y + 3 x\right) + 12$

# %%
P.Pow(2)
# Out:
# $\displaystyle P =\left(x y \left(5 x^{2} y + 3 x\right) - 2 x + 3 y + 12\right)^{2}$

# %%
P.expand()
# Out:
# $\displaystyle P =25 x^{6} y^{4} + 30 x^{5} y^{3} - 11 x^{4} y^{2} + 30 x^{3} y^{3} + 120 x^{3} y^{2} - 12 x^{3} y + 18 x^{2} y^{2} + 72 x^{2} y + 4 x^{2} - 12 x y - 48 x + 9 y^{2} + 72 y + 144$

# %%
P.Rpow(2)
# Out:
# $\displaystyle P =\sqrt{25 x^{6} y^{4} + 30 x^{5} y^{3} - 11 x^{4} y^{2} + 30 x^{3} y^{3} + 120 x^{3} y^{2} - 12 x^{3} y + 18 x^{2} y^{2} + 72 x^{2} y + 4 x^{2} - 12 x y - 48 x + 9 y^{2} + 72 y + 144}$

# %%
P.factor()
# Out:
# $\displaystyle P =\sqrt{\left(5 x^{3} y^{2} + 3 x^{2} y - 2 x + 3 y + 12\right)^{2}}$

# %%
helplib('rsimplify')

# %%
P.rsimplify()  #kill  root of poqw
# Out:
# $\displaystyle P =5 x^{3} y^{2} + 3 x^{2} y - 2 x + 3 y + 12$

# %%
Q=MyEq(2*x**3*y**2+8*x+17,'Q')
# Out:
# $\displaystyle Q =2 x^{3} y^{2} + 8 x + 17$

# %%
P+Q
# Out:
#    3  2      2
# 7⋅x ⋅y  + 3⋅x ⋅y + 6⋅x + 3⋅y + 29

# %%
P.Add(Q)  # P was added Q Add() Mul() Div() Pow() Rpow()
# Out:
# $\displaystyle P =7 x^{3} y^{2} + 3 x^{2} y + 6 x + 3 y + 29$

# %%
P.Mul(3)
# Out:
# $\displaystyle P =21 x^{3} y^{2} + 9 x^{2} y + 18 x + 9 y + 87$

# %%
P(x=1) # evalue.... but not change
# Out:
#     2
# 21⋅y  + 18⋅y + 105

# %%
P(x=a,y=b)
# Out:
#     3  2      2
# 21⋅a ⋅b  + 9⋅a ⋅b + 18⋅a + 9⋅b + 87

# %%
P.set(x=3)  # set.. permanent change
# Out:
# $\displaystyle P =567 y^{2} + 90 y + 141$

# %%
P.s()
# Out:
# $\displaystyle P =567 y^{2} + 90 y + 141$

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)

# %%
from  Libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)

# %% [markdown]
# ![image.png](attachment:b71ed32c-4f76-4277-8c73-31d63b6f86b1.png)

# %%
#MyEq or MQ is the equivalente that MyEq = MyEq ....
Q=MQ(4-3*x,2*x-11)
# Out:
# $\displaystyle 4 - 3 x = 2 x - 11$

# %%
x=Q.solve('x')
# Out:
# $\displaystyle x =3$

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)

# %% [markdown]
# ![image.png](attachment:09db470f-956c-42ca-8a55-2d48dbe4f0db.png)

# %%
Q=MQ((rpow(t,2)+3)/rpow(t,2),2)
# Out:
# $\displaystyle \frac{\sqrt{t} + 3}{\sqrt{t}} = 2$

# %%
Q.crossMul()
# Out:
# $\displaystyle \sqrt{t} + 3 = 2 \sqrt{t}$

# %%
Q.alone(t)
# Out:
# $\displaystyle t = 9$

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)

# %%
from  Libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)

# %% [markdown]
# ![image.png](attachment:4f65bd1f-6098-40c6-a11a-711381e6b6ca.png)

# %%
f=symbols('f')
Q=MQ(D/d,rpow(cfrac(f+p,f-p),2))
# Out:
# $\displaystyle \frac{D}{d} = \sqrt{\frac{f + p}{f - p}}$

# %%
Q.Pow(2)
# Out:
# $\displaystyle \frac{D^{2}}{d^{2}} = \frac{f + p}{f - p}$

# %%
Q.alone(f)
# Out:
# $\displaystyle f = \frac{p \left(D^{2} + d^{2}\right)}{D^{2} - d^{2}}$

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)

# %%
from  Libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:24b47585-ed82-41a0-bbf7-9b4f38ed4550.png)

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)

# %% [markdown]
# ![image.png](attachment:6d4334f9-2eeb-482b-9a66-3ba9b7e47520.png)

# %%
Q=MyEq(3*x*x*x+x*x+3*x+5,'Q')
# Out:
# $\displaystyle Q =3 x^{3} + x^{2} + 3 x + 5$

# %%
Q.Div(x+1)
# Out:
# $\displaystyle Q =\frac{3 x^{3} + x^{2} + 3 x + 5}{x + 1}$

# %%
Q.factor()
# Out:
# $\displaystyle Q =3 x^{2} - 2 x + 5$
