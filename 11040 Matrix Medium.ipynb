# %% [markdown]
# ![image.png](attachment:b179179d-c4ed-4d73-8fb4-f4207cef78d2.png)

# %% [markdown]
# ![image.png](attachment:fe4d89c2-2fe0-4968-89ec-eacf08018c0b.png)

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)

# %% [markdown]
# ![image.png](attachment:66e10b8e-8fe6-4b76-8bfb-9c0b04ca5bef.png)

# %%
from  libaldomath  import *
from  MyMatrix  import *
# this cell will be initializing your variables

# %%
A=MyMat((a, 1), (0, a))
B=MyMat((a, 0), (1, a))
C=MyMat((a**(n + 4)*(n + 1), a**(n + 5)), (a**(n + 5), 0))
X=MyMat((x1,x2),(x3,x4))
# Out:
# ⎡a  1⎤
# ⎢    ⎥
# ⎣0  a⎦
# ⎡a  0⎤
# ⎢    ⎥
# ⎣1  a⎦
# ⎡ n + 4           n + 5⎤
# ⎢a     ⋅(n + 1)  a     ⎥
# ⎢                      ⎥
# ⎢     n + 5            ⎥
# ⎣    a             0   ⎦
# ⎡x₁  x₂⎤
# ⎢      ⎥
# ⎣x₃  x₄⎦

# %%
A.Pow(n)
# Out:
# ⎡ n   n - 1  ⎤
# ⎢a   a     ⋅n⎥
# ⎢            ⎥
# ⎢        n   ⎥
# ⎣0      a    ⎦

# %%
AX=A*X
AX
# Out:
# ⎡ n       n - 1        n       n - 1     ⎤
# ⎢a ⋅x₁ + a     ⋅n⋅x₃  a ⋅x₂ + a     ⋅n⋅x₄⎥
# ⎢                                        ⎥
# ⎢        n                    n          ⎥
# ⎣       a ⋅x₃                a ⋅x₄       ⎦

# %%
AXB=AX*B.M

# %%
R=MyMat(AXB-C.M)
# Out:
# ⎡  ⎛ n       n - 1     ⎞    n       n - 1         n + 4            ⎛ n       n
# ⎢a⋅⎝a ⋅x₁ + a     ⋅n⋅x₃⎠ + a ⋅x₂ + a     ⋅n⋅x₄ - a     ⋅(n + 1)  a⋅⎝a ⋅x₂ + a
# ⎢
# ⎢                      n       n       n + 5
# ⎣                   a⋅a ⋅x₃ + a ⋅x₄ - a                                      a
#
#  - 1     ⎞    n + 5⎤
#     ⋅n⋅x₄⎠ - a     ⎥
#                    ⎥
#   n                ⎥
# ⋅a ⋅x₄             ⎦

# %%
R.set(x4=0)
# Out:
# ⎡  ⎛ n       n - 1     ⎞    n       n + 4           n + 1       n + 5⎤
# ⎢a⋅⎝a ⋅x₁ + a     ⋅n⋅x₃⎠ + a ⋅x₂ - a     ⋅(n + 1)  a     ⋅x₂ - a     ⎥
# ⎢                                                                    ⎥
# ⎢                n + 1       n + 5                                   ⎥
# ⎣               a     ⋅x₃ - a                              0         ⎦

# %%
x22=simplesolve(R(0,1),x2,'simplify','show')
# Out:
# $\displaystyle x2 =a^{4}$

# %%
R.set(x2=a**4)
# Out:
# ⎡ n         n + 1       n + 4     ⎤
# ⎢a ⋅n⋅x₃ + a     ⋅x₁ - a     ⋅n  0⎥
# ⎢                                 ⎥
# ⎢       n + 1       n + 5         ⎥
# ⎣      a     ⋅x₃ - a             0⎦

# %%
x33=simplesolve(R(1,0),x3,'simplify','show')
# Out:
# $\displaystyle x3 =a^{4}$

# %%
R.set(x3=a**4)
# Out:
# ⎡ n + 1      ⎤
# ⎢a     ⋅x₁  0⎥
# ⎢            ⎥
# ⎣    0      0⎦

# %%
x11=simplesolve(R(0,0),x1,'simplify','show')
# Out:
# $\displaystyle x1 =0$

# %%
X=MyMat((x11,x22),(x33,0))
# Out:
# ⎡     4⎤
# ⎢0   a ⎥
# ⎢      ⎥
# ⎢ 4    ⎥
# ⎣a   0 ⎦

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)

# %% [markdown]
# ![image.png](attachment:3e37af2c-69e1-4e02-8f1a-5e444d6855e6.png)

# %%
from  libaldomath  import *
from  MyMatrix  import *
# this cell will be initializing your variables

# %%
A=MyMat((1,-1),(0,1))
# Out:
# ⎡1  -1⎤
# ⎢     ⎥
# ⎣0  1 ⎦

# %%
A.M+A.pow(2)
# Out:
# ⎡2  -3⎤
# ⎢     ⎥
# ⎣0  2 ⎦

# %%
A.M+A.pow(2)+A.pow(3)
# Out:
# ⎡3  -6⎤
# ⎢     ⎥
# ⎣0  3 ⎦

# %%
A.M+A.pow(2)+A.pow(3)+A.pow(4)
# Out:
# ⎡4  -10⎤
# ⎢      ⎥
# ⎣0   4 ⎦

# %%
-1-2-3-4
# Out:
# -10

# %%
A.M+A.pow(2)+A.pow(3)+A.pow(4)+A.pow(5)
# Out:
# ⎡5  -15⎤
# ⎢      ⎥
# ⎣0   5 ⎦

# %%
-1-2-3-4-5
# Out:
# -15

# %%
A.M+A.pow(2)+A.pow(3)+A.pow(4)+A.pow(5)+A.pow(6)
# Out:
# ⎡6  -21⎤
# ⎢      ⎥
# ⎣0   6 ⎦

# %%
-1-2-3-4-5-6
# Out:
# -21

# %%
def Mn(n):
    ks=-1*n*(n-1)/2
    A=MyMat((n,ks),(0,n))

# %%
Mn(2)
# Out:
# ⎡2  -1.0⎤
# ⎢       ⎥
# ⎣0   2  ⎦

# %%
Mn(6)
# Out:
# ⎡6  -15.0⎤
# ⎢        ⎥
# ⎣0    6  ⎦

# %%
Mn(n)
# Out:
# ⎡   -n⋅(n - 1) ⎤
# ⎢n  ───────────⎥
# ⎢        2     ⎥
# ⎢              ⎥
# ⎣0       n     ⎦

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)

# %%
from  libaldomath  import *
from  MyMatrix  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:14a3cf97-5117-4ba9-b9ce-bdb34bee0ebe.png)

# %% [markdown]
# ![image.png](attachment:efd0d797-3b1a-4521-aee0-f32cce10446a.png)

# %%
A=MyMat((1,1,1),(4,0,1),(0,4,2))
B=createMatrix(3,3,'b','simetric')
C=createMatrix(3,3,'c','asimetric')
# Out:
# ⎡1  1  1⎤
# ⎢       ⎥
# ⎢4  0  1⎥
# ⎢       ⎥
# ⎣0  4  2⎦
# ⎡b₀₀  b₁₀  b₂₀⎤
# ⎢             ⎥
# ⎢b₁₀  b₁₁  b₂₁⎥
# ⎢             ⎥
# ⎣b₂₀  b₂₁  b₂₂⎦
# ⎡c₀₀  -c₁₀  -c₂₀⎤
# ⎢               ⎥
# ⎢c₁₀  c₁₁   -c₂₁⎥
# ⎢               ⎥
# ⎣c₂₀  c₂₁   c₂₂ ⎦

# %%
B.set(b00=1)
B.set(b11=0)
B.set(b22=2)
# Out:
# ⎡ 1   b₁₀  b₂₀⎤
# ⎢             ⎥
# ⎢b₁₀  b₁₁  b₂₁⎥
# ⎢             ⎥
# ⎣b₂₀  b₂₁  b₂₂⎦
# ⎡ 1   b₁₀  b₂₀⎤
# ⎢             ⎥
# ⎢b₁₀   0   b₂₁⎥
# ⎢             ⎥
# ⎣b₂₀  b₂₁  b₂₂⎦
# ⎡ 1   b₁₀  b₂₀⎤
# ⎢             ⎥
# ⎢b₁₀   0   b₂₁⎥
# ⎢             ⎥
# ⎣b₂₀  b₂₁   2 ⎦

# %%
C.set(c00=0)
C.set(c11=0)
C.set(c22=0)
# Out:
# ⎡ 0   -c₁₀  -c₂₀⎤
# ⎢               ⎥
# ⎢c₁₀  c₁₁   -c₂₁⎥
# ⎢               ⎥
# ⎣c₂₀  c₂₁   c₂₂ ⎦
# ⎡ 0   -c₁₀  -c₂₀⎤
# ⎢               ⎥
# ⎢c₁₀   0    -c₂₁⎥
# ⎢               ⎥
# ⎣c₂₀  c₂₁   c₂₂ ⎦
# ⎡ 0   -c₁₀  -c₂₀⎤
# ⎢               ⎥
# ⎢c₁₀   0    -c₂₁⎥
# ⎢               ⎥
# ⎣c₂₀  c₂₁    0  ⎦

# %%
BC=MyMat(B+C)
# Out:
# ⎡    1      b₁₀ - c₁₀  b₂₀ - c₂₀⎤
# ⎢                               ⎥
# ⎢b₁₀ + c₁₀      0      b₂₁ - c₂₁⎥
# ⎢                               ⎥
# ⎣b₂₀ + c₂₀  b₂₁ + c₂₁      2    ⎦

# %%
ABC=MyMat(A-BC)
# Out:
# ⎡      0         -b₁₀ + c₁₀ + 1  -b₂₀ + c₂₀ + 1⎤
# ⎢                                              ⎥
# ⎢-b₁₀ - c₁₀ + 4        0         -b₂₁ + c₂₁ + 1⎥
# ⎢                                              ⎥
# ⎣  -b₂₀ - c₂₀    -b₂₁ - c₂₁ + 4        0       ⎦

# %%
simplesolve(ABC.vecdata(),'show')
# Out:
# $\displaystyle b10 =\frac{5}{2}$
# $\displaystyle b20 =\frac{1}{2}$
# $\displaystyle b21 =\frac{5}{2}$
# $\displaystyle c10 =\frac{3}{2}$
# $\displaystyle c20 =- \frac{1}{2}$
# $\displaystyle c21 =\frac{3}{2}$
# [5/2, 1/2, 5/2, 3/2, -1/2, 3/2]

# %%
B.set(b10=cfrac(5,2),b20=cfrac(1,2),b21=cfrac(5,2))
# Out:
# ⎡ 1   5/2  1/2⎤
# ⎢             ⎥
# ⎢5/2   0   5/2⎥
# ⎢             ⎥
# ⎣1/2  5/2   2 ⎦

# %%
simplify(1+cfrac(5,2)+cfrac(1,2))
# Out:
# 4

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)

# %%
from  libaldomath  import *
from  MyMatrix  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:14a3cf97-5117-4ba9-b9ce-bdb34bee0ebe.png)

# %% [markdown]
# ![image.png](attachment:a943bd4c-1a1a-4a19-809a-482cd40e23cc.png)

# %%
A=MyMat((n+1,n+2,n+3,n+4),(n+2,n+3,n+4,n+5),(n+3,n+4,n+5,n+6),(n+4,n+5,n+6,n+7))
# Out:
# ⎡n + 1  n + 2  n + 3  n + 4⎤
# ⎢                          ⎥
# ⎢n + 2  n + 3  n + 4  n + 5⎥
# ⎢                          ⎥
# ⎢n + 3  n + 4  n + 5  n + 6⎥
# ⎢                          ⎥
# ⎣n + 4  n + 5  n + 6  n + 7⎦

# %%
A.D
# Out:
# 0

# %%
F=MyEq(x**4-3*x*x+2,'F',var=x)
# Out:
# $\displaystyle F =x^{4} - 3 x^{2} + 2$

# %%
F.factor()
# Out:
# $\displaystyle F =\left(x - 1\right) \left(x + 1\right) \left(x^{2} - 2\right)$

# %%
F.factor('sqrt')
# Out:
# $\displaystyle F =\left(x - 1\right) \left(x + 1\right) \left(x - \sqrt{2}\right) \left(x + \sqrt{2}\right)$

# %%
Q=MyEq(x/((1+2/x)*(1-1/x)),'Q',var=x)
# Out:
# $\displaystyle Q =\frac{x}{\left(1 - \frac{1}{x}\right) \left(1 + \frac{2}{x}\right)}$

# %%
simplify(Q(sqrt(2)))
# Out:
# 2

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)

# %%
from  libaldomath  import *
from  MyMatrix  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:14a3cf97-5117-4ba9-b9ce-bdb34bee0ebe.png)

# %% [markdown]
# ![image.png](attachment:a00bc1d0-db3e-4885-8c8e-1e2a33958a7a.png)

# %%
 def xxx(var,var2):
        mm=[x**2 for x in range(var,var2+1)]
        return mm

# %%
xxx(1,5)
# Out:
# [1, 4, 9, 16, 25]

# %%
xxx(2,6)
# Out:
# [4, 9, 16, 25, 36]

# %%
args=[5,5]+xxx(1,5)+xxx(2,6)+xxx(3,7)+xxx(4,8)+xxx(5,10)+['A']

# %%
A=MyMat(*args)
# Out:
# ⎡ 5 ⎤
# ⎢   ⎥
# ⎢ 5 ⎥
# ⎢   ⎥
# ⎢ 1 ⎥
# ⎢   ⎥
# ⎢ 4 ⎥
# ⎢   ⎥
# ⎢ 9 ⎥
# ⎢   ⎥
# ⎢16 ⎥
# ⎢   ⎥
# ⎢25 ⎥
# ⎢   ⎥
# ⎢ 4 ⎥
# ⎢   ⎥
# ⎢ 9 ⎥
# ⎢   ⎥
# ⎢16 ⎥
# ⎢   ⎥
# ⎢25 ⎥
# ⎢   ⎥
# ⎢36 ⎥
# ⎢   ⎥
# ⎢ 9 ⎥
# ⎢   ⎥
# ⎢16 ⎥
# ⎢   ⎥
# ⎢25 ⎥
# ⎢   ⎥
# ⎢36 ⎥
# ⎢   ⎥
# ⎢49 ⎥
# ⎢   ⎥
# ⎢16 ⎥
# ⎢   ⎥
# ⎢25 ⎥
# ⎢   ⎥
# ⎢36 ⎥
# ⎢   ⎥
# ⎢49 ⎥
# ⎢   ⎥
# ⎢64 ⎥
# ⎢   ⎥
# ⎢25 ⎥
# ⎢   ⎥
# ⎢36 ⎥
# ⎢   ⎥
# ⎢49 ⎥
# ⎢   ⎥
# ⎢64 ⎥
# ⎢   ⎥
# ⎢81 ⎥
# ⎢   ⎥
# ⎢100⎥
# ⎢   ⎥
# ⎣ A ⎦

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)

# %%
from  libaldomath  import *
from  MyMatrix  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:14a3cf97-5117-4ba9-b9ce-bdb34bee0ebe.png)

# %% [markdown]
# ![image.png](attachment:70592c54-0db4-4580-abbd-ee36c5c35f93.png)

# %%
A=MyMat((x-1,x*x-1,x**3-1),(2*x-4,x*x-4,x**3-8),(3*x-9,x*x-9,x**3-27))
# Out:
# ⎡          2       3     ⎤
# ⎢ x - 1   x  - 1  x  - 1 ⎥
# ⎢                        ⎥
# ⎢          2       3     ⎥
# ⎢2⋅x - 4  x  - 4  x  - 8 ⎥
# ⎢                        ⎥
# ⎢          2       3     ⎥
# ⎣3⋅x - 9  x  - 9  x  - 27⎦

# %%
A.D
# Out:
#      4       3       2
# - 2⋅x  + 12⋅x  - 22⋅x  + 12⋅x

# %%
F=MyEq(A.D,'F',var=x)
# Out:
# $\displaystyle F =- 2 x^{4} + 12 x^{3} - 22 x^{2} + 12 x$

# %%
F.factor()
# Out:
# $\displaystyle F =- 2 x \left(x - 3\right) \left(x - 2\right) \left(x - 1\right)$

# %%
v=F.solve(x,'all');v
# Out:
# $\displaystyle \left[ 0, \  1, \  2, \  3\right]$
# [0, 1, 2, 3]

# %%
sum(v)
# Out:
# 6

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)
