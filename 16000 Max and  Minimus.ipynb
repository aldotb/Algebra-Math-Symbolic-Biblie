# %% [markdown]
# ![image.png](attachment:4ccff57c-4757-48d2-983c-e7def128ca12.png)

# %%
from  libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:e31313f2-d8f2-4240-9eb6-dbaf2488827b.png)

# %% [markdown]
# ![image.png](attachment:0e78acea-b012-477f-89e0-507864fa255f.png)

# %%
Q=MyEq(x*(10-x),'Q',var=x)
# Out:
# $\displaystyle Q =x \left(10 - x\right)$

# %%
M=MyEq(Q.diff(),'Max',var=x)
# Out:
# $\displaystyle Max =10 - 2 x$

# %%
x=M.solve('x')
# Out:
# $\displaystyle x =5$

# %% [markdown]
# ![image.png](attachment:e31313f2-d8f2-4240-9eb6-dbaf2488827b.png)

# %% [markdown]
# ![image.png](attachment:15a28cfa-6427-429a-b5a6-ce3bff699f32.png)

# %%
from  libaldomath  import *
# this cell will be initializing your variables

# %%
A=MyEq(x*y,'A',var=x)
# Out:
# $\displaystyle A =x y$

# %%
A.set(y=60-x)
# Out:
# $\displaystyle A =x \left(60 - x\right)$

# %%
dA=A.diff('dA')
# Out:
# $\displaystyle dA =60 - 2 x$

# %%
x=dA.solve('x')
# Out:
# $\displaystyle x =30$

# %%
from  libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:e31313f2-d8f2-4240-9eb6-dbaf2488827b.png)

# %% [markdown]
# ![image.png](attachment:44a5d573-8960-4f25-9a80-05fd0aa4c166.png)

# %%
A=MyEq(a*b/2,'A',var=a)
# Out:
# $\displaystyle A =\frac{a b}{2}$

# %%
Q=MQ((b-2),2/(a-1))
# Out:
# $\displaystyle b - 2 = \frac{2}{a - 1}$

# %%
b=Q.solve(b)
# Out:
# $\displaystyle b =\frac{2 a}{a - 1}$

# %%
A.update(b)
# Out:
# $\displaystyle A =\frac{a^{2}}{a - 1}$

# %%
dA=A.diff('dA')
# Out:
# $\displaystyle dA =- \frac{a^{2}}{\left(a - 1\right)^{2}} + \frac{2 a}{a - 1}$

# %%
dA.reducecero()
# Out:
# $\displaystyle dA =a - 2$

# %%
a=dA.solve('a')
# Out:
# $\displaystyle a =2$

# %%
b.update(a)
# Out:
# $\displaystyle b =4$

# %%
from  libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:e31313f2-d8f2-4240-9eb6-dbaf2488827b.png)

# %% [markdown]
# ![image.png](attachment:b4e390a8-7074-4e7d-91d8-9d6163157c04.png)

# %%
t1=MyEq(sqrt(25+x*x)/2,'t1',var=x)
t2=MyEq((6-x)/4,'t2',var=x)
# Out:
# $\displaystyle t1 =\frac{\sqrt{x^{2} + 25}}{2}$
# $\displaystyle t2 =\frac{3}{2} - \frac{x}{4}$

# %%
t1.Add(t2)
# Out:
# $\displaystyle t1 =- \frac{x}{4} + \frac{\sqrt{x^{2} + 25}}{2} + \frac{3}{2}$

# %%
T=t1.diff('T')
# Out:
# $\displaystyle T =\frac{x}{2 \sqrt{x^{2} + 25}} - \frac{1}{4}$

# %%
x=T.solve('x')
# Out:
# $\displaystyle x =\frac{5 \sqrt{3}}{3}$

# %%
from  libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:e31313f2-d8f2-4240-9eb6-dbaf2488827b.png)

# %% [markdown]
# ![image.png](attachment:9389a2e4-9e52-46c9-9ca0-62db8b321639.png)

# %%
r1=(3-h)/3 # for simillar triangles
g1=sqrt(r1**2+h**2,2)
area=pi*r1*g1

# %%
A=MyEq(area,'A',var=h)
# Out:
# $\displaystyle A =\pi \left(1 - \frac{h}{3}\right) \sqrt{h^{2} + \left(1 - \frac{h}{3}\right)^{2}}$

# %%
dA=A.diff(h,'dA')
# Out:
# $\displaystyle dA =\frac{\pi \left(1 - \frac{h}{3}\right) \left(\frac{10 h}{9} - \frac{1}{3}\right)}{\sqrt{h^{2} + \left(1 - \frac{h}{3}\right)^{2}}} - \frac{\pi \sqrt{h^{2} + \left(1 - \frac{h}{3}\right)^{2}}}{3}$

# %%
# h A is max when dA=0
dA.reducecero()
# Out:
# $\displaystyle dA =\left(4 h - 3\right) \left(5 h - 6\right)$

# %%
h1,h2=dA.solve(h,'all')
# Out:
# $\displaystyle \left[ \frac{3}{4}, \  \frac{6}{5}\right]$

# %%
A(h2)
# Out:
# 9⋅√5⋅π
# ──────
#   25

# %%
from  libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:e31313f2-d8f2-4240-9eb6-dbaf2488827b.png)

# %% [markdown]
# ![image.png](attachment:9c122ee4-82d9-437c-9e25-6b2919f98829.png)

# %% [markdown]
# ![image.png](attachment:6dc0829f-1604-42c1-a776-23d6aac7c2be.png)

# %%
x=MyEq(h*R/sqrt(h*h-R*R),'x',var=h)
# Out:
# $\displaystyle x =\frac{R h}{\sqrt{- R^{2} + h^{2}}}$

# %%
V=MyEq(x*x*pi*h/3,'V',var=h)
# Out:
# $\displaystyle V =\frac{\pi R^{2} h^{3}}{3 \left(- R^{2} + h^{2}\right)}$

# %%
dV=V.diff('dV')
# Out:
# $\displaystyle dV =- \frac{2 \pi R^{2} h^{4}}{3 \left(- R^{2} + h^{2}\right)^{2}} + \frac{\pi R^{2} h^{2}}{- R^{2} + h^{2}}$

# %%
dV.reducecero()
# Out:
# $\displaystyle dV =- 3 R^{2} + h^{2}$

# %%
h=dV.solve('h','signo')
# Out:
# $\displaystyle h =\sqrt{3} R$

# %%
from  libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:85328feb-c61e-4d3e-adf0-a353a750a5d4.png)

# %%
Q1=MyEq(1000-pi*r*r*h,'Q1',var=r)
# Out:
# $\displaystyle Q1 =- \pi h r^{2} + 1000$

# %%
h=Q1.solve('h')
# Out:
# $\displaystyle h =\frac{1000}{\pi r^{2}}$

# %%
C=MyEq(2*pi*r*2+h,'C',var=r)
# Out:
# $\displaystyle C =4 \pi r + \frac{1000}{\pi r^{2}}$

# %%
dC=C.diff('dC')
# Out:
# $\displaystyle dC =4 \pi - \frac{2000}{\pi r^{3}}$

# %%
dC.reducecero()
# Out:
# $\displaystyle dC =\pi^{2} r^{3} - 500$

# %%
r=dC.solve('r')
# Out:
# $\displaystyle r =\frac{5 \cdot 2^{\frac{2}{3}}}{\pi^{\frac{2}{3}}}$

# %%
r.simplify()
# Out:
# $\displaystyle r =\frac{5 \cdot 2^{\frac{2}{3}}}{\pi^{\frac{2}{3}}}$

# %%
h.update(r)
# Out:
# $\displaystyle h =10 \cdot 2^{\frac{2}{3}} \sqrt[3]{\pi}$

# %%
from  libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:e31313f2-d8f2-4240-9eb6-dbaf2488827b.png)

# %% [markdown]
# ![image.png](attachment:4bbdb82b-7430-4457-ad20-e67554777a10.png)

# %%
# usin Line and Points library fom sympy..
L=Line(2*x-y+b)

# %%
P1=Point(1,1)
P2=Point(1,2)
P3=Point(2,2)

# %%
D=MyEq(P1.distance(L)**2+P2.distance(L)**2+P3.distance(L)**2,'D',var=b)
# Out:
# $\displaystyle D =\frac{b^{2}}{5} + \left(- \frac{b}{5} - \frac{2}{5}\right)^{2} + \left(- \frac{b}{5} - \frac{1}{5}\right)^{2} + \left(\frac{2 b}{5} + \frac{2}{5}\right)^{2} + \left(\frac{2 b}{5} + \frac{4}{5}\right)^{2}$

# %%
dD=D.diff('dD')
# Out:
# $\displaystyle dD =\frac{6 b}{5} + \frac{6}{5}$

# %%
b=dD.solve('b')
# Out:
# $\displaystyle b =-1$
