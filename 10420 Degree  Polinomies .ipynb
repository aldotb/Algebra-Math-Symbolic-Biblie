# %% [markdown]
# * solvecomparecoef(MyEqEq,main var,var2solve1,var2solve2,..... )
# * solvecomparecoef(exp1,exp2,main ,var,var2solve1,var2solve2,..... )
#     * exp1 and exp2 = MyEq, math expr, [coeff list]...

# %%
import sys
sys.path.append('Libaldo')
from  libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:20e0cd2a-95b2-4f69-8c93-5299e944d921.png)

# %% [markdown]
# ![image.png](attachment:46908ade-131b-4e1b-baf3-be6287fb119e.png)

# %%
Q1=MQ(2*(a-1)+3*b,17)
Q2=MQ(a+b,2*(a-1))
# Out:
# $\displaystyle 2 a + 3 b - 2 = 17$
# $\displaystyle a + b = 2 a - 2$

# %%
a,b=simplesolve(Q1,Q2)
# Out:
# $\displaystyle a =5$
# $\displaystyle b =3$

# %% [markdown]
# ![image.png](attachment:7b428bb1-4d3b-438c-af57-447beed34dad.png)

# %% [markdown]
# ![image.png](attachment:22df2820-ec12-4caf-b0f4-c759d0c31824.png)

# %% [markdown]
# ![image.png](attachment:7b428bb1-4d3b-438c-af57-447beed34dad.png)

# %%
import sys
sys.path.append('Libaldo')
from  libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:20e0cd2a-95b2-4f69-8c93-5299e944d921.png)

# %% [markdown]
# ![image.png](attachment:c25c3d44-0f91-48c3-b578-7af4b21c3dd7.png)

# %%
Q=MQ((2*a+b)*x**2-6*x+1,6*x*x-(4*a-b)*x+1)
# Out:
# $\displaystyle x^{2} \cdot \left(2 a + b\right) - 6 x + 1 = 6 x^{2} - x \left(4 a - b\right) + 1$

# %%
veccoef=coef_list(Q.L-Q.R,'noncero')
veccoef
# Out:
# [2⋅a + b - 6, 4⋅a - b - 6]

# %%
a,b=simplesolve(*veccoef)
# Out:
# $\displaystyle a =2$
# $\displaystyle b =2$

# %% [markdown]
# ![image.png](attachment:7b428bb1-4d3b-438c-af57-447beed34dad.png)

# %%
import sys
sys.path.append('Libaldo')
from  libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:20e0cd2a-95b2-4f69-8c93-5299e944d921.png)

# %% [markdown]
# ![image.png](attachment:a363fbd1-f4c3-4330-8120-b2a3c2781a70.png)

# %%
findFunc(x+1,['A','D','P','A'],[-1,2,-1,1])
# Out:
#  2⋅x
# ─────
# x - 1

# %%
M=MyEq((a*x+b)/(a*x-b),'M')
# Out:
# $\displaystyle M =\frac{a x + b}{a x - b}$

# %%
M2=MyEq((z+1)/(z-1),'M1')
# Out:
# $\displaystyle M1 =\frac{z + 1}{z - 1}$

# %%
M3=MyEq(1+2/(z-1),'M2')
# Out:
# $\displaystyle M2 =1 + \frac{2}{z - 1}$

# %%
findFunc(x+1,['A','D','P','A'],[-1,2,-1,1])
# Out:
#  2⋅x
# ─────
# x - 1

# %%
F=MyEq(2*x/(x-1),'F')
# Out:
# $\displaystyle F =\frac{2 x}{x - 1}$

# %%
F(2)*F(3)
# Out:
# 12

# %% [markdown]
# ![image.png](attachment:7b428bb1-4d3b-438c-af57-447beed34dad.png)

# %%
import sys
sys.path.append('Libaldo')
from  libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:20e0cd2a-95b2-4f69-8c93-5299e944d921.png)

# %% [markdown]
# ![image.png](attachment:076e049a-1946-4b11-a57a-a5d82e9026e7.png)

# %%
Q=MQ(P,rpow(x**n*P,n))
# Out:
# $\displaystyle P = \left(P x^{n}\right)^{\frac{1}{n}}$

# %%
Q.Pow(n)
# Out:
# $\displaystyle P^{n} = \left(\left(P x^{n}\right)^{\frac{1}{n}}\right)^{n}$

# %%
Q.mulexpo()
# Out:
# $\displaystyle P^{n} = P x^{n}$

# %%
Q.Div(P)
# Out:
# $\displaystyle \frac{P^{n}}{P} = x^{n}$

# %%
Q.joinbase()
# Out:
# $\displaystyle P^{n - 1} = x^{n}$

# %%
Q.Rpow(n-1)
# Out:
# $\displaystyle \left(P^{n - 1}\right)^{\frac{1}{n - 1}} = \left(x^{n}\right)^{\frac{1}{n - 1}}$

# %%
Q.mulexpo()
# Out:
# $\displaystyle P = x^{\frac{n}{n - 1}}$

# %% [markdown]
# ![image.png](attachment:7b428bb1-4d3b-438c-af57-447beed34dad.png)

# %%
import sys
sys.path.append('Libaldo')
from  libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:faac98b0-6904-44f2-94b2-eec3cc2ccb41.png)

# %%
Q=MQ(ppow(ppow(a,x*x),ppow(x,-x)),ppow(a,rpow(cfrac(1,8))))
# Out:
# $\displaystyle \left(a^{x^{2}}\right)^{x^{- x}} = a^{\sqrt{\frac{1}{8}}}$

# %%
Q.mulexpo()
# Out:
# $\displaystyle a^{x^{2} x^{- x}} = a^{\frac{\sqrt{2}}{4}}$

# %%
Q.simplify()
# Out:
# $\displaystyle a^{x^{2 - x}} = a^{\frac{\sqrt{2}}{4}}$

# %%
Q2=MQ(getexpo(Q.L),getexpo(Q.R))
# Out:
# $\displaystyle x^{2 - x} = \frac{\sqrt{2}}{4}$

# %%
Q2.joinbase()
# Out:
# $\displaystyle x^{2 - x} = \frac{\sqrt{2}}{4}$

# %%
Q2.primefactor()
# Out:
# $\displaystyle x^{2 - x} = \frac{2^{1 \cdot \frac{1}{2}}}{2^{2}}$

# %%
Q2.subsubs(2,b)
# Out:
# $\displaystyle x^{b - x} = b^{\frac{1}{b}} b^{- b}$

# %%
Q2.simplify()
# Out:
# $\displaystyle x^{b - x} = b^{- b + \frac{1}{b}}$

# %%
# whit coparation b=1/2,x=1/2

# %%
Q2.set(b=cfrac(1,2))
# Out:
# $\displaystyle x^{- x + \frac{1}{2}} = \left(\frac{1}{2}\right)^{\left(\frac{1}{2}\right)^{-1} - \frac{1}{2}}$

# %%
Q2.Mul(x**x)
# Out:
# $\displaystyle \sqrt{x} = \frac{\sqrt{2} x^{x}}{4}$

# %%
Q2.joinbase()
# Out:
# $\displaystyle \sqrt{x} = \frac{\sqrt{2} x^{x}}{4}$

# %%
#  then  x=1/2

# %% [markdown]
# ![image.png](attachment:7b428bb1-4d3b-438c-af57-447beed34dad.png)

# %%
import sys
sys.path.append('Libaldo')
from  libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:20e0cd2a-95b2-4f69-8c93-5299e944d921.png)

# %% [markdown]
# ![image.png](attachment:2bc6ec1a-0b27-47bd-901d-5d48a8df90bb.png)

# %%
P1=x**m+a**m
P2=(b**2*a)**m+x**m
Q=MQ(rpow(P1/P2,m),1/b)
# Out:
# $\displaystyle \left(\frac{a^{m} + x^{m}}{x^{m} + \left(a b^{2}\right)^{m}}\right)^{\frac{1}{m}} = \frac{1}{b}$

# %%
Q.Pow(m)
# Out:
# $\displaystyle \left(\left(\frac{a^{m} + x^{m}}{x^{m} + \left(a b^{2}\right)^{m}}\right)^{\frac{1}{m}}\right)^{m} = \left(\frac{1}{b}\right)^{m}$

# %%
Q.mulexpo()
# Out:
# $\displaystyle \frac{a^{m} + x^{m}}{x^{m} + \left(a b^{2}\right)^{m}} = b^{- m}$

# %%
Q.crossMul()
# Out:
# $\displaystyle b^{m} \left(a^{m} + x^{m}\right) = x^{m} + \left(a b^{2}\right)^{m}$

# %%
Q.mulexpo()
# Out:
# $\displaystyle b^{m} \left(a^{m} + x^{m}\right) = a^{m} b^{2 m} + x^{m}$

# %%
Q.Substrac(a**m*b**m+x**m)
# Out:
# $\displaystyle - a^{m} b^{m} + b^{m} \left(a^{m} + x^{m}\right) - x^{m} = a^{m} b^{2 m} - a^{m} b^{m}$

# %%
Q.factor()
# Out:
# $\displaystyle x^{m} \left(b^{m} - 1\right) = a^{m} b^{m} \left(b^{m} - 1\right)$

# %%
Q.mulexpo()
# Out:
# $\displaystyle x^{m} \left(b^{m} - 1\right) = a^{m} b^{m} \left(b^{m} - 1\right)$

# %%
Q.Div(b**m-1)
# Out:
# $\displaystyle x^{m} = a^{m} b^{m}$

# %%
 Q.Rpow(m)
# Out:
# $\displaystyle \left(x^{m}\right)^{\frac{1}{m}} = \left(a^{m} b^{m}\right)^{\frac{1}{m}}$

# %%
Q.mulexpo()
# Out:
# $\displaystyle x^{m \frac{1}{m}} = a^{m \frac{1}{m}} b^{m \frac{1}{m}}$

# %%
Q.simplify()
# Out:
# $\displaystyle x = a b$

# %%
import sys
sys.path.append('Libaldo')
from  libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:20e0cd2a-95b2-4f69-8c93-5299e944d921.png)

# %% [markdown]
# ![image.png](attachment:e2b401a8-e5d6-4684-a4af-e30502166fcf.png)

# %%
P1=(b**b*x)**x
P2=b**(b**(1-b))
Q=MQ(P1,P2)
# Out:
# $\displaystyle \left(b^{b} x\right)^{x} = b^{b^{1 - b}}$

# %%
Q.Pow(b**b)
# Out:
# $\displaystyle \left(\left(b^{b} x\right)^{x}\right)^{b^{b}} = \left(b^{b^{1 - b}}\right)^{b^{b}}$

# %%
Q.simplify('R')
# Out:
# $\displaystyle \left(\left(b^{b} x\right)^{x}\right)^{b^{b}} = \left(b^{b^{1 - b}}\right)^{b^{b}}$

# %%
Q2=MQ(b**b*x,b)
# Out:
# $\displaystyle b^{b} x = b$

# %%
x=Q2.solve(x)
# Out:
# $\displaystyle x =b^{1 - b}$

# %%
P=MQ(x,b**(1-b))
# Out:
# $\displaystyle b^{1 - b} = b^{1 - b}$

# %% [markdown]
# ![image.png](attachment:7b428bb1-4d3b-438c-af57-447beed34dad.png)

# %%
import sys
sys.path.append('Libaldo')
from  libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:20e0cd2a-95b2-4f69-8c93-5299e944d921.png)

# %% [markdown]
# ![image.png](attachment:cca4c9ab-6cb9-48a0-8d91-38758c4ff733.png)

# %%
P1=(4**x-3**(x-cfrac(1,2)))
P2=3**(x+cfrac(1,2))-2**(2*x-1)
Q=MQ(P1,P2)
# Out:
# $\displaystyle 4^{x} - 3^{x - \frac{1}{2}} = - 2^{2 x - 1} + 3^{x + \frac{1}{2}}$

# %%
Q.sum2mulexpo()
# Out:
# $\displaystyle - 3^{x} 3^{- \frac{1}{2}} + 4^{x} = - \frac{2^{2 x}}{2} + 3^{x} 3^{\frac{1}{2}}$

# %%
Q.Mul(6)
# Out:
# $\displaystyle - 2 \cdot 3^{x + \frac{1}{2}} + 6 \cdot 4^{x} = 6 \cdot 3^{x + \frac{1}{2}} - 3 \cdot 4^{x}$

# %%
Q.pow2powpow()
# Out:
# $\displaystyle - 2 \cdot 3^{x + \frac{1}{2}} + 6 \cdot 4^{x} = 6 \cdot 3^{x + \frac{1}{2}} - 3 \cdot 4^{x}$

# %%
Q.Add(3*4**x)
# Out:
# $\displaystyle - 2 \cdot 3^{x + \frac{1}{2}} + 9 \cdot 4^{x} = 6 \cdot 3^{x + \frac{1}{2}}$

# %%
Q.Add(2*sqrt(3)*3**x)
# Out:
# $\displaystyle 2 \sqrt{3} \cdot 3^{x} - 2 \cdot 3^{x + \frac{1}{2}} + 9 \cdot 4^{x} = 2 \sqrt{3} \cdot 3^{x} + 6 \cdot 3^{x + \frac{1}{2}}$

# %%
Q.Div(9*3**x)
# Out:
# $\displaystyle 3^{- x} 4^{x} = \frac{8 \cdot 3^{- x} 3^{x + \frac{1}{2}}}{9}$

# %%
Q.simplify()
# Out:
# $\displaystyle \left(\frac{4}{3}\right)^{x} = \frac{8 \sqrt{3}}{9}$

# %%
Q.log()
# Out:
# $\displaystyle \log{\left(\left(\frac{4}{3}\right)^{x} \right)} = \log{\left(\frac{8 \sqrt{3}}{9} \right)}$

# %%
Q.lexpand()
# Out:
# $\displaystyle x \left(- \log{\left(3 \right)} + 2 \log{\left(2 \right)}\right) = - \frac{3 \log{\left(3 \right)}}{2} + 3 \log{\left(2 \right)}$

# %%
Q.get_args(0,1)
# Out:
# -log(3) + 2⋅log(2)

# %%
Q.Div(Q.get_args(0,1))
# Out:
# $\displaystyle x = \frac{\log{\left(\frac{8 \sqrt{3}}{9} \right)}}{\log{\left(\frac{4}{3} \right)}}$

# %%
Q.simplify()
# Out:
# $\displaystyle x = \frac{3}{2}$
