# %%
from  libaldomath  import *
from lib_MyIntegral import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:e31313f2-d8f2-4240-9eb6-dbaf2488827b.png)

# %% [markdown]
# ![image.png](attachment:3b8cb492-1d54-4078-b688-443b95bb8af1.png)

# %%
y=MyIntg(sin(3*x)**2,'y')
# Out:
# $\displaystyle y=\int \sin^{2}{\left(3 x \right)}\, dx$

# %%
y.doit()
# Out:
# x   sin(3⋅x)⋅cos(3⋅x)
# ─ - ─────────────────
# 2           6

# %% [markdown]
# ![image.png](attachment:e31313f2-d8f2-4240-9eb6-dbaf2488827b.png)

# %% [markdown]
# ![image.png](attachment:3b8cb492-1d54-4078-b688-443b95bb8af1.png)

# %%
y=MyIntg(x**5*sqrt(1-x*x),'y')
# Out:
# $\displaystyle y=\int x^{5} \sqrt{1 - x^{2}}\, dx$

# %% [markdown]
# ![image.png](attachment:68893262-c805-41f1-932d-1de010f7cbf1.png)

# %% [markdown]
# ![image.png](attachment:42765d1c-6faf-49c9-b58f-ab419c98411d.png)

# %% [markdown]
# ![image.png](attachment:e31313f2-d8f2-4240-9eb6-dbaf2488827b.png)

# %% [markdown]
# ![image.png](attachment:245252bc-3aa3-4f46-a5e8-7fe7967ce5b7.png)

# %%
y=MyIntg(1/(x*sqrt(x**3-1)),'y')
# Out:
# $\displaystyle y=\int \frac{1}{x \sqrt{x^{3} - 1}}\, dx$

# %%
y.doit()  #??
# Out:
# ⎧         ⎛ 1  ⎞
# ⎪2⋅ⅈ⋅acosh⎜────⎟
# ⎪         ⎜ 3/2⎟
# ⎪         ⎝x   ⎠       1
# ⎪───────────────  for ──── > 1
# ⎪       3             │ 3│
# ⎪                     │x │
# ⎨
# ⎪       ⎛ 1  ⎞
# ⎪-2⋅asin⎜────⎟
# ⎪       ⎜ 3/2⎟
# ⎪       ⎝x   ⎠
# ⎪──────────────    otherwise
# ⎪      3
# ⎩

# %%
y=MyIntg(1/(x*sqrt(x**3-1)),'y')
# Out:
# $\displaystyle y=\int \frac{1}{x \sqrt{x^{3} - 1}}\, dx$

# %%
y.changevar(x**3,t*t+1)
# Out:
# $\displaystyle y=\int \frac{2 t}{\left(3 t^{2} + 3\right) \sqrt{t^{2}}}\, dt$

# %%
y.rsimplify()
# Out:
# $\displaystyle y=\int \frac{2}{3 \left(t^{2} + 1\right)}\, dt$

# %%
y.doit('update')
# Out:
# $\displaystyle y=\frac{2 \operatorname{atan}{\left(t \right)}}{3}$

# %%
y.subs(t,sqrt(x**3-1))
# Out:
# $\displaystyle y=\frac{2 \operatorname{atan}{\left(\sqrt{x^{3} - 1} \right)}}{3}$

# %% [markdown]
# ![image.png](attachment:6c4d34eb-3509-4473-996b-211519d18748.png)

# %% [markdown]
# ![image.png](attachment:1dd0c23f-a11e-4b38-88fa-d57f1043153d.png)

# %%
import sys
sys.path.append('Libaldo')
from  libaldomath  import *
from lib_simpleintegral import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:e31313f2-d8f2-4240-9eb6-dbaf2488827b.png)

# %% [markdown]
# ![image.png](attachment:b00978f3-5c63-42c1-a9d0-d3549908e985.png)

# %%
y=MyIntg(x**4/rpow(x**5+1,7),'y')
# Out:
# $\displaystyle y=\int x^{4} \left(x^{5} + 1\right)^{- \frac{1}{7}}\, dx$

# %%
y.doit() #??
# Out:
#                1                            1                       1
#               -─                           -─                      -─
#                7         -1                 7         -1            7
#    10 ⎛ 5    ⎞   ⎛     1⎞        5 ⎛ 5    ⎞   ⎛     1⎞     ⎛ 5    ⎞   ⎛     1⎞
#   x  ⋅⎝x  + 1⎠  ⋅⎜-1 + ─⎟     2⋅x ⋅⎝x  + 1⎠  ⋅⎜-1 + ─⎟     ⎝x  + 1⎠  ⋅⎜-1 + ─⎟
#                  ⎝     7⎠                     ⎝     7⎠                ⎝     7⎠
# - ───────────────────────── - ────────────────────────── - ───────────────────
#               5                           5                          5
#            5⋅x  + 5                    5⋅x  + 5                   5⋅x  + 5
#
#
#
# -1
#
#
#
# ──

# %%
y.changevar(x**5+1,t)
# Out:
# $\displaystyle y=\int \frac{1}{5 \sqrt[7]{t}}\, dt$

# %%
y.doit('update')
# Out:
# $\displaystyle y=\frac{7 t^{\frac{6}{7}}}{30}$

# %%
y.subs(t,x**5+1)
# Out:
# $\displaystyle y=\frac{7 \left(x^{5} + 1\right)^{\frac{6}{7}}}{30}$
