# %% [markdown]
# ![image.png](attachment:b179179d-c4ed-4d73-8fb4-f4207cef78d2.png)

# %% [markdown]
# ![image.png](attachment:fe4d89c2-2fe0-4968-89ec-eacf08018c0b.png)

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)

# %%
from  Libaldomath  import *
from  lib_MyMatrix  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:14a3cf97-5117-4ba9-b9ce-bdb34bee0ebe.png)

# %% [markdown]
# ![image.png](attachment:0559b069-8262-469d-8e56-8177cd448e44.png)

# %%
A=MyMat(a,b,c,d,2,2)
# Out:
# ⎡a  b⎤
# ⎢    ⎥
# ⎣c  d⎦

# %%
B=MyMat(A.pow(2)-A.mul(a+d))
# Out:
# ⎡ 2                                          ⎤
# ⎢a  - a⋅(a + d) + b⋅c   a⋅b + b⋅d - b⋅(a + d)⎥
# ⎢                                            ⎥
# ⎢                              2             ⎥
# ⎣a⋅c + c⋅d - c⋅(a + d)  b⋅c + d  - d⋅(a + d) ⎦

# %%
B.Add(a*d-b*c)
# Out:
# ⎡       2                                                            ⎤
# ⎢      a  + a⋅d - a⋅(a + d)         a⋅b + a⋅d - b⋅c + b⋅d - b⋅(a + d)⎥
# ⎢                                                                    ⎥
# ⎢                                                2                   ⎥
# ⎣a⋅c + a⋅d - b⋅c + c⋅d - c⋅(a + d)        a⋅d + d  - d⋅(a + d)       ⎦

# %%
B.simplify()
# Out:
# ⎡    0      a⋅d - b⋅c⎤
# ⎢                    ⎥
# ⎣a⋅d - b⋅c      0    ⎦

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)

# %%
from  Libaldomath  import *
from  lib_MyMatrix  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)

# %% [markdown]
# ![image.png](attachment:eeb32280-4ba6-4141-b0ba-d002b09e60d6.png)

# %%
A=MyMat(1,0,2,2,1,-1,1,3,4,3,3)
# Out:
# ⎡1  0  2 ⎤
# ⎢        ⎥
# ⎢2  1  -1⎥
# ⎢        ⎥
# ⎣1  3  4 ⎦

# %%
B=MyMat(A.Adj())
# Out:
# ⎡7   6   -2⎤
# ⎢          ⎥
# ⎢-9  2   5 ⎥
# ⎢          ⎥
# ⎣5   -3  1 ⎦

# %%
B(0,1)+B(0,2)+B(1,0)
# Out:
# -5

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)

# %%
from  Libaldomath  import *
from  lib_MyMatrix  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:a168ac49-a66a-4253-9a77-f24ece35d5ae.png)

# %%
A=MyMat(a-8,p-b,m-a,a-5,b+6,n-b,5-a,b-2,-2*c+5,3,3)
# Out:
# ⎡a - 8  -b + p  -a + m ⎤
# ⎢                      ⎥
# ⎢a - 5  b + 6   -b + n ⎥
# ⎢                      ⎥
# ⎣5 - a  b - 2   5 - 2⋅c⎦

# %%
B=MyMat(diag(x,y,z))
# Out:
# ⎡x  0  0⎤
# ⎢       ⎥
# ⎢0  y  0⎥
# ⎢       ⎥
# ⎣0  0  z⎦

# %%
Q=MyMat(A-B)
# Out:
# ⎡a - x - 8   -b + p       -a + m   ⎤
# ⎢                                  ⎥
# ⎢  a - 5    b - y + 6     -b + n   ⎥
# ⎢                                  ⎥
# ⎣  5 - a      b - 2    -2⋅c - z + 5⎦

# %%
a,b,c,m,n,p,x,y=simplesolve(Q.flat())
# Out:
# $\displaystyle a =5$
# $\displaystyle b =2$
# $\displaystyle c =\frac{5}{2} - \frac{z}{2}$
# $\displaystyle m =5$
# $\displaystyle n =2$
# $\displaystyle p =2$
# $\displaystyle x =-3$
# $\displaystyle y =8$

# %%
m-n+p
# Out:
# 5

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)

# %%
from  Libaldomath  import *
from  lib_MyMatrix  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)

# %% [markdown]
# ![image.png](attachment:2fdacd25-de78-454f-a02e-7069c4705819.png)

# %%
A,B=simplesolve(A+2*B-R1,2*A-B-R2)
# Out:
# $\displaystyle A =\frac{R_{1}}{5} + \frac{2 R_{2}}{5}$
# $\displaystyle B =\frac{2 R_{1}}{5} - \frac{R_{2}}{5}$

# %%
R1=MyMat(5,2,0,-3,2,2)
R2=MyMat(5,-11,-5,4,2,2)
# Out:
# ⎡5  2 ⎤
# ⎢     ⎥
# ⎣0  -3⎦
# ⎡5   -11⎤
# ⎢       ⎥
# ⎣-5   4 ⎦

# %%
A=MyMat(R1+R2.mul(2))
B=MyMat(R1.mul(2)-R2())
# Out:
# ⎡15   -20⎤
# ⎢        ⎥
# ⎣-10   5 ⎦
# ⎡5  15 ⎤
# ⎢      ⎥
# ⎣5  -10⎦

# %%
A.Div(5)
B.Div(5)
# Out:
# ⎡3   -4⎤
# ⎢      ⎥
# ⎣-2  1 ⎦
# ⎡1  3 ⎤
# ⎢     ⎥
# ⎣1  -2⎦

# %%
abs(A.D)+abs(B.D)
# Out:
# 10

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)

# %%
from  Libaldomath  import *
from  lib_MyMatrix  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)

# %% [markdown]
# ![image.png](attachment:1764a0b9-39c1-4c0c-a44e-4b78202bd667.png)

# %%
A=MyMat(0,0,a,0,b,0,c,0,0,3,3)
B=MyMat(x,y,z,3,1)
C=MyMat(a+b,b+c,c+a,3,1)
# Out:
# ⎡0  0  a⎤
# ⎢       ⎥
# ⎢0  b  0⎥
# ⎢       ⎥
# ⎣c  0  0⎦
# ⎡x⎤
# ⎢ ⎥
# ⎢y⎥
# ⎢ ⎥
# ⎣z⎦
# ⎡a + b⎤
# ⎢     ⎥
# ⎢b + c⎥
# ⎢     ⎥
# ⎣a + c⎦

# %% [markdown]
# ![image.png](attachment:30272a01-049f-4d23-950c-e3681c162600.png)

# %%
x1,x2,x3=MatSolveSys(A,C)
# Out:
# ⎡a + c  b + c  a + b⎤
# ⎢─────, ─────, ─────⎥
# ⎣  c      b      a  ⎦

# %%
F=MyEq((x1-1)*(x2-1)*(x3-1),'F')
# Out:
# $\displaystyle F =\left(-1 + \frac{a + b}{a}\right) \left(-1 + \frac{b + c}{b}\right) \left(-1 + \frac{a + c}{c}\right)$

# %%
F.expand()
# Out:
# $\displaystyle F =1$

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)

# %%
from  Libaldomath  import *
from  lib_MyMatrix  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)

# %% [markdown]
# ![image.png](attachment:79922e28-8b7e-4034-806c-fa39492ccf99.png)

# %%
A=MyMat(1,2,0,0,1,5,1,0,1,3,3)
B=MyMat(1,5,2,3,1)
# Out:
# ⎡1  2  0⎤
# ⎢       ⎥
# ⎢0  1  5⎥
# ⎢       ⎥
# ⎣1  0  1⎦
# ⎡1⎤
# ⎢ ⎥
# ⎢5⎥
# ⎢ ⎥
# ⎣2⎦

# %%
x,y,z =MatSolveSys(A,B)
# Out:
# [1, 0, 1]

# %%
x+y+z
# Out:
# 2
