# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %%
from  libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:9ba7c4d3-3822-42f5-a16d-4b2630e4ef86.png)

# %% [markdown]
# ![image.png](attachment:8bd895b7-0cd2-4f0a-9639-485a2209d1b8.png)

# %%
P=MyEq((x**3-2*x*x-4*x+8)/(3*x*x+3*x-6),'P',var=x)
# Out:
# $\displaystyle P =\frac{x^{3} - 2 x^{2} - 4 x + 8}{3 x^{2} + 3 x - 6}$

# %%
# neerd solution testin -2
P(-2)
# Out:
# nan

# %%
P.factor()
# Out:
# $\displaystyle P =\frac{\left(x - 2\right)^{2}}{3 \left(x - 1\right)}$

# %%
P(-2)
# Out:
# -16/9

# %%
P=MyEq((x**3-2*x*x-4*x+8)/(3*x*x+3*x-6),'P',var=x)
# Out:
# $\displaystyle P =\frac{x^{3} - 2 x^{2} - 4 x + 8}{3 x^{2} + 3 x - 6}$

# %%
P.Limit(-2)
# Out:
#       ⎛ 3      2          ⎞
#       ⎜x  - 2⋅x  - 4⋅x + 8⎟
#  lim  ⎜───────────────────⎟
# x─→-2⁺⎜      2            ⎟
#       ⎝   3⋅x  + 3⋅x - 6  ⎠

# %%
k=P.Limit(-2)

# %%
k.doit()
# Out:
# -16/9

# %%
P.limit(-2)
# Out:
# -16/9

# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %%
import sys
sys.path.append('Libaldo')
from  libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:4edac88e-22a9-4acd-a8da-9989c1e9080d.png)

# %% [markdown]
# ![image.png](attachment:8bd895b7-0cd2-4f0a-9639-485a2209d1b8.png)

# %%
P=MyEq((x*x-(a-1)*x-a)/(x*x-(a-2)*x-2*a),'P',var=x)
# Out:
# $\displaystyle P =\frac{- a + x^{2} - x \left(a - 1\right)}{- 2 a + x^{2} - x \left(a - 2\right)}$

# %%
# test
P(a)
# Out:
#   2
#  a  - a⋅(a - 1) - a
# ────────────────────
#  2
# a  - a⋅(a - 2) - 2⋅a

# %%
P.factor()
# Out:
# $\displaystyle P =\frac{x + 1}{x + 2}$

# %%
P(a)
# Out:
# a + 1
# ─────
# a + 2

# %%
P=MyEq((x*x-(a-1)*x-a)/(x*x-(a-2)*x-2*a),'P',var=x)
# Out:
# $\displaystyle P =\frac{- a + x^{2} - x \left(a - 1\right)}{- 2 a + x^{2} - x \left(a - 2\right)}$

# %%
P.limit(a)
# Out:
# a + 1
# ─────
# a + 2

# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %%
import sys
sys.path.append('Libaldo')
from  libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:a36c0c1e-8f1b-4f49-819c-06f27f1a57ec.png)

# %% [markdown]
# ![image.png](attachment:8bd895b7-0cd2-4f0a-9639-485a2209d1b8.png)

# %%
p1=3-rpow(5+x)
p2=1-rpow(5-x)

# %%
P=MyEq(p1/p2,'P',var=x)
# Out:
# $\displaystyle P =\frac{3 - \sqrt{x + 5}}{1 - \sqrt{5 - x}}$

# %%
#test
P(4)
# Out:
# nan

# %%
p3=3+rpow(5+x)
p4=1+rpow(5-x)

# %%
P.Mul(p3*p4)
# Out:
# $\displaystyle P =\frac{\left(3 - \sqrt{x + 5}\right) \left(\sqrt{5 - x} + 1\right) \left(\sqrt{x + 5} + 3\right)}{1 - \sqrt{5 - x}}$

# %%
P.numerexpand()
# Out:
# $\displaystyle P =\frac{- x \sqrt{5 - x} - x + 4 \sqrt{5 - x} + 4}{1 - \sqrt{5 - x}}$

# %%
P.Div(p3*p4)
# Out:
# $\displaystyle P =\frac{- x \sqrt{5 - x} - x + 4 \sqrt{5 - x} + 4}{\left(1 - \sqrt{5 - x}\right) \left(\sqrt{5 - x} + 1\right) \left(\sqrt{x + 5} + 3\right)}$

# %%
P.denoexpand()
# Out:
# $\displaystyle P =\frac{- x \sqrt{5 - x} - x + 4 \sqrt{5 - x} + 4}{x \sqrt{x + 5} + 3 x - 4 \sqrt{x + 5} - 12}$

# %%
P.factor()
# Out:
# $\displaystyle P =- \frac{\sqrt{5 - x} + 1}{\sqrt{x + 5} + 3}$

# %%
P(4)
# Out:
# -1/3

# %%
# again 
P=MyEq(p1/p2,'P',var=x)
# Out:
# $\displaystyle P =\frac{3 - \sqrt{x + 5}}{1 - \sqrt{5 - x}}$

# %%
P.limit(4) # voilaaaaaaaaa
# Out:
# -1/3

# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %%
import sys
sys.path.append('Libaldo')
from  libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:792cf5e5-9bdd-48a2-b55e-330c4ef3573b.png)

# %% [markdown]
# ![image.png](attachment:8bd895b7-0cd2-4f0a-9639-485a2209d1b8.png)

# %%
p1=rpow(x+1,3) 
p2=rpow(1-x)

# %%
P=MyEq((p1-p2)/x,'P',var=x)
# Out:
# $\displaystyle P =\frac{- \sqrt{1 - x} + \left(x + 1\right)^{\frac{1}{3}}}{x}$

# %%
#test
P(0)
# Out:
# nan

# %%
P.expand()
# Out:
# $\displaystyle P =- \frac{\sqrt{1 - x}}{x} + \frac{\left(x + 1\right)^{\frac{1}{3}}}{x}$

# %% [markdown]
# ![image.png](attachment:d9680941-53e8-42a6-bbb1-9d4556f62bd5.png)

# %%
P1=MyEq(P.get_args(0),'P1',var=x)
P2=MyEq(P.get_args(1),'P2',var=x)
# Out:
# $\displaystyle P1 =\frac{\left(x + 1\right)^{\frac{1}{3}}}{x}$
# $\displaystyle P2 =- \frac{\sqrt{1 - x}}{x}$

# %%
P1.Add(-1/x)
P2.Add(1/x)
# Out:
# $\displaystyle P1 =\frac{\sqrt[3]{x + 1}}{x} - \frac{1}{x}$
# $\displaystyle P2 =- \frac{\sqrt{1 - x}}{x} + \frac{1}{x}$

# %% [markdown]
# ![image.png](attachment:711e8a04-62e0-4855-b6cb-bcf352242b1d.png)

# %%
P1.factor()
P2.factor()
# Out:
# $\displaystyle P1 =\frac{\sqrt[3]{x + 1} - 1}{x}$
# $\displaystyle P2 =- \frac{\sqrt{1 - x} - 1}{x}$

# %%
P1.Mul(rpow(x+1,3)**2+rpow(x+1,3)+1)
# Out:
# $\displaystyle P1 =\frac{\left(\sqrt[3]{x + 1} - 1\right) \left(1 + \left(x + 1\right)^{\frac{1}{3}} + \left(x + 1\right)^{2 \cdot \frac{1}{3}}\right)}{x}$

# %% [markdown]
# ![image.png](attachment:dce2330a-ac1c-4b77-9ede-cd7d5450233c.png)

# %%
P1.numerexpand()
# Out:
# $\displaystyle P1 =1$

# %%
P1.Div(rpow(x+1,3)**2+rpow(x+1,3)+1)
# Out:
# $\displaystyle P1 =\frac{1}{\left(x + 1\right)^{\frac{2}{3}} + \sqrt[3]{x + 1} + 1}$

# %%
P2.Mul(rpow(1-x)+1)
# Out:
# $\displaystyle P2 =\frac{\left(1 - \sqrt{1 - x}\right) \left(\sqrt{1 - x} + 1\right)}{x}$

# %% [markdown]
# ![image.png](attachment:5c2f84a3-d419-4025-84fa-343e6f9d296c.png)

# %%
P2.numerexpand()
# Out:
# $\displaystyle P2 =1$

# %%
P2.Div(rpow(1-x)+1)
# Out:
# $\displaystyle P2 =\frac{1}{\sqrt{1 - x} + 1}$

# %% [markdown]
# ![image.png](attachment:fec1ab9f-08e5-486f-841b-bd4806b89f2e.png)

# %%
# lim(P,x->0) =lim(P1,x->0)+lim(P2,x->0)
P1(0)+P2(0)
# Out:
# 5/6

# %%
P=MyEq((p1-p2)/x,'P',var=x)
# Out:
# $\displaystyle P =\frac{- \sqrt{1 - x} + \left(x + 1\right)^{\frac{1}{3}}}{x}$

# %%
simplify(P.limit(0))
# Out:
# 5/6

# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %%
import sys
sys.path.append('Libaldo')
from  libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:10916fec-5895-4ad9-b910-8f92697b6cd7.png)

# %% [markdown]
# ![image.png](attachment:8bd895b7-0cd2-4f0a-9639-485a2209d1b8.png)

# %% [markdown]
# ![image.png](attachment:e15038d7-cf04-4f87-9673-ce1863d1c101.png)

# %%
p1=rpow(x+1,3) 
p2=rpow(x+1,4)

# %%
np=x*p1+p2-1
dp=x*x*p1+p2-1

# %%
P=MyEq(np/dp,'P',var=x)
# Out:
# $\displaystyle P =\left(x \left(x + 1\right)^{\frac{1}{3}} - 1 + \left(x + 1\right)^{\frac{1}{4}}\right) \left(x^{2} \left(x + 1\right)^{\frac{1}{3}} - 1 + \left(x + 1\right)^{\frac{1}{4}}\right)^{-1}$

# %%
 P.limit(0)
# Out:
#            -1
# ⎛    1⎞ ⎛1⎞
# ⎜1 + ─⎟⋅⎜─⎟
# ⎝    4⎠ ⎝4⎠

# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %%
import sys
sys.path.append('Libaldo')
from  libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:5d932108-0137-4337-969c-15860c1d0b2a.png)

# %% [markdown]
# ![image.png](attachment:8bd895b7-0cd2-4f0a-9639-485a2209d1b8.png)

# %% [markdown]
# ![image.png](attachment:f07b802e-f8f5-4760-ba0e-53a9f7b95c4d.png)

# %% [markdown]
# ![image.png](attachment:d4843bda-ad27-4772-b646-f2185d21a389.png)

# %%
p1=rpow(x-1,3) 
p2=rpow(x*x-3)  
p3=rpow(3*x+10)

# %%
np=p1-x+p2
dp=p3-4

# %%
P=MyEq(np/dp,'P',var=x)
# Out:
# $\displaystyle P =\frac{- x + \sqrt{x^{2} - 3} + \left(x - 1\right)^{\frac{1}{3}}}{\sqrt{3 x + 10} - 4}$

# %%
 simplify(P.limit(2))
# Out:
# 32/9
