# %%
import sys
sys.path.append('Libaldo')
from  libaldomath  import *
from lib_simpleintegral import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:e31313f2-d8f2-4240-9eb6-dbaf2488827b.png)

# %% [markdown]
# ![image.png](attachment:55c55f47-8f7e-42a5-aefc-433eee86f6c7.png)

# %%
y=MyIntg( 1/(5-4*sin(x)+3*cos(x)),'y')
# Out:
# $\displaystyle y=\int \frac{1}{- 4 \sin{\left(x \right)} + 3 \cos{\left(x \right)} + 5}\, dx$

# %% [markdown]
# ![image.png](attachment:c02896df-2f8f-4a30-ba82-7f2788986e24.png)

# %%
y.set(sin(x),2*z/(1+z*z))
# Out:
# $\displaystyle y=\int \frac{1}{- \frac{8 z}{z^{2} + 1} + 3 \cos{\left(x \right)} + 5}\, dx$

# %%
y.set(cos(x),(1-z*z)/(1+z*z))
# Out:
# $\displaystyle y=\int \frac{1}{- \frac{8 z}{z^{2} + 1} + \frac{3 \cdot \left(1 - z^{2}\right)}{z^{2} + 1} + 5}\, dx$

# %%
y.Mul(2/(1+z*z))
# Out:
# $\displaystyle y=\int \frac{2}{\left(z^{2} + 1\right) \left(- \frac{8 z}{z^{2} + 1} + \frac{3 - 3 z^{2}}{z^{2} + 1} + 5\right)}\, dx$

# %%
y.var=z

# %%
y.s()
# Out:
# $\displaystyle y=\int \frac{2}{\left(z^{2} + 1\right) \left(- \frac{8 z}{z^{2} + 1} + \frac{3 - 3 z^{2}}{z^{2} + 1} + 5\right)}\, dz$

# %%
y.simplify()
# Out:
# $\displaystyle y=\int \frac{1}{z^{2} - 4 z + 4}\, dz$

# %%
y.factor()
# Out:
# $\displaystyle y=\int \frac{1}{\left(z - 2\right)^{2}}\, dz$

# %%
y.doit()
# Out:
#  -1
# ─────
# z - 2

# %% [markdown]
# ![image.png](attachment:e31313f2-d8f2-4240-9eb6-dbaf2488827b.png)

# %%
import sys
sys.path.append('Libaldo')
from  libaldomath  import *
from lib_simpleintegral import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:508225bf-97d8-4275-b5d6-8fc18608bc8c.png)

# %%
P=MyEq(4-2*x-x*x,'P')
# Out:
# $\displaystyle P =- x^{2} - 2 x + 4$

# %%
y=MyIntg((x+2)/sqrt(P()),'y')
# Out:
# $\displaystyle y=\int \frac{x + 2}{\sqrt{- x^{2} - 2 x + 4}}\, dx$

# %%
P.ksym=transform2(P(),'A-(x+1)**2')

# %%
y=MyIntg((x+2)/sqrt(P()),'y')
# Out:
# $\displaystyle y=\int \frac{x + 2}{\sqrt{5 - \left(x + 1\right)^{2}}}\, dx$

# %%
y.set(x+2,z+1)
# Out:
# $\displaystyle y=\int \frac{z + 1}{\sqrt{5 - z^{2}}}\, dx$

# %%
y.var=z

# %%
y.s()
# Out:
# $\displaystyle y=\int \frac{z + 1}{\sqrt{5 - z^{2}}}\, dz$

# %%
y.doit('update')
# Out:
# $\displaystyle y=- \sqrt{5 - z^{2}} + \operatorname{asin}{\left(\frac{\sqrt{5} z}{5} \right)}$

# %%
y.set(z=x+1)
# Out:
# $\displaystyle y=- \sqrt{5 - \left(x + 1\right)^{2}} + \operatorname{asin}{\left(\frac{\sqrt{5} \left(x + 1\right)}{5} \right)}$

# %%
y.expand()
# Out:
# $\displaystyle y=- \sqrt{- x^{2} - 2 x + 4} + \operatorname{asin}{\left(\frac{\sqrt{5} x}{5} + \frac{\sqrt{5}}{5} \right)}$

# %%
import sys
sys.path.append('Libaldo')
from  libaldomath  import *
from lib_simpleintegral import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:e31313f2-d8f2-4240-9eb6-dbaf2488827b.png)

# %% [markdown]
# ![image.png](attachment:0db31c31-8369-4a22-a383-90e3799e9960.png)

# %%
P=MyEq((1-x)/(1+x),'P')
# Out:
# $\displaystyle P =\frac{1 - x}{x + 1}$

# %%
y=MyIntg(rpow(P(),3),'y')
# Out:
# $\displaystyle y=\int \left(\frac{1 - x}{x + 1}\right)^{\frac{1}{3}}\, dx$

# %%
Q=MQ(z**3,P)
# Out:
# $\displaystyle z^{3} = \frac{1 - x}{x + 1}$

# %%
x=Q.solve(x)
# Out:
# $\displaystyle x =\frac{1 - z^{3}}{z^{3} + 1}$

# %%
y.update(x)
# Out:
# $\displaystyle y=\int \left(\frac{- \frac{1 - z^{3}}{z^{3} + 1} + 1}{\frac{1 - z^{3}}{z^{3} + 1} + 1}\right)^{\frac{1}{3}}\, dx$

# %%
y.simplify()
# Out:
# $\displaystyle y=\int \sqrt[3]{z^{3}}\, dx$

# %%
y.rsimplify()
# Out:
# $\displaystyle y=\int z\, dx$

# %%
y.var=z

# %%
y.doit('up')
# Out:
# $\displaystyle y=\frac{z^{2}}{2}$

# %%
Q=MQ(z**3,P)
# Out:
# $\displaystyle z^{3} = \frac{1 - x}{x + 1}$

# %%
z1=Q.solve(z)
# Out:
# $\displaystyle z =\sqrt[3]{- \frac{x}{x + 1} + \frac{1}{x + 1}}$

# %%
y.set(z,z1())
# Out:
# $\displaystyle y=\frac{\left(- \frac{x}{x + 1} + \frac{1}{x + 1}\right)^{\frac{2}{3}}}{2}$
