# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %%
from  libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:5a757dee-2f01-4dea-83ac-322c59df7e77.png)

# %%
limit(sin(x),x,0)
# Out:
# 0

# %%
limit(tan(x)/x,x,0)
# Out:
# 1

# %%
limit(sin(x),x,a)
# Out:
# sin(a)

# %%
limit(cos(x),x,0)
# Out:
# 1

# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %%
from  libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:b8ba6b9a-79b5-4959-80e6-a57ae1ef6e02.png)

# %%
P=MyEq((1-cos(x))/x,'P',var=x)
# Out:
# $\displaystyle P =\frac{1 - \cos{\left(x \right)}}{x}$

# %%
P=MyEq((1-cos(x))/x,'P',var=x)
# Out:
# $\displaystyle P =\frac{1 - \cos{\left(x \right)}}{x}$

# %%
P.Mul(1+cos(x))
# Out:
# $\displaystyle P =\frac{\left(1 - \cos{\left(x \right)}\right) \left(\cos{\left(x \right)} + 1\right)}{x}$

# %%
P.numerexpand()
# Out:
# $\displaystyle P =\frac{1 - \cos^{2}{\left(x \right)}}{x}$

# %%
P.tsimplify()
# Out:
# $\displaystyle P =\frac{\sin^{2}{\left(x \right)}}{x}$

# %%
P.Div(1+cos(x))
# Out:
# $\displaystyle P =\frac{\sin^{2}{\left(x \right)}}{x \left(\cos{\left(x \right)} + 1\right)}$

# %%
p1=sin(x)/x;p1
# Out:
# sin(x)
# ──────
#   x

# %%
p2=sin(x)/(cos(x)+1);p2
# Out:
#   sin(x)
# ──────────
# cos(x) + 1

# %%
# P =p1 *p2...

# %%
limit(p1,x,0)*limit(p2,x,0)
# Out:
# 0

# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %%
P=MyEq((1-cos(x))/x,'P',var=x)
# Out:
# $\displaystyle P =\frac{1 - \cos{\left(x \right)}}{x}$

# %%
# post andemic methode.....
P.limit(0)
# Out:
# 0

# %%
P=MyEq((1-cos(x))/x,'P',var=x)
P.limit(0)
# Out:
# $\displaystyle P =\frac{1 - \cos{\left(x \right)}}{x}$
# 0

# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %%
from  libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:72da0969-94fb-4b39-b8bc-2bfcfc9a987e.png)

# %%
P1=MyEq((1-cos(m*x))/x**2,'P1',var=x)
P2=MyEq((1-cos(n*x))/x**2,'P2',var=x)
# Out:
# $\displaystyle P1 =\frac{1 - \cos{\left(m x \right)}}{x^{2}}$
# $\displaystyle P2 =\frac{1 - \cos{\left(n x \right)}}{x^{2}}$

# %%
#test
factor(P1-P2)
# Out:
# -(cos(m⋅x) - cos(n⋅x))
# ───────────────────────
#             2
#            x

# %%
P2.limit(0)-P1.limit(0)
# Out:
#    2    2
#   m    n
# - ── + ──
#   2    2

# %%
# or
P=MyEq(P1-P2,'P',var=x)
# Out:
# $\displaystyle P =\frac{1 - \cos{\left(m x \right)}}{x^{2}} - \frac{1 - \cos{\left(n x \right)}}{x^{2}}$

# %%
P.limit(0)
# Out:
#  2    2
# m    n
# ── - ──
# 2    2

# %%
P=MyEq(P1-P2,'P',var=x)
P.limit(0)
# Out:
# $\displaystyle P =\frac{1 - \cos{\left(m x \right)}}{x^{2}} - \frac{1 - \cos{\left(n x \right)}}{x^{2}}$
#  2    2
# m    n
# ── - ──
# 2    2

# %% [markdown]
# ![image.png](attachment:fb4a0593-7b41-4cdb-a0d9-25828b4f2e1f.png)

# %%
from  libaldomath  import *
# this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:a10332df-c45d-479d-8899-8da60dd326de.png)

# %%
P1=MyEq(1-cos(sin(4*x)),'P1',var=x)
P2=MyEq(sin(sin(3*x))**2,'P2',var=x)
# Out:
# $\displaystyle P1 =1 - \cos{\left(\sin{\left(4 x \right)} \right)}$
# $\displaystyle P2 =\sin^{2}{\left(\sin{\left(3 x \right)} \right)}$

# %%
P1.Div(P2)
# Out:
# $\displaystyle P1 =\frac{1 - \cos{\left(\sin{\left(4 x \right)} \right)}}{\sin^{2}{\left(\sin{\left(3 x \right)} \right)}}$

# %%
P1.limit(0)
# Out:
# 8/9
