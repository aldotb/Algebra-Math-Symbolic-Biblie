# %% [markdown]
# ![image.png](attachment:b39ef867-cc4d-4087-a3bf-cd4aaeed85f9.png)

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)

# %%
from  Libaldomath import *  # this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)

# %% [markdown]
# ![image.png](attachment:1c700511-59f3-4ee6-afa4-0d592808a953.png)

# %%
# declare your MyEq but define independien var
P=MyEq(3*x**2+2*x+4,'P',var=x)
# Out:
# $\displaystyle P =3 x^{2} + 2 x + 4$

# %%
helpgui

# %%
P(x)
# Out:
#    2
# 3⋅x  + 2⋅x + 4

# %%
P(1)
# Out:
# 9

# %%
P(x+1)+P(x-1)-2*P(x)
# Out:
#      2            2            2
# - 6⋅x  + 3⋅(x - 1)  + 3⋅(x + 1)

# %%
Q=MyEq(P(x+1)+P(x-1)-2*P(x),'Q')
# Out:
# $\displaystyle Q =- 6 x^{2} + 3 \left(x - 1\right)^{2} + 3 \left(x + 1\right)^{2}$

# %%
Q.expand()
# Out:
# $\displaystyle Q =6$

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)

# %%
from  Libaldomath import *  # this cell will be initializing your variables

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)

# %% [markdown]
# ![image.png](attachment:161238ee-1ed2-4057-b9a8-d4326fd78148.png)

# %%
f=MyEq(x-2*a,'f',var=x)
g=MyEq(2*x+a,'g',var=x)
# Out:
# $\displaystyle f =- 2 a + x$
# $\displaystyle g =a + 2 x$

# %%
# testing
f(g(x))
# Out:
# -a + 2⋅x

# %%
f(a)
# Out:
# -a

# %%
f(g(a))
# Out:
# a

# %%
Q=MQ(f(g(x))-g(f(x)),f(g(a))+19)
# Out:
# $\displaystyle 2 a = a + 19$

# %%
#  for deduccion you can aje thisi.. but still is Mq expresion not a answer
Q.Add(-a)
# Out:
# $\displaystyle a = 19$

# %%
# or..
Q=MQ(f(g(x))-g(f(x)),f(g(a))+19) #  because was change in bellow step..
# Out:
# $\displaystyle 2 a = a + 19$

# %%
a=Q.solve(a), # return a like MyEq expre..
# Out:
# $\displaystyle a=19$

# %%
from  Libaldomath import *  # this cell will be initializing your variables

# %% [markdown]
#  <img src="https://github.com/aldotb/Solve-Academic-Algebra-Math-Problems-whit-Python-and-Sympy/blob/main/images/linep.png?raw=1" alt="ml" style="width : 100%;"/>

# %% [markdown]
#  <img src="https://github.com/aldotb/Solve-Academic-Algebra-Math-Problems-whit-Python-and-Sympy/blob/main/images/p36.png?raw=1" alt="ml" style="width : 100%;"/>

# %% [markdown]
#  <img src="https://github.com/aldotb/Solve-Academic-Algebra-Math-Problems-whit-Python-and-Sympy/blob/main/images/lines.png?raw=1" alt="ml" style="width : 100%;"/>

# %%
a0,a1,a2,a3,a4,a5,a6,a7=symbols('a0 a1 a2 a3 a4 a5 a6 a7')

# %%
vec=[a0,a1,a2,a3,a4,a5,a6,a7]
P=[vec[i]*x**i for i in range(8)]

# %%
F=MyEq(sum(P),'F',var=x)
# Out:
# $\displaystyle F =a_{0} + a_{1} x + a_{2} x^{2} + a_{3} x^{3} + a_{4} x^{4} + a_{5} x^{5} + a_{6} x^{6} + a_{7} x^{7}$

# %%
F2=MyEq(F()*F()*F()-F()*F(),'F2',var=x)
# Out:
# $\displaystyle F2 =\left(a_{0} + a_{1} x + a_{2} x^{2} + a_{3} x^{3} + a_{4} x^{4} + a_{5} x^{5} + a_{6} x^{6} + a_{7} x^{7}\right)^{3} - \left(a_{0} + a_{1} x + a_{2} x^{2} + a_{3} x^{3} + a_{4} x^{4} + a_{5} x^{5} + a_{6} x^{6} + a_{7} x^{7}\right)^{2}$

# %%
F2.expand()
# Out:
# $\displaystyle F2 =a_{0}^{3} + 3 a_{0}^{2} a_{1} x + 3 a_{0}^{2} a_{2} x^{2} + 3 a_{0}^{2} a_{3} x^{3} + 3 a_{0}^{2} a_{4} x^{4} + 3 a_{0}^{2} a_{5} x^{5} + 3 a_{0}^{2} a_{6} x^{6} + 3 a_{0}^{2} a_{7} x^{7} - a_{0}^{2} + 3 a_{0} a_{1}^{2} x^{2} + 6 a_{0} a_{1} a_{2} x^{3} + 6 a_{0} a_{1} a_{3} x^{4} + 6 a_{0} a_{1} a_{4} x^{5} + 6 a_{0} a_{1} a_{5} x^{6} + 6 a_{0} a_{1} a_{6} x^{7} + 6 a_{0} a_{1} a_{7} x^{8} - 2 a_{0} a_{1} x + 3 a_{0} a_{2}^{2} x^{4} + 6 a_{0} a_{2} a_{3} x^{5} + 6 a_{0} a_{2} a_{4} x^{6} + 6 a_{0} a_{2} a_{5} x^{7} + 6 a_{0} a_{2} a_{6} x^{8} + 6 a_{0} a_{2} a_{7} x^{9} - 2 a_{0} a_{2} x^{2} + 3 a_{0} a_{3}^{2} x^{6} + 6 a_{0} a_{3} a_{4} x^{7} + 6 a_{0} a_{3} a_{5} x^{8} + 6 a_{0} a_{3} a_{6} x^{9} + 6 a_{0} a_{3} a_{7} x^{10} - 2 a_{0} a_{3} x^{3} + 3 a_{0} a_{4}^{2} x^{8} + 6 a_{0} a_{4} a_{5} x^{9} + 6 a_{0} a_{4} a_{6} x^{10} + 6 a_{0} a_{4} a_{7} x^{11} - 2 a_{0} a_{4} x^{4} + 3 a_{0} a_{5}^{2} x^{10} + 6 a_{0} a_{5} a_{6} x^{11} + 6 a_{0} a_{5} a_{7} x^{12}
# ...

# %%
F.simplify()
# Out:
# $\displaystyle F =a_{0} + a_{1} x + a_{2} x^{2} + a_{3} x^{3} + a_{4} x^{4} + a_{5} x^{5} + a_{6} x^{6} + a_{7} x^{7}$

# %%
F.set(a0=0)
# Out:
# $\displaystyle F =a_{1} x + a_{2} x^{2} + a_{3} x^{3} + a_{4} x^{4} + a_{5} x^{5} + a_{6} x^{6} + a_{7} x^{7}$

# %%
F.set(a1=2,a2=2,a3=1,a4=0,a5=1,a6=1,a7=1) # comparinfg coefficients
# Out:
# $\displaystyle F =x^{7} + x^{6} + x^{5} + x^{3} + 2 x^{2} + 2 x$

# %%
F(cos(pi)**3)
# Out:
# -2

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)

# %%
from  Libaldomath import *  # this cell will be initializing your variables

# %% [markdown]
#  <img src="https://github.com/aldotb/Solve-Academic-Algebra-Math-Problems-whit-Python-and-Sympy/blob/main/images/linep.png?raw=1" alt="ml" style="width : 100%;"/>

# %% [markdown]
#  <img src="https://github.com/aldotb/Solve-Academic-Algebra-Math-Problems-whit-Python-and-Sympy/blob/main/images/p38.png?raw=1" alt="ml" style="width : 100%;"/>

# %% [markdown]
#  <img src="https://github.com/aldotb/Solve-Academic-Algebra-Math-Problems-whit-Python-and-Sympy/blob/main/images/lines.png?raw=1" alt="ml" style="width : 100%;"/>

# %% [markdown]
# ![image.png](attachment:18b7c941-dbc0-46a9-905d-b6a203924bad.png)

# %%
f=MyEq(x,'f',var=x)
# Out:
# $\displaystyle f =x$

# %%
f(-3)+f(4)
# Out:
# 1

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)

# %%
from  Libaldomath import *  # this cell will be initializing your variables

# %% [markdown]
#  <img src="https://github.com/aldotb/Solve-Academic-Algebra-Math-Problems-whit-Python-and-Sympy/blob/main/images/linep.png?raw=1" alt="ml" style="width : 100%;"/>

# %% [markdown]
#  <img src="https://github.com/aldotb/Solve-Academic-Algebra-Math-Problems-whit-Python-and-Sympy/blob/main/images/p39.png?raw=1" alt="ml" style="width : 100%;"/>

# %% [markdown]
#  <img src="https://github.com/aldotb/Solve-Academic-Algebra-Math-Problems-whit-Python-and-Sympy/blob/main/images/linep.png?raw=1" alt="ml" style="width : 100%;"/>

# %%
f=MyEq(exp(x)+ppow(pi,x),'f',var=x)
# Out:
# $\displaystyle f =\pi^{x} + e^{x}$

# %%
f.Pow(3)
# Out:
# $\displaystyle f =\left(\pi^{x} + e^{x}\right)^{3}$

# %%
f.expand()
# Out:
# $\displaystyle f =\pi^{3 x} + 3 \pi^{2 x} e^{x} + 3 \pi^{x} e^{2 x} + e^{3 x}$

# %%
F=MyEq((f(1)/(f(4)-f(7))),'F',var=x)
# Out:
# $\displaystyle F =\frac{e^{3} + \pi^{3} + 3 \pi e^{2} + 3 e \pi^{2}}{- 3 \pi^{14} e^{7} - \pi^{21} - 3 \pi^{7} e^{14} - e^{21} + e^{12} + 3 \pi^{4} e^{8} + \pi^{12} + 3 \pi^{8} e^{4}}$

# %%
F.Rpow(3)
# Out:
# $\displaystyle F =\sqrt[3]{e^{3} + \pi^{3} + 3 \pi e^{2} + 3 e \pi^{2}} \sqrt[3]{\frac{1}{- 3 \pi^{14} e^{7} - \pi^{21} - 3 \pi^{7} e^{14} - e^{21} + e^{12} + 3 \pi^{4} e^{8} + \pi^{12} + 3 \pi^{8} e^{4}}}$

# %%
Q1=MQ(f(3),1)
# Out:
# $\displaystyle e^{9} + \pi^{9} + 3 \pi^{3} e^{6} + 3 \pi^{6} e^{3} = 1$

# %%
Q1.Add(-pi**3)
# Out:
# $\displaystyle - \pi^{3} + e^{9} + \pi^{9} + 3 \pi^{3} e^{6} + 3 \pi^{6} e^{3} = 1 - \pi^{3}$

# %%
g=MyEq((f(4)-f(7)),'g',var=x)
# Out:
# $\displaystyle g =- 3 \pi^{14} e^{7} - \pi^{21} - 3 \pi^{7} e^{14} - e^{21} + e^{12} + 3 \pi^{4} e^{8} + \pi^{12} + 3 \pi^{8} e^{4}$

# %%
g.subsubs(exp(7),exp(4)*(1-pi**3))
# Out:
# $\displaystyle g =- \pi^{21} - 3 \pi^{7} e^{14} - e^{21} + e^{12} + 3 \pi^{4} e^{8} + \pi^{12} + 3 \pi^{8} e^{4} - 3 \pi^{14} \cdot \left(1 - \pi^{3}\right) e^{4}$

# %%
g.subsubs(exp(4),exp(1)*(1-pi**3))
# Out:
# $\displaystyle g =- 3 e \pi^{14} \left(1 - \pi^{3}\right)^{2} - \pi^{21} - 3 \pi^{7} e^{14} - e^{21} + 3 e \pi^{8} \cdot \left(1 - \pi^{3}\right) + e^{12} + 3 \pi^{4} e^{8} + \pi^{12}$

# %%
g.subsubs(pi**7,pi**4*(1-exp(3)))
# Out:
# $\displaystyle g =- 3 e \pi^{14} \left(1 - \pi^{3}\right)^{2} - \pi^{21} - e^{21} + 3 e \pi^{8} \cdot \left(1 - \pi^{3}\right) + e^{12} + 3 \pi^{4} e^{8} + \pi^{12} - 3 \pi^{4} \cdot \left(1 - e^{3}\right) e^{14}$

# %%
g.subsubs(pi**4,pi*(1-exp(3)))
# Out:
# $\displaystyle g =- 3 e \pi^{14} \left(1 - \pi^{3}\right)^{2} - \pi^{21} - 3 \pi \left(1 - e^{3}\right)^{2} e^{14} - e^{21} + 3 e \pi^{8} \cdot \left(1 - \pi^{3}\right) + 3 \pi \left(1 - e^{3}\right) e^{8} + e^{12} + \pi^{12}$

# %%
g.subsubs((1-pi**3),exp(3))
# Out:
# $\displaystyle g =- 3 \pi^{14} e^{7} - \pi^{21} - 3 \pi \left(1 - e^{3}\right)^{2} e^{14} - e^{21} + 3 \pi \left(1 - e^{3}\right) e^{8} + e^{12} + \pi^{12} + 3 \pi^{8} e^{4}$

# %%
g.subsubs((1-exp(3)),pi**3)
# Out:
# $\displaystyle g =- 3 \pi^{14} e^{7} - \pi^{21} - 3 \pi^{7} e^{14} - e^{21} + e^{12} + 3 \pi^{4} e^{8} + \pi^{12} + 3 \pi^{8} e^{4}$

# %%
F=MyEq(ppow(cfrac(f(1),g()),1,3),'F',var=x)
# Out:
# $\displaystyle F =\sqrt[3]{- \pi^{16} e^{8} - \pi^{21} - 3 \pi^{7} e^{14} - e^{21} + e^{3} + \pi^{3} + 3 \pi e^{2} + e^{12} + 3 \pi^{4} e^{8} + \pi^{12} + 3 \pi^{8} e^{4}}$

# %%
from  Libaldomath import *  # this cell will be initializing your variables

# %% [markdown]
#  <img src="https://github.com/aldotb/Solve-Academic-Algebra-Math-Problems-whit-Python-and-Sympy/blob/main/images/linep.png?raw=1" alt="ml" style="width : 100%;"/>

# %% [markdown]
#  <img src="https://github.com/aldotb/Solve-Academic-Algebra-Math-Problems-whit-Python-and-Sympy/blob/main/images/p47.png?raw=1" alt="ml" style="width : 100%;"/>

# %% [markdown]
#  <img src="https://github.com/aldotb/Solve-Academic-Algebra-Math-Problems-whit-Python-and-Sympy/blob/main/images/lines.png?raw=1" alt="ml" style="width : 100%;"/>

# %%
f=MyEq(x*x+a,'f',var=x)
# Out:
# $\displaystyle f =a + x^{2}$

# %%
f(f(f(x)))
# Out:
#                    2
#     ⎛            2⎞
#     ⎜    ⎛     2⎞ ⎟
# a + ⎝a + ⎝a + x ⎠ ⎠

# %%
Q=MQ(f(f(f(x))),x**8+4*x**6+8*x**4+8*x*x+5)
# Out:
# $\displaystyle a + \left(a + \left(a + x^{2}\right)^{2}\right)^{2} = x^{8} + 4 x^{6} + 8 x^{4} + 8 x^{2} + 5$

# %%
Q.expand()
# Out:
# $\displaystyle a^{4} + 4 a^{3} x^{2} + 2 a^{3} + 6 a^{2} x^{4} + 4 a^{2} x^{2} + a^{2} + 4 a x^{6} + 2 a x^{4} + a + x^{8} = x^{8} + 4 x^{6} + 8 x^{4} + 8 x^{2} + 5$

# %% [markdown]
#  <img src="https://github.com/aldotb/Solve-Academic-Algebra-Math-Problems-whit-Python-and-Sympy/blob/main/images/p47a.png?raw=1" alt="ml" style="width : 80%;"/>

# %%
Q.sortdegree(x)
# Out:
# $\displaystyle a^{4} + 2 a^{3} + a^{2} + 4 a x^{3} + a + x^{4} + x^{2} \cdot \left(6 a^{2} + 2 a\right) + x \left(4 a^{3} + 4 a^{2}\right) = a^{4} + 2 a^{3} + a^{2} + 4 a x^{3} + a + x^{4} + x^{2} \cdot \left(6 a^{2} + 2 a\right) + x \left(4 a^{3} + 4 a^{2}\right)$

# %%
# try a=1
F=MyEq(x*x+1,'F',var=x)
# Out:
# $\displaystyle F =x^{2} + 1$

# %%
# match
expand(F(F(F(x))))
# Out:
#  8      6      4      2
# x  + 4⋅x  + 8⋅x  + 8⋅x  + 5

# %%
F(35)
# Out:
# 1226

# %%
helplib('primefactorexp')

# %%
primefactor(F(35))
# Out:
# 613⋅2
