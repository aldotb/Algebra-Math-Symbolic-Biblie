# %% [markdown]
# Area

# %%
from  libaldomath  import *
from lib_MyIntegral import *

# %% [markdown]
#  <img src="imgdata/linep.png" alt="ml" style="width : 100%;"/>

# %% [markdown]
# ![image.png](attachment:e4cd6ac6-3060-4018-badf-5d435419110a.png)

# %%
A=MyIntg(1+(6*x-x*x)/9,'A',x1=0,x2=5,var=x)
# Out:
# $\displaystyle A=\int\limits_{0}^{5} \left(- \frac{x^{2}}{9} + \frac{2 x}{3} + 1\right)\, dx$

# %%
A.doit()
# Out:
# 235
# ───
#  27

# %% [markdown]
#  <img src="imgdata/linep.png" alt="ml" style="width : 100%;"/>

# %% [markdown]
# ![image.png](attachment:c348c8e5-1167-4712-a647-faf7965d029b.png)

# %%
A=MyIntg(ln(x),'A',x1=1,x2=exp(1),var=x)
# Out:
# $\displaystyle A=\int\limits_{1}^{e} \log{\left(x \right)}\, dx$

# %%
A.doit()
# Out:
# 1

# %% [markdown]
#  <img src="imgdata/linep.png" alt="ml" style="width : 100%;"/>

# %% [markdown]
# ![image.png](attachment:40c5a40f-9981-4291-b9f8-c046fafc178d.png)

# %%
from  libaldomath  import *
from lib_MyIntegral import *

# %%
A1=MyEq(2*x/5+cfrac(2,5),'A1',var=x)
A2=MyEq(((x-2)**2)/9-1,'A2',var=x)
# Out:
# $\displaystyle A1 =\frac{2 x}{5} + \frac{2}{5}$
# $\displaystyle A2 =\frac{\left(x - 2\right)^{2}}{9} - 1$

# %%
A=MyIntg(A1-A2,'A',var=x,x1=-1,x2=4)
# Out:
# $\displaystyle A=\int\limits_{-1}^{4} \left(\frac{2 x}{5} - \frac{\left(x - 2\right)^{2}}{9} + 1 + \frac{2}{5}\right)\, dx$

# %%
A.doit()
# Out:
# 235
# ───
#  27

# %% [markdown]
#  <img src="imgdata/linep.png" alt="ml" style="width : 100%;"/>

# %% [markdown]
# ![image.png](attachment:4adbde10-d5f2-4f0f-8d1b-9d9cbc7631c9.png)

# %%
from  libaldomath  import *
from lib_MyIntegral import *

# %%
y=MyEq(-x/2+1,'y',var=x)
# Out:
# $\displaystyle y =1 - \frac{x}{2}$

# %%
A1=MyIntg(-x/2+1,'A1',var=x,x1=-2,x2=2)
# Out:
# $\displaystyle A1=\int\limits_{-2}^{2} \left(1 - \frac{x}{2}\right)\, dx$

# %%
A2=MyIntg(-x/2+1,'A2',var=x,x1=2,x2=4)
# Out:
# $\displaystyle A2=\int\limits_{2}^{4} \left(1 - \frac{x}{2}\right)\, dx$

# %%
A=A1.doit()-A2.doit()
A
# Out:
# 5

# %%
from  libaldomath  import *
from lib_MyIntegral import *

# %% [markdown]
# ![image.png](attachment:bae646db-447b-4401-ba05-8aecbd026b20.png)

# %%
A=MyIntg(-x/2+1,'A',var=x,x1=-2,x2=4)
# Out:
# $\displaystyle A=\int\limits_{-2}^{4} \left(1 - \frac{x}{2}\right)\, dx$

# %%
A.Area()
# Out:
# $\displaystyle A=- \int\limits_{2}^{4} \left(1 - \frac{x}{2}\right)\, dx + \int\limits_{-2}^{2} \left(1 - \frac{x}{2}\right)\, dx$

# %%
A.doit()
# Out:
# 5

# %% [markdown]
#  <img src="imgdata/linep.png" alt="ml" style="width : 100%;"/>

# %% [markdown]
# ![image.png](attachment:95afec67-58c6-4a62-8d73-4fb9da984587.png)

# %%
from  libaldomath  import *
from lib_MyIntegral import *

# %%
y1=MyEq(x/3+1,'y1',var=x)
y2=MyEq(5-x,'y2',var=x) 
y3=MyEq(x**2/2-2*x+1,'y3',var=x)
# Out:
# $\displaystyle y1 =\frac{x}{3} + 1$
# $\displaystyle y2 =5 - x$
# $\displaystyle y3 =\frac{x^{2}}{2} - 2 x + 1$

# %%
A1=MyIntg(y1-y3,'A1',var=x,x1=0,x2=3)
A2=MyIntg(y2-y3,'A1',var=x,x1=3,x2=4)
# Out:
# $\displaystyle A1=\int\limits_{0}^{3} \left(- \frac{x^{2}}{2} + \frac{7 x}{3}\right)\, dx$
# $\displaystyle A1=\int\limits_{3}^{4} \left(- \frac{x^{2}}{2} + x + 4\right)\, dx$

# %%
A1.doit()+A2.doit()
# Out:
# 22/3

# %% [markdown]
#  <img src="imgdata/linep.png" alt="ml" style="width : 100%;"/>

# %% [markdown]
# ![image.png](attachment:7e904cf0-e852-4486-80e4-886f1f4fd2c2.png)

# %%
from  libaldomath  import *
from lib_MyIntegral import *

# %%
y1=MyEq(x**2,'y1',var=x)
y2=MyEq(2-x,'y2',var=x)
# Out:
# $\displaystyle y1 =x^{2}$
# $\displaystyle y2 =2 - x$

# %%
A=MyIntg(y2-y1,'A',var=x,x1=-2,x2=1)
# Out:
# $\displaystyle A=\int\limits_{-2}^{1} \left(- x^{2} - x + 2\right)\, dx$

# %%
A.doit()
# Out:
# 9/2
