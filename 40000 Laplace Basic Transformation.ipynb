# %% [markdown]
# ![imagen.png](attachment:6fe077e5-9821-4674-a8d4-8529d237cdba.png)

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)

# %%
from  Libaldomath  import *
from lib_MyDiff import *
from lib_MyIntegral import *
# this cell will be initializing your variables

# %% [markdown]
# ![imagen.png](attachment:47d76ccb-fe94-43b8-b9df-c841fa007717.png)

# %%
F=MyEq(t,'F',var=t)
# Out:
# $\displaystyle F =t$

# %%
Lt=func2laplace(F)
# Out:
# $\displaystyle \mathcal{L} = \frac{1}{s^{2}}$

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)

# %%
from  Libaldomath  import *
from lib_MyDiff import *
from lib_MyIntegral import *

# %%
# Classic methos analyzer

# %% [markdown]
# ![imagen.png](attachment:bea85517-1194-42bb-ba10-3c0ce04bfb26.png)

# %%
f=symbols('f(t)')

# %%
F=MyIntg(f*exp(-s*t),'F',t,x1=0,x2=oo)
# Out:
# $\displaystyle F=\int\limits_{0}^{\infty} f(t) e^{- s t}\, dt$

# %%
F.subs(f,exp(a*t))
# Out:
# $\displaystyle F=\int\limits_{0}^{\infty} e^{a t} e^{- s t}\, dt$

# %%
F.joinbase()
# Out:
# $\displaystyle F=\int\limits_{0}^{\infty} e^{t \left(a - s\right)}\, dt$

# %%
F.doit()
# Out:
# $\displaystyle F=\begin{cases} - \frac{1}{a - s} & \text{for}\: \left|{\arg{\left(a - s \right)} + \pi}\right| < \frac{\pi}{2} \\\int\limits_{0}^{\infty} e^{t \left(a - s\right)}\, dt & \text{otherwise} \end{cases}$

# %% [markdown]
# ![imagen.png](attachment:1cdd1714-943e-41e7-91f4-b1f43850c074.png)

# %%
# usin Libaldo tools

# %%
F=MyEq(exp(a*t),'F',var=t)
# Out:
# $\displaystyle F =e^{a t}$

# %%
Lf=func2laplace(F)
# Out:
# $\displaystyle \mathcal{L} = \frac{1}{- a + s}$

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)

# %%
from  Libaldomath  import *
from lib_MyDiff import *
from lib_MyIntegral import *

# %%
from  libaldomath  import *
from lib_MyDiff import *
# this cell will be initializing your variables

# %% [markdown]
# ![imagen.png](attachment:adc58e1b-95b5-470a-bfe1-b38845515c9b.png)

# %%
F=MyEq(t**n,'F',var=t)
# Out:
# $\displaystyle F =t^{n}$

# %%
Lf=func2laplace(F)
# Out:
# $\displaystyle \mathcal{L} = \frac{s^{- n} \Gamma\left(n + 1\right)}{s}$

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)

# %%
from  Libaldomath  import *
from lib_MyDiff import *
from lib_MyIntegral import *

# %% [markdown]
# ![imagen.png](attachment:3ed78cc2-ac89-429e-b0f3-7db273f16ad1.png)

# %%
F=MyEq(sin(a*t),'F',var=t)
# Out:
# $\displaystyle F =\sin{\left(a t \right)}$

# %%
L=func2laplace(F)
# Out:
# $\displaystyle \mathcal{L} = \frac{a}{a^{2} + s^{2}}$

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)

# %%
from  Libaldomath  import *
from lib_MyDiff import *
from lib_MyIntegral import *

# %% [markdown]
# ![imagen.png](attachment:b7596e58-46c4-4afc-8a26-7d387a3d8b1b.png)

# %%
F=MyEq(cos(a*t),'F',var=t)
# Out:
# $\displaystyle F =\cos{\left(a t \right)}$

# %%
L=func2laplace(F)
# Out:
# $\displaystyle \mathcal{L} = \frac{s}{a^{2} + s^{2}}$

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)

# %%
from  Libaldomath  import *
from lib_MyDiff import *
from lib_MyIntegral import *

# %% [markdown]
# ![imagen.png](attachment:e59d1c9d-0422-4afa-bc3a-80fc778a64d0.png)

# %%
F=MyEq(t**4+sin(4*t)+cos(7*t),'F',var=t)
# Out:
# $\displaystyle F =t^{4} + \sin{\left(4 t \right)} + \cos{\left(7 t \right)}$

# %%
L=func2laplace(F)
# Out:
# $\displaystyle \mathcal{L} = \frac{s}{s^{2} + 49} + \frac{4}{s^{2} + 16} + \frac{24}{s^{5}}$

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)

# %%
from  Libaldomath  import *
from lib_MyDiff import *
from lib_MyIntegral import *

# %% [markdown]
# ![imagen.png](attachment:eba30742-fa6c-44e1-ac2d-413327b09e3e.png)

# %%
F=MyEq(sin(20*t),'F',var=t)
# Out:
# $\displaystyle F =\sin{\left(20 t \right)}$

# %%
L=func2laplace(F)
# Out:
# $\displaystyle \mathcal{L} = \frac{20}{s^{2} + 400}$

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)

# %%
from  Libaldomath  import *
from lib_MyDiff import *
from lib_MyIntegral import *

# %% [markdown]
# ![imagen.png](attachment:b64fbc76-4fcb-43fc-bde2-fa31e142918f.png)

# %%
F=MyEq((sin(pi*t))**2,'F',var=t)
# Out:
# $\displaystyle F =\sin^{2}{\left(\pi t \right)}$

# %%
L=func2laplace(F)
# Out:
# $\displaystyle \mathcal{L} = \frac{2 \pi^{2}}{s \left(s^{2} + 4 \pi^{2}\right)}$

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)

# %%
from  Libaldomath  import *
from lib_MyDiff import *
from lib_MyIntegral import *

# %% [markdown]
# ![imagen.png](attachment:993c9f2c-4b91-49e9-9dd3-8502b0e8cce0.png)

# %%
F=MyEq(t**3*exp(4*t),'F',var=t)
# Out:
# $\displaystyle F =t^{3} e^{4 t}$

# %%
L=func2laplace(F)
# Out:
# $\displaystyle \mathcal{L} = \frac{6}{\left(s - 4\right)^{4}}$

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)
