# %% [markdown]
# ![image.png](attachment:fe4d89c2-2fe0-4968-89ec-eacf08018c0b.png)

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)

# %% [markdown]
# ![image.png](attachment:30793e2e-4c00-4d26-9d4d-cfbfd2eb8dd1.png)

# %%
from libaldomath import *
from lib_MyInequality3 import *

# %%
Q1=MQ(x**5+3*x**4-5*x**3-15*x*x+4*x+12,'>',0)
# Out:
# $\displaystyle x^{5} + 3 x^{4} - 5 x^{3} - 15 x^{2} + 4 x + 12 > 0$

# %%
Q1.factor()
# Out:
# $\displaystyle \left(x - 2\right) \left(x - 1\right) \left(x + 1\right) \left(x + 2\right) \left(x + 3\right) > 0$

# %%
R=Q1.isolve()
# Out:
# $\displaystyle \left(-3 < x \wedge x < -2\right) \vee \left(-1 < x \wedge x < 1\right) \vee \left(2 < x \wedge x < \infty\right)$

# %%
isolu2Iq(R)
# Out:
# $\displaystyle [-3<x<-2] U [-1<x<1] U [2<x<\infty]$

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)

# %% [markdown]
# ![image.png](attachment:4bc372d5-fdcf-44a2-8915-551314ee62eb.png)

# %%
from libaldomath import *
from lib_MyInequality3 import *

# %%
Q=MQ((x-2)/(x+3),'<',(x+1)/x)
# Out:
# $\displaystyle \frac{x - 2}{x + 3} < \frac{x + 1}{x}$

# %% [markdown]
# ![image.png](attachment:8359aa48-b140-4785-b978-6b2dc36e2536.png)

# %%
R=Q.isolve()
# Out:
# $\displaystyle \left(-3 < x \wedge x < - \frac{1}{2}\right) \vee \left(0 < x \wedge x < \infty\right)$

# %%
isolu2Iq(R)
# Out:
# $\displaystyle [-3<x<- \frac{1}{2}] U [0<x<\infty]$

# %% [markdown]
# ![image.png](attachment:e10f1480-9caa-4284-806f-29469213dec7.png)

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)

# %% [markdown]
# ![image.png](attachment:f4ff3054-25c4-4895-9e4f-ee3313f8af5b.png)

# %%
from libaldomath import *
from lib_MyInequality3 import *

# %%
Q=MQ(sqrt(8-2*x),'<',sqrt(13))
# Out:
# $\displaystyle \sqrt{8 - 2 x} < \sqrt{13}$

# %%
Q1=MQ(8-2*x,'>=',0)
# Out:
# $\displaystyle 8 - 2 x ≥ 0$

# %%
Q.Pow(2)
# Out:
# $\displaystyle 8 - 2 x < 13$

# %%
R=isolve(Q,Q1)
R
# Out:
# x ≤ 4 ∧ -5/2 < x

# %%
S=isolu2Iq(R)
# Out:
# $\displaystyle - \frac{5}{2} < x ≤4$

# %% [markdown]
# ![image.png](attachment:35ba8c07-15ce-49e7-8b63-eb87e3881f91.png)

# %% [markdown]
# ![image.png](attachment:88ad5e4c-afa2-450d-9622-62851c582729.png)

# %% [markdown]
# ![image.png](attachment:98f91c05-097f-491c-b6e8-53744077b5f5.png)

# %%
from libaldomath import *
from lib_MyInequality3 import *

# %%
Q=MQ(sqrt(x*x-x-12),'<',sqrt(x*x-6*x+5))
# Out:
# $\displaystyle \sqrt{x^{2} - x - 12} < \sqrt{x^{2} - 6 x + 5}$

# %%
Q1=MQ(x*x-x-12,'>=',0)
Q2=MQ(x*x-6*x+5,'>=',0)
# Out:
# $\displaystyle x^{2} - x - 12 ≥ 0$
# $\displaystyle x^{2} - 6 x + 5 ≥ 0$

# %%
Q.Pow(2)
# Out:
# $\displaystyle x^{2} - x - 12 < x^{2} - 6 x + 5$

# %%
Q.all2L()
# Out:
# $\displaystyle 5 x - 17 < 0$

# %%
S=isolu2Iq(isolve(Q,Q1,Q2))
# Out:
# $\displaystyle -\infty < x ≤-3$

# %% [markdown]
# ![image.png](attachment:0d32c73f-e6da-4c42-bd70-96d7eb7b8d3d.png)

# %% [markdown]
# ![image.png](attachment:dbf57fd8-5d91-484d-84c7-3a53cf327fda.png)
